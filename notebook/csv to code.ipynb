# %%
import pandas as pd
import numpy as np
import colorsys

# %%
code = """        colorList.add(ColorName("Davy's grey",0x55,0x55,0x55,0.0F,0.0F,0.33F))
        colorList.add(ColorName("Gainsboro",0xDC,0xDC,0xDC,0.0F,0.0F,0.86F))
        colorList.add(ColorName("Light gray",0xD3,0xD3,0xD3,0.0F,0.0F,0.83F))
        colorList.add(ColorName("Quick Silver",0xA6,0xA6,0xA6,0.0F,0.0F,0.65F))
        colorList.add(ColorName("Spanish gray",0x98,0x98,0x98,0.0F,0.0F,0.6F))
        colorList.add(ColorName("Gray",0x80,0x80,0x80,0.0F,0.0F,0.5F))
        colorList.add(ColorName("Silver chalice",0xAC,0xAC,0xAC,0.0F,0.0F,0.67F))
        colorList.add(ColorName("Dim gray",0x69,0x69,0x69,0.0F,0.0F,0.41F))
        colorList.add(ColorName("Jet",0x34,0x34,0x34,0.0F,0.0F,0.2F))
        colorList.add(ColorName("Cultured",0xF5,0xF5,0xF5,0.0F,0.0F,0.96F))
        colorList.add(ColorName("Gray",0xBE,0xBE,0xBE,0.0F,0.0F,0.75F))
        colorList.add(ColorName("Sonic silver",0x75,0x75,0x75,0.0F,0.0F,0.46F))
        colorList.add(ColorName("Granite gray",0x67,0x67,0x67,0.0F,0.0F,0.4F))
        colorList.add(ColorName("Silver",0xC0,0xC0,0xC0,0.0F,0.0F,0.75F))
        colorList.add(ColorName("Feldgrau",0x4D,0x5D,0x53,143.0F,0.09F,0.33F))
        colorList.add(ColorName("Ash gray",0xB2,0xBE,0xB5,135.0F,0.08F,0.72F))
        colorList.add(ColorName("Xanadu",0x73,0x86,0x78,136.0F,0.08F,0.49F))
        colorList.add(ColorName("Roman silver",0x83,0x89,0x96,221.0F,0.08F,0.55F))
        colorList.add(ColorName("Old lavender",0x79,0x68,0x78,304.0F,0.08F,0.44F))
        colorList.add(ColorName("Ebony",0x55,0x5D,0x50,97.0F,0.08F,0.34F))
        colorList.add(ColorName("Platinum",0xE5,0xE4,0xE2,40.0F,0.06F,0.89F))
        colorList.add(ColorName("Middle grey",0x8B,0x86,0x80,33.0F,0.05F,0.52F))
        colorList.add(ColorName("Dark liver",0x53,0x4B,0x4F,330.0F,0.05F,0.31F))
        colorList.add(ColorName("Rocket metallic",0x8A,0x7F,0x80,355.0F,0.05F,0.52F))
        colorList.add(ColorName("Black olive",0x3B,0x3C,0x36,70.0F,0.05F,0.22F))
        colorList.add(ColorName("Taupe gray",0x8B,0x85,0x89,320.0F,0.03F,0.53F))
        colorList.add(ColorName("Silver",0xAA,0xA9,0xAD,255.0F,0.02F,0.67F))
        colorList.add(ColorName("Silver sand",0xBF,0xC1,0xC2,200.0F,0.02F,0.75F))
        colorList.add(ColorName("Nickel",0x72,0x74,0x72,120.0F,0.01F,0.45F))
        colorList.add(ColorName("Battleship grey",0x84,0x84,0x82,60.0F,0.01F,0.51F))
        colorList.add(ColorName("Manatee",0x97,0x9A,0xAA,231.0F,0.1F,0.63F))
        colorList.add(ColorName("Heliotrope gray",0xAA,0x98,0xA9,303.0F,0.1F,0.63F))
        colorList.add(ColorName("Timberwolf",0xDB,0xD7,0xD2,33.0F,0.11F,0.84F))
        colorList.add(ColorName("Pale silver",0xC9,0xC0,0xBB,21.0F,0.12F,0.76F))
        colorList.add(ColorName("Lavender gray",0xC4,0xC3,0xD0,245.0F,0.12F,0.79F))
        colorList.add(ColorName("Cinereous",0x98,0x81,0x7B,12.0F,0.12F,0.54F))
        colorList.add(ColorName("Slate gray",0x70,0x80,0x90,210.0F,0.13F,0.5F))
        colorList.add(ColorName("Mountbatten pink",0x99,0x7A,0x8D,323.0F,0.13F,0.54F))
        colorList.add(ColorName("Light slate gray",0x77,0x88,0x99,210.0F,0.14F,0.53F))
        colorList.add(ColorName("Rhythm",0x77,0x76,0x96,242.0F,0.13F,0.53F))
        colorList.add(ColorName("Artichoke",0x8F,0x97,0x79,76.0F,0.13F,0.53F))
        colorList.add(ColorName("Grullo",0xA9,0x9A,0x86,34.0F,0.17F,0.59F))"""

# %%
pre = "        colorList.add(ColorName("
post = "))"
new_pre = "        colourList.add(ColorName("

# %%
striped = []
for line in code.split('\n'):
    line = line.lstrip(pre)
    line = line.rstrip(post)
    # hex to int
    tmp = line.split(',')
    r = int(tmp[1].lstrip('0x'), 16)
    g = int(tmp[2].lstrip('0x'), 16)
    b = int(tmp[3].lstrip('0x'), 16)
    # Get HSV
    h, s, v = colorsys.rgb_to_hsv(r/255, g/255, b/255)
    tmp.append("{:.2f}F".format(s))
    tmp.append("{:.2f}F".format(v))
    striped.append(tmp)
# Format back to code
formatted = ''
for line in striped:
    formatted += new_pre
    for item in line:
        if line.index(item) == 0:
            formatted += item
        else: 
            formatted += ','
            formatted += item
    formatted += post
    formatted += '\n'
print(formatted)
# Out:
#         colourList.add(ColorName("Davy's grey",0x55,0x55,0x55,0.0F,0.0F,0.33F,0.00F,0.33F))
#         colourList.add(ColorName("Gainsboro",0xDC,0xDC,0xDC,0.0F,0.0F,0.86F,0.00F,0.86F))
#         colourList.add(ColorName("Light gray",0xD3,0xD3,0xD3,0.0F,0.0F,0.83F,0.00F,0.83F))
#         colourList.add(ColorName("Quick Silver",0xA6,0xA6,0xA6,0.0F,0.0F,0.65F,0.00F,0.65F))
#         colourList.add(ColorName("Spanish gray",0x98,0x98,0x98,0.0F,0.0F,0.6F,0.00F,0.60F))
#         colourList.add(ColorName("Gray",0x80,0x80,0x80,0.0F,0.0F,0.5F,0.00F,0.50F))
#         colourList.add(ColorName("Silver chalice",0xAC,0xAC,0xAC,0.0F,0.0F,0.67F,0.00F,0.67F))
#         colourList.add(ColorName("Dim gray",0x69,0x69,0x69,0.0F,0.0F,0.41F,0.00F,0.41F))
#         colourList.add(ColorName("Jet",0x34,0x34,0x34,0.0F,0.0F,0.2F,0.00F,0.20F))
#         colourList.add(ColorName("Cultured",0xF5,0xF5,0xF5,0.0F,0.0F,0.96F,0.00F,0.96F))
# ...

# %% [markdown]
# # Desc.csv

# %%
# Name0,Desc1,Desc2,HEX,R,G,B,Hue,Sat,Lum
csv_desc = """black,Black,Black,#000000,0,0,0,0,0.0,0.0
blue,blue,Bright blue,#3C69E7,60,105,231,224,78.1,57.1
blue,blue,Bright blue,#4169E1,65,105,225,225,72.7,56.9
blue,blue,Bright blue,#273be2,39,59,226,233,76.3,52.0
blue,cyan,Bright blue,#26a7de,38,167,222,197,73.6,51.0
blue,cyan,Bright blue,#42ADDE,66,173,222,199,70.3,56.5
blue,cyan-blue,Bright blue,#45B1E8,69,177,232,200,78.0,59.0
blue,cyan-blue,Bright blue,#24a0ed,36,160,237,202,84.8,53.5
blue,cyan-blue,Bright blue,#3E8EDE,62,142,222,210,70.8,55.7
blue,cyan-blue,Bright blue,#318CE7,49,140,231,210,79.1,54.9
blue,medium light blue,Bright blue,#4166F5,65,102,245,228,90.0,60.8
blue,cyan,Bright cyan,#3ECAE8,62,202,232,191,78.7,57.6
cyan,cyan,Bright cyan,#40E0D0,64,224,208,174,72.1,56.5
green,green,Bright green,#A7F432,167,244,50,84,89.8,57.6
green,green,Bright green,#8ee53f,142,229,63,91,76.1,57.3
green,medium light green,Bright green,#9EFD38,158,253,56,89,98.0,60.6
green,yellow-green,Bright green,#C2F732,194,247,50,76,92.5,58.2
orange,medium light orange,Bright orange,#f99245,249,146,69,25,93.8,62.4
orange,medium light red-orange,Bright orange,#f37042,243,112,66,15,88.1,60.6
orange,medium light red-orange,Bright orange,#F37A48,243,122,72,18,87.7,61.8
brown,orange,Bright orange,#E67E30,230,126,48,26,78.4,54.5
brown,orange,Bright orange,#ED872D,237,135,45,28,84.2,55.3
brown,orange,Bright orange,#e08d3c,224,141,60,29,72.6,55.7
brown,orange,Bright orange,#E18731,225,135,49,29,74.6,53.7
orange,orange,Bright orange,#f07427,240,116,39,22,87.0,54.7
orange,orange,Bright orange,#fb8136,251,129,54,22,96.1,59.8
orange,orange,Bright orange,#F58025,245,128,37,26,91.2,55.3
orange,red-orange,Bright orange,#e56024,229,96,36,18,78.8,52.0
orange,red-orange,Bright orange,#df6124,223,97,36,20,74.5,50.8
orange,red-orange,Bright orange,#E9692C,255,150,0,35,81.1,54.3
red,red-orange,Bright orange,#E25822,226,88,34,17,76.8,51.0
pink,magenta-pink,Bright pink,#E936A7,233,54,167,322,80.3,56.3
pink,magenta-pink,Bright pink,#e9399e,233,57,158,325,80.0,56.9
pink,magenta-pink,Bright pink,#FE28A2,254,40,162,326,99.1,57.6
pink,magenta-pink,Bright pink,#e73895,231,56,149,328,78.5,56.3
pink,magenta-pink,Bright pink,#e94196,233,65,150,329,79.2,58.4
pink,magenta-pink,Bright pink,#DA3287,218,50,135,330,69.4,52.5
pink,medium light magenta-pink,Bright pink,#F9429E,249,66,158,330,93.8,61.8
pink,medium light pink,Bright pink,#fc419a,252,65,154,331,96.9,62.2
pink,medium light pink,Bright pink,#FD3592,253,63,146,334,98.0,60.0
pink,medium light pink,Bright pink,#FD3F92,253,63,146,334,97.9,62.0
pink,medium light pink,Bright pink,#F7468A,247,70,138,337,91.7,62.2
pink,pink,Bright pink,#f62681,246,38,129,333,92.0,55.7
pink,pink,Bright pink,#EC3B83,236,59,131,336,82.3,57.8
pink,pink,Bright pink,#DA3163,218,49,99,342,69.5,52.4
pink,pink,Bright pink,#F03D6F,240,61,111,343,85.6,59.0
pink,pink,Bright pink,#DE3163,222,49,99,343,72.4,53.1
pink,pink,Bright pink,#E52B80,229,43,80,348,78.2,53.3
red,pink,Bright pink,#E3256B,227,37,107,338,77.2,51.8
purple,magenta,Bright purple,#DF33EA,211,56,234,292,81.3,55.9
purple,magenta,Bright purple,#ED3CCA,237,60,202,312,83.1,58.2
red,pink-red,Bright red,#EF3038,239,48,36,4,85.7,56.3
red,pink-red,Bright red,#DA2647,218,38,71,349,70.9,50.2
red,pink-red,Bright red,#E44165,228,65,101,347,75.1,57.5
red,pink-red,Bright red,#E52B50,229,43,80,348,78.2,53.3
red,pink-red,Bright red,#E32636,227,38,54,355,77.1,52.0
orange,red,Bright red,#f35336,243,83,54,9,88.7,58.2
orange,red,Bright red,#eb593d,235,89,61,9,81.3,58.0
red,red,Bright red,#E12C2C,225,44,44,0,75.1,52.7
red,red,Bright red,#ef3939,239,57,57,0,85.0,58.0
red,red,Bright red,#D92121,217,33,33,0,73.6,49.0
red,red,Bright red,#d9463e,217,70,62,3,67.1,54.7
red,red,Bright red,#EB4C42,235,76,66,4,80.9,59.0
red,red,Bright red,#E03C31,224,60,49,4,73.8,53.5
red,red,Bright red,#dc3023,220,48,35,4,72.5,50.0
red,red,Bright red,#E34234,227,66,52,5,75.8,54.7
red,red,Bright red,#F34234,227,66,52,5,88.8,57.8
purple,blue-magenta,Bright violet,#8A2BE2,138,43,226,271,75.9,52.7
purple,blue-magenta,Bright violet,#9842E3,152,66,227,272,74.2,57.5
yellow,medium light yellow-green,Bright yellow,#ECF245,236,242,69,62,86.9,61.0
yellow,yellow-green,Bright yellow,#FEFE33,254,254,51,60,99.0,59.8
yellow,yellow-green,Bright yellow,#FAFA37,250,250,55,60,95.1,59.8
brown,brown,Brown,#e69b3a,230,155,58,33,77.5,56.5
blue,blue,Dark blue,#324AB2,50,74,178,229,56.1,44.7
blue,cyan-blue,Dark blue,#3176AF,49,118,173,207,56.3,43.9
blue,cyan-blue,Dark blue,#2D5DA1,45,93,161,215,56.3,40.4
blue,dark blue,Dark blue,#062A78,6,42,120,221,90.5,24.7
blue,dark blue,Dark blue,#00147e,0,20,126,230,100.0,24.7
blue,medium dark cyan,Dark blue,#006994,0,105,148,197,100.0,29.0
blue,medium dark cyan,Dark blue,#126180,18,97,128,197,75.3,28.6
blue,medium dark blue,Dark blue,#0033AA,0,51,170,222,100.0,33.3
blue,medium dark blue,Dark blue,#002FA7,0,47,167,223,100.0,32.7
blue,medium dark blue,Dark blue,#26428B,38,66,139,223,57.1,34.7
blue,medium dark blue,Dark blue,#002387,0,35,135,224,100.0,26.5
blue,medium dark blue,Dark blue,#002395,0,35,149,226,100.0,29.2
blue,medium dark blue,Dark blue,#1034A6,16,52,166,226,82.4,35.7
blue,medium dark blue,Dark blue,#091F92,9,31,146,230,88.4,30.4
blue,medium dark blue,Dark blue,#0018A8,0,24,168,231,100.0,32.9
blue,medium dark blue,Dark blue,#12279E,18,39,158,231,79.5,34.5
blue,medium dark blue,Dark blue,#000f89,0,15,137,233,100.0,26.9
blue,medium dark blue,Dark blue,#0014A8,0,20,168,233,100.0,32.9
blue,medium dark blue,Dark blue,#23297A,35,41,122,236,55.4,30.8
blue,medium dark blue,Dark blue,#0a1195,10,17,149,237,87.4,31.2
blue,medium dark blue-magenta,Dark blue,#000080,0,0,128,240,100.0,25.1
blue,medium dark blue-magenta,Dark blue,#00008B,0,0,139,240,100.0,27.3
blue,medium dark blue-magenta,Dark blue,#00009C,0,0,156,240,100.0,30.6
blue,medium dark blue-magenta,Dark blue,#2E2787,46,39,135,244,55.2,34.1
blue,medium dark blue-magenta,Dark blue,#120A8F,18,10,143,244,86.9,30.0
blue,medium dark blue-magenta,Dark blue,#1b03a3,27,3,163,249,96.4,32.5
blue,medium dark cyan,Dark blue,#007AA5,0,122,165,196,100.0,32.4
blue,medium dark cyan,Dark blue,#007BA7,0,123,167,196,100.0,32.7
blue,medium dark cyan,Dark blue,#006594,0,101,148,199,100.0,29.0
blue,medium dark cyan-blue,Dark blue,#0072b1,0,114,177,201,100.0,34.7
blue,medium dark cyan-blue,Dark blue,#0067A5,0,103,165,203,100.0,32.4
blue,medium dark cyan-blue,Dark blue,#006DB0,0,109,176,203,100.0,34.5
blue,medium dark cyan-blue,Dark blue,#005B99,0,91,153,204,100.0,30.0
blue,medium dark cyan-blue,Dark blue,#004F98,0,79,152,209,100.0,29.8
blue,medium dark cyan-blue,Dark blue,#035096,3,80,150,209,96.1,30.0
blue,medium dark cyan-blue,Dark blue,#08457E,8,69,126,209,88.1,26.3
blue,medium dark cyan-blue,Dark blue,#00468c,0,70,140,210,100.0,27.5
blue,medium dark cyan-blue,Dark blue,#26619c,38,97,156,210,60.8,38.0
blue,medium dark cyan-blue,Dark blue,#00438A,0,67,138,211,100.0,27.1
blue,medium dark cyan-blue,Dark blue,#1A5798,17,80,147,211,70.8,34.9
blue,medium dark cyan-blue,Dark blue,#0F4D92,15,77,146,212,81.4,31.6
blue,medium dark cyan-blue,Dark blue,#0047AB,0,71,171,215,100.0,33.5
blue,medium dark cyan-blue,Dark blue,#28589c,40,88,156,215,59.2,38.4
blue,medium dark cyan-blue,Dark blue,#003C92,0,60,146,215,100.0,28.6
blue,medium dark cyan-blue,Dark blue,#1f4788,31,71,136,217,62.9,32.7
blue,medium dark cyan-blue,Dark blue,#0038A8,0,56,168,220,100.0,32.9
blue,medium dark cyan-blue,Dark blue,#003399,0,51,153,220,100.0,30.0
blue,medium dark cyan-blue,Dark blue,#0038a7,0,56,167,220,100.0,32.7
blue,medium dark cyan-blue,Dark blue,#00308F,0,48,143,220,100.0,28.0
brown,red-orange,Dark brown,#AF593E,175,89,67,12,47.7,46.5
brown,red-orange,Dark brown,#9b533f,155,83,63,13,42.2,42.7
cyan,cyan,Dark cyan,#20B2AA,32,178,170,177,69.5,41.2
grey,dark cyan,Dark cyan,#006c7f,0,108,127,188,100.0,24.9
green,dark green-cyan,Dark cyan,#00755E,0,117,94,168,100.0,22.9
green,dark cyan,Dark cyan,#01796F,1,121,111,175,98.4,23.9
green,dark cyan,Dark cyan,#007A74,0,122,116,177,100.0,23.9
green,dark green-cyan,Dark cyan,#007F66,0,127,102,168,100.0,24.9
blue,medium dark cyan,Dark cyan,#0093AF,0,147,175,190,100.0,34.3
blue,medium dark cyan,Dark cyan,#1d697c,29,105,124,192,62.1,30.0
cyan,medium dark cyan,Dark cyan,#008B8B,0,139,139,180,100.0,27.3
cyan,medium dark cyan,Dark cyan,#008080,0,128,128,180,100.0,25.1
cyan,medium dark cyan,Dark cyan,#009698,0,150,152,181,100.0,29.8
cyan,medium dark cyan,Dark cyan,#0E9CA5,14,156,165,184,84.4,35.1
cyan,medium dark cyan,Dark cyan,#0A7E8C,10,126,140,186,86.7,29.4
green,medium dark cyan,Dark cyan,#00A693,41,171,136,164,100.0,32.5
green,medium dark cyan,Dark cyan,#00827f,0,130,127,178,100.0,25.5
green,medium dark cyan,Dark cyan,#008B87,0,139,135,178,100.0,27.3
green,dark green,Dark green,#3B7E00,59,126,0,92,100.0,24.7
green,green,Dark green,#66B032,102,176,50,95,55.8,44.3
green,medium dark green,Dark green,#568203,86,130,3,81,95.5,26.1
green,medium dark green,Dark green,#2a8000,42,128,0,100,100.0,25.1
green,medium dark yellow-green,Dark green,#6B8E23,107,142,35,80,60.5,34.7
grey,grey,Dark grey,#8C8C8C,140,140,140,0,0.0,54.9
grey,grey,Dark grey,#808080,128,128,128,0,0.0,50.2
grey,grey,Dark grey,#989898,152,152,152,0,0.0,59.6
grey,grey,Dark grey,#757575,117,117,117,0,0.0,45.9
grey,blue,Dark greyish blue,#838996,131,150,156,194,8.3,55.1
grey,blue-magenta,Dark greyish blue,#78779b,120,119,155,241,15.3,53.7
grey,blue-magenta,Dark greyish blue,#777696,119,118,150,242,13.2,52.5
purple,blue-magenta,Dark greyish blue,#8683A1,134,131,162,246,13.8,57.3
grey,cyan-blue,Dark greyish blue,#708090,112,128,144,210,12.6,50.2
grey,cyan-blue,Dark greyish blue,#778899,119,136,153,210,14.3,53.3
grey,medium light blue,Dark greyish blue,#a8a9ad,168,169,173,228,3.0,66.9
grey,medium light blue,Dark greyish blue,#8C92AC,140,146,172,229,16.2,61.2
grey,medium light blue,Dark greyish blue,#979AAA,151,154,170,231,10.1,62.9
grey,medium light blue-magenta,Dark greyish blue,#AAA9AD,170,169,173,255,2.4,67.1
grey,medium light cyan-blue,Dark greyish blue,#91A3B0,145,163,176,205,16.4,62.9
grey,brown,Dark greyish brown,#8B8680,139,134,128,33,4.5,52.4
grey,brown,Dark greyish brown,#A99A86,169,154,134,34,16.9,59.4
grey,brown,Dark greyish brown,#a09484,160,148,132,34,12.8,57.3
grey,cyan,Dark greyish cyan,#86aba5,134,171,165,170,18.0,59.8
grey,cyan,Dark greyish cyan,#718080,113,128,128,180,6.2,47.3
grey,cyan,Dark greyish cyan,#6e7f80,110,127,128,183,7.6,46.7
grey,green-cyan,Dark greyish cyan,#6a7f7a,106,127,122,165,9.0,45.7
grey,green,Dark greyish green,#8c9c76,140,156,118,85,16.1,53.7
grey,green,Dark greyish green,#78866B,120,134,107,91,11.2,47.3
grey,green,Dark greyish green,#63775b,99,119,91,102,13.3,41.2
grey,yellow-green,Dark greyish green,#8F9779,143,151,121,76,12.6,53.3
grey,green,Dark greyish green-cyan,#738678,115,134,120,136,7.6,48.8
grey,green-cyan,Dark greyish green-cyan,#819c8b,129,156,139,142,12.0,55.9
grey,green-cyan,Dark greyish green-cyan,#8DA399,141,163,153,153,10.7,59.6
grey,green,Dark greyish lime green,#757d75,117,125,117,120,3.3,47.5
grey,green,Dark greyish lime green,#727472,114,116,114,120,0.9,45.1
grey,green,Dark greyish lime green,#828e84,130,142,132,130,5.0,53.3
grey,green,Dark greyish lime green,#738276,115,130,118,132,6.1,48.0
grey,orange,Dark greyish orange,#97867c,151,134,124,22,11.5,53.9
grey,orange,Dark greyish orange,#88786A,136,120,106,28,12.4,47.5
grey,magenta-pink,Dark greyish pink,#8B8589,139,133,137,320,2.5,53.3
grey,magenta-pink,Dark greyish pink,#997A8D,154,122,141,324,13.2,53.9
grey,pink,Dark greyish pink,#9C7687,156,118,135,333,16.1,53.7
purple,pink,Dark greyish pink,#A47D90,164,125,144,331,17.6,56.7
grey,magenta,Dark greyish purple,#8A7F8D,138,127,141,287,5.8,52.5
grey,magenta,Dark greyish purple,#796878,121,104,120,304,7.6,44.1
grey,magenta,Dark greyish purple,#A17E9A,161,126,154,312,15.7,56.3
grey,medium light magenta,Dark greyish purple,#AA98A9,170,152,169,303,9.6,63.1
grey,medium light magenta,Dark greyish purple,#AE98AA,174,152,170,311,12.0,63.9
grey,pink-red,Dark greyish red,#896F73,137,111,115,351,10.5,48.6
grey,pink-red,Dark greyish red,#98777B,152,119,123,353,13.8,53.1
grey,pink-red,Dark greyish red,#8A7F80,138,127,128,355,4.5,52.0
brown,red,Dark greyish red,#AD8884,173,160,132,41,20.0,59.8
grey,red,Dark greyish red,#755d5b,117,93,91,4,12.5,40.8
grey,red,Dark greyish red,#A3807B,163,128,123,8,17.9,56.1
grey,red-orange,Dark greyish red,#98817B,152,129,123,12,12.3,53.9
grey,blue-magenta,Dark greyish violet,#766980,118,105,128,273,9.9,45.7
grey,magenta,Dark greyish violet,#9c8aa4,156,138,164,281,12.5,59.2
grey,magenta,Dark greyish violet,#716675,113,102,117,284,6.8,42.9
grey,yellow,Dark greyish yellow,#817b69,129,123,105,45,10.3,45.9
grey,yellow,Dark greyish yellow,#878681,135,134,129,50,2.4,51.8
grey,yellow-green,Dark greyish yellow,#848482,132,132,130,60,0.8,51.4
grey,yellow-green,Dark greyish yellow,#898a74,137,138,116,62,8.7,49.8
green,dark green-cyan,Dark lime green,#007F5C,0,127,92,163,100.0,24.9
green,green,Dark lime green,#38a32a,56,163,42,113,59.0,40.2
green,green,Dark lime green,#34b233,52,178,51,119,55.5,44.9
green,green,Dark lime green,#27A640,39,166,76,137,62.0,40.2
green,green-cyan,Dark lime green,#32ad61,50,173,97,142,55.2,43.7
green,green-cyan,Dark lime green,#29AB87,41,171,135,163,61.3,41.6
green,medium dark green,Dark lime green,#059033,5,144,51,139,93.3,29.2
green,medium dark green,Dark lime green,#299617,41,150,23,111,73.4,33.9
green,medium dark green,Dark lime green,#30B21A,48,178,26,112,74.5,40.0
green,medium dark green,Dark lime green,#18880d,24,136,13,114,82.6,29.2
green,medium dark green,Dark lime green,#138808,19,136,8,115,88.9,28.2
green,medium dark green,Dark lime green,#0e7a0d,14,122,13,119,80.7,26.5
green,medium dark green,Dark lime green,#009900,0,153,0,120,100.0,30.0
green,medium dark green,Dark lime green,#009000,0,144,0,120,100.0,28.2
green,medium dark green,Dark lime green,#228B22,34,139,34,120,60.7,33.9
green,medium dark green,Dark lime green,#008000,0,128,0,120,100.0,25.1
green,medium dark green,Dark lime green,#008001,0,128,1,120,100.0,25.1
green,medium dark green-cyan,Dark lime green,#00AD43,0,173,67,143,100.0,33.9
green,medium dark green-cyan,Dark lime green,#00A550,0,165,80,149,100.0,32.4
green,medium dark green-cyan,Dark lime green,#008543,0,133,67,150,100.0,26.1
green,medium dark green-cyan,Dark lime green,#1aa260,26,162,96,150,72.3,36.9
green,medium dark green-cyan,Dark lime green,#009150,0,145,80,153,100.0,28.4
green,medium dark green-cyan,Dark lime green,#009E60,0,158,96,156,100.0,31.0
green,medium dark green-cyan,Dark lime green,#00AB66,0,171,102,156,100.0,33.5
green,medium dark green-cyan,Dark lime green,#00A86B,0,168,107,158,100.0,32.9
green,medium dark green-cyan,Dark lime green,#01A368,1,163,104,158,98.8,32.2
green,medium dark green-cyan,Dark lime green,#1CAC78,28,172,120,158,72.0,39.2
green,medium dark green-cyan,Dark lime green,#009966,0,153,102,160,100.0,30.0
green,medium dark green-cyan,Dark lime green,#009F6B,0,159,107,160,100.0,31.2
green,medium dark green-cyan,Dark lime green,#00a870,0,168,112,160,100.0,32.9
green,medium dark green-cyan,Dark lime green,#00A877,0,168,119,163,100.0,32.9
brown,medium dark pink-red,Dark medium red,#7e2639,126,38,57,347,53.7,32.2
brown,medium dark pink-red,Dark medium red,#893843,137,56,67,352,42.0,37.8
blue,blue,Dark moderate blue,#39569c,57,86,156,222,46.5,41.8
blue,blue,Dark moderate blue,#545AA7,84,90,167,236,33.1,49.2
blue,cyan,Dark moderate blue,#44798e,68,121,142,197,35.2,41.2
blue,cyan,Dark moderate blue,#4d8fac,77,143,172,198,38.2,48.8
blue,cyan-blue,Dark moderate blue,#4081A4,64,129,164,201,43.9,44.7
blue,cyan-blue,Dark moderate blue,#5d8cae,93,140,174,205,33.3,52.4
blue,cyan-blue,Dark moderate blue,#44719B,68,113,155,209,39.0,43.7
blue,cyan-blue,Dark moderate blue,#436B95,67,107,149,211,38.0,42.4
blue,cyan-blue,Dark moderate blue,#3560A6,53,96,166,217,51.6,42.9
blue,cyan-blue,Dark moderate blue,#5072A7,80,114,167,217,35.2,48.4
blue,medium dark blue,Dark moderate blue,#365194,54,81,148,222,46.5,39.6
blue,medium dark blue,Dark moderate blue,#333C87,51,60,135,234,45.2,36.5
blue,medium dark blue-magenta,Dark moderate blue,#333399,51,51,153,240,50.0,40.0
blue,medium dark blue-magenta,Dark moderate blue,#2E2D88,46,45,136,241,50.3,35.5
blue,medium dark blue-magenta,Dark moderate blue,#483D8B,72,61,139,248,39.0,39.2
blue,medium dark cyan-blue,Dark moderate blue,#3B708D,59,112,141,201,41.0,39.2
blue,medium dark cyan-blue,Dark moderate blue,#32527b,50,82,123,213,42.2,33.9
blue,medium dark cyan-blue,Dark moderate blue,#2E5894,46,88,148,215,52.6,38.0
blue,medium dark cyan-blue,Dark moderate blue,#2E5090,46,80,144,219,51.6,37.3
purple,medium dark blue-magenta,Dark moderate blue-purple,#4B308D,75,48,141,257,49.2,37.1
brown,brown,Dark moderate brown,#b08d57,176,141,87,36,36.0,51.6
brown,red-orange,Dark moderate brown,#9f5233,159,82,51,17,51.4,41.2
brown,red-orange,Dark moderate brown,#985538,152,85,56,18,46.2,40.8
brown,red-orange,Dark moderate brown,#965a3e,150,90,62,19,41.5,41.6
blue,cyan,Dark moderate cyan,#48929b,72,146,155,186,36.6,44.5
green,cyan,Dark moderate cyan,#3AB09E,58,176,158,171,50.4,45.9
green,green-cyan,Dark moderate cyan,#39A78E,57,167,142,166,49.1,43.9
blue,medium dark cyan,Dark moderate cyan,#256D7B,37,109,123,190,53.8,31.4
blue,medium dark cyan,Dark moderate cyan,#317589,49,117,137,193,47.3,36.5
blue,medium dark cyan,Dark moderate cyan,#367588,54,117,136,194,43.2,37.3
cyan,medium dark cyan,Dark moderate cyan,#2F847C,47,132,124,174,47.5,35.1
green,medium dark cyan,Dark moderate cyan,#317873,49,120,115,176,42.0,33.1
green,medium dark cyan,Dark moderate cyan,#36747D,54,116,125,188,39.7,35.1
green,green,Dark moderate green,#8db255,141,178,85,83,37.7,51.6
green,green,Dark moderate green,#6f9940,111,153,64,88,41.0,42.5
green,medium dark green,Dark moderate green,#5E8C31,94,140,49,90,48.1,37.1
green,green,Dark moderate lime green,#4C9141,76,145,65,112,38.1,41.2
green,green,Dark moderate lime green,#44944A,68,148,74,125,37.0,42.4
green,medium dark green,Dark moderate lime green,#4F7942,79,121,66,106,29.4,36.7
green,medium dark green,Dark moderate lime green,#4B8740,75,135,64,111,35.7,39.0
green,medium dark green,Dark moderate lime green,#2e963d,46,150,61,128,53.1,38.4
pink,pink,Dark moderate pink,#A23B6C,162,59,108,331,46.6,43.3
pink,pink,Dark moderate pink,#AA4069,170,64,105,337,45.3,45.9
pink,pink,Dark moderate pink,#a4345d,164,52,93,338,51.9,42.4
pink,pink,Dark moderate pink,#AA375A,170,55,90,342,51.1,44.1
pink,pink,Dark moderate pink,#B04C6A,176,76,106,342,39.7,49.4
purple,pink,Dark moderate pink,#A8516E,168,81,110,340,34.9,48.8
purple,pink,Dark moderate pink,#8F4155,143,65,85,345,37.5,40.8
brown,pink-red,Dark moderate pink-red,#AB5C6D,171,92,109,347,32.0,51.6
purple,pink-red,Dark moderate pink-red,#A95C68,169,92,104,351,30.9,51.2
purple,blue-magenta,Dark moderate purple,#5946B2,89,70,178,251,43.5,48.6
purple,magenta,Dark moderate purple,#9A4EAE,154,78,174,288,38.1,49.4
purple,magenta,Dark moderate purple,#8F509D,143,80,157,289,32.5,46.5
purple,magenta,Dark moderate purple,#A757AB,167,87,171,297,33.3,50.6
purple,magenta,Dark moderate purple,#934D91,147,77,145,302,31.3,43.9
purple,magenta,Dark moderate purple,#8E4585,142,69,133,307,34.6,41.4
purple,magenta,Dark moderate purple,#98508E,152,80,142,308,31.0,45.5
purple,magenta,Dark moderate purple,#A55790,165,87,144,316,31.0,49.4
purple,magenta,Dark moderate purple,#963D7F,150,61,127,316,42.2,41.4
purple,magenta,Dark moderate purple,#AE4F93,174,79,147,317,37.5,49.6
purple,magenta,Dark moderate purple,#9C5186,156,81,134,318,31.6,46.5
purple,magenta,Dark moderate purple,#94417B,148,65,123,318,39.0,41.8
purple,magenta,Dark moderate purple,#924E7D,146,78,125,319,30.4,43.9
purple,magenta-pink,Dark moderate purple,#A85387,168,83,135,323,33.9,49.2
purple,magenta-pink,Dark moderate purple,#A63A79,166,58,121,325,48.2,43.9
purple,magenta-pink,Dark moderate purple,#914E75,145,78,117,325,30.0,43.7
purple,magenta-pink,Dark moderate purple,#A03472,160,52,114,326,50.9,41.6
purple,magenta-pink,Dark moderate purple,#9F4576,159,69,118,327,39.5,44.7
purple,magenta-pink,Dark moderate purple,#9A366B,154,54,107,328,48.1,40.8
purple,magenta-pink,Dark moderate purple,#8A496B,138,73,107,329,30.8,41.4
purple,magenta-pink,Dark moderate purple,#AD4379,173,67,121,329,44.2,47.1
purple,magenta-pink,Dark moderate purple,#AB3472,171,52,114,329,53.4,43.7
purple,medium dark blue-magenta,Dark moderate purple,#3E2F84,62,47,132,251,47.5,35.1
brown,medium dark pink-red,Dark moderate red,#8B3F43,139,63,67,357,37.6,39.6
purple,medium dark pink-red,Dark moderate red,#893F45,137,63,69,355,37.0,39.2
brown,pink-red,Dark moderate red,#AB4B52,171,75,82,356,39.0,48.2
brown,pink-red,Dark moderate red,#AB4E52,171,78,82,357,37.3,48.8
brown,pink-red,Dark moderate red,#933d41,147,61,65,357,41.3,40.8
brown,pink-red,Dark moderate red,#9A393D,154,57,61,358,46.0,41.4
brown,pink-red,Dark moderate red,#A23B3C,162,59,60,359,46.6,43.3
brown,red,Dark moderate red,#944747,148,71,71,0,35.2,42.9
brown,red,Dark moderate red,#A55353,165,83,83,0,33.1,48.6
brown,red,Dark moderate red,#a24f46,162,79,70,5,39.7,45.5
brown,red,Dark moderate red,#AF4035,175,64,53,5,53.5,44.7
brown,red,Dark moderate red,#A45A52,164,90,82,6,33.3,48.2
brown,red,Dark moderate red,#b05c52,176,92,82,6,37.3,50.6
brown,red,Dark moderate red,#B0665C,176,102,92,7,34.7,52.5
brown,red,Dark moderate red,#ab4c3d,171,76,61,8,47.4,45.5
purple,blue-magenta,Dark moderate violet,#7058A3,112,88,163,259,29.9,49.2
purple,blue-magenta,Dark moderate violet,#7851A9,120,91,169,262,35.2,49.0
purple,blue-magenta,Dark moderate violet,#714AB2,113,74,178,263,41.3,49.4
purple,blue-magenta,Dark moderate violet,#6B3FA0,107,63,160,267,43.5,43.7
purple,blue-magenta,Dark moderate violet,#69359c,105,53,156,270,49.3,41.0
purple,blue-magenta,Dark moderate violet,#7B4BAB,123,75,171,270,39.0,48.2
purple,blue-magenta,Dark moderate violet,#734F96,115,79,150,270,31.0,44.9
purple,blue-magenta,Dark moderate violet,#714693,113,70,147,274,35.5,42.5
purple,blue-magenta,Dark moderate violet,#8359A3,131,89,163,274,29.4,49.4
purple,magenta,Dark moderate violet,#7f3e98,127,62,152,283,42.1,42.0
brown,yellow,Dark moderate yellow,#9c8a4d,156,138,77,46,33.9,45.7
green,yellow-green,Dark moderate yellow-green,#96a53c,150,165,60,68,46.7,44.1
brown,dark brown,Dark brown,#7B3F00,123,63,0,31,100.0,24.1
brown,medium dark orange,Dark brown,#8B4513,139,69,19,25,75.9,31.0
brown,medium dark brown,Medium dark brown,#A75502,167,85,2,30,97.6,33.1
brown,medium dark brown,Medium dark brown,#804000,128,64,0,30,100.0,25.1
brown,medium dark brown,Medium dark brown,#964B00,150,75,0,30,100.0,29.4
brown,medium dark brown,Medium dark brown,#804a00,128,74,0,34,100.0,25.1
brown,medium dark brown,Medium dark brown,#88540B,136,84,11,35,85.0,28.8
brown,medium dark brown,Medium dark brown,#734A12,115,74,18,35,72.9,26.1
brown,medium dark brown,Medium dark brown,#996515,153,101,21,36,75.9,34.1
brown,medium dark brown,Medium dark brown,#b17304,177,115,4,38,95.6,35.5
brown,medium dark orange,Dark brown,#87410E,183,65,14,18,81.2,29.2
brown,medium dark orange,Dark brown,#A05220,160,82,45,19,66.7,37.6
brown,medium dark orange,Dark brown,#993300,153,51,0,20,100.0,30.0
brown,medium dark orange,Dark brown,#933709,147,55,9,20,88.5,30.6
brown,medium dark orange,Dark brown,#87421F,135,66,31,20,62.7,32.5
brown,medium dark orange,Dark brown,#7E3A15,126,58,21,21,71.4,28.8
brown,medium dark orange,Dark brown,#923c01,146,60,1,24,98.6,28.8
brown,medium dark orange,Dark brown,#985629,152,86,41,24,57.5,37.8
brown,medium dark orange,Dark brown,#80461B,128,70,27,26,65.2,30.4
brown,medium dark orange,Dark brown,#804618,128,70,27,26,68.4,29.8
brown,medium dark orange,Dark brown,#7F3A02,127,58,2,27,96.9,25.3
brown,medium dark orange,Dark brown,#9D5616,157,86,22,28,75.4,35.1
brown,medium dark red-orange,Dark brown,#ac4313,172,67,19,18,80.1,37.5
brown,medium dark yellow,Medium dark yellow-brown,#996600,153,102,0,40,100.0,30.0
brown,medium dark yellow,Medium dark yellow-brown,#936900,147,105,0,42,100.0,28.8
brown,medium dark yellow,Medium dark yellow-brown,#a17917,161,121,23,43,75.0,36.1
brown,medium dark yellow,Medium dark yellow-brown,#967117,150,113,23,43,73.4,33.9
brown,orange,Brown,#a96232,169,98,50,24,54.3,42.9
brown,red-orange,Brown,#A0522D,160,82,45,19,56.1,40.2
pink,magenta-pink,Dark pink,#B12B7F,177,43,127,322,60.9,43.1
purple,medium dark magenta-pink,Dark pink,#A50B5E,165,11,94,328,87.5,34.5
pink,medium dark magenta,Dark pink,#A2006D,162,0,109,320,100.0,31.8
pink,medium dark magenta-pink,Dark pink,#871550,135,21,80,329,73.1,30.6
purple,medium dark magenta-pink,Medium dark pink,#990066,153,0,102,320,100.0,30.0
purple,medium dark magenta-pink,Medium dark pink,#99005D,153,0,93,324,100.0,30.0
purple,medium dark magenta-pink,Medium dark pink,#811453,129,20,83,325,73.2,29.2
purple,medium dark magenta-pink,Medium dark pink,#9F2B68,159,43,104,328,57.4,39.6
purple,medium dark magenta-pink,Medium dark pink,#78184A,120,24,74,329,66.7,28.2
purple,medium dark magenta-pink,Medium dark pink,#872657,135,38,87,330,56.1,33.9
pink,medium dark pink,Dark pink,#B11355,177,19,85,335,80.6,38.4
purple,medium dark pink,Medium dark pink,#891446,137,20,70,334,74.5,30.8
purple,medium dark pink,Medium dark pink,#9F1F4C,159,31,76,339,67.4,37.3
purple,medium dark pink,Medium dark pink,#7F1734,127,23,52,343,69.3,29.4
red,medium dark pink,Dark pink-red,#960145,150,1,69,332,98.7,29.6
red,medium dark pink,Dark pink-red,#B00049,176,0,73,335,100.0,34.5
red,medium dark pink,Dark pink-red,#980036,152,0,54,338,100.0,29.8
red,medium dark pink,Dark pink-red,#9E0E40,158,14,64,339,83.7,33.7
red,medium dark pink,Dark pink-red,#ac1e44,172,30,68,343,70.3,39.6
red,medium dark pink,Dark pink-red,#AD1C42,173,28,66,344,72.1,39.4
pink,pink,Dark pink,#B03060,176,48,96,338,57.1,43.9
pink,pink,Dark pink,#AB274F,171,39,79,342,62.9,41.2
purple,medium dark magenta,Dark purple,#650086,101,0,134,285,100.0,26.3
purple,medium dark magenta,Dark purple,#731E8F,115,30,143,285,65.3,33.9
purple,medium dark magenta,Dark purple,#8601AF,134,1,175,286,98.9,34.5
purple,medium dark magenta,Dark purple,#9400A5,148,0,165,294,100.0,32.4
purple,medium dark magenta,Dark purple,#7D2181,125,33,129,298,59.3,31.8
purple,medium dark magenta,Dark purple,#991199,153,17,153,300,80.0,33.3
purple,medium dark magenta,Dark purple,#990099,153,0,153,300,100.0,30.0
purple,medium dark magenta,Dark purple,#880085,136,0,137,300,100.0,26.7
purple,medium dark magenta,Dark purple,#800080,128,0,128,300,100.0,25.1
purple,medium dark magenta,Dark purple,#81007f,129,0,127,300,100.0,25.3
purple,medium dark magenta,Dark purple,#8B008B,139,0,139,300,100.0,27.3
purple,medium dark magenta,Dark purple,#B10097,177,0,151,309,100.0,34.7
purple,medium dark magenta,Dark purple,#A10684,161,6,132,311,92.8,32.7
brown,dark red,Dark brown,#7C0A02,124,10,2,4,96.8,24.7
brown,dark red,Dark brown,#770f05,119,15,5,5,91.9,24.3
red,medium dark red,Dark red,#a40000,164,0,0,0,100.0,32.2
brown,medium dark pink-red,Dark brown,#9D2933,157,41,51,355,58.6,38.8
brown,medium dark pink-red,Dark brown,#9F1D35,159,29,35,357,69.1,36.9
purple,medium dark pink-red,Dark brown,#9C2542,156,37,66,345,61.7,37.8
purple,medium dark pink-red,Dark brown,#800020,128,0,32,345,100.0,25.1
purple,medium dark pink-red,Dark brown,#7B1113,125,52,67,348,75.7,27.5
purple,medium dark pink-red,Dark brown,#922B3E,146,43,62,350,54.5,37.1
red,medium dark pink-red,Dark red,#990024,97,64,81,329,100.0,30.0
red,medium dark pink-red,Dark red,#af002a,175,0,42,345,100.0,34.3
red,medium dark pink-red,Dark red,#B20931,178,9,49,346,90.4,36.7
red,medium dark pink-red,Dark red,#A9203E,169,32,62,347,68.2,39.4
red,medium dark pink-red,Dark red,#A32638,163,38,65,347,62.2,39.4
red,medium dark pink-red,Dark red,#900020,144,0,32,347,100.0,28.2
red,medium dark pink-red,Dark red,#9E1B32,158,27,50,349,70.8,36.3
red,medium dark pink-red,Dark red,#841B2D,132,27,45,350,66.0,31.2
red,medium dark pink-red,Dark red,#960018,150,0,24,350,100.0,29.4
red,medium dark pink-red,Dark red,#9b1c31,155,28,49,350,69.4,35.9
red,medium dark pink-red,Dark red,#b11226,177,18,38,352,81.5,38.2
red,medium dark pink-red,Dark red,#b2071d,178,7,29,352,92.4,36.3
red,medium dark pink-red,Dark red,#AD1022,173,16,34,353,83.1,37.1
red,medium dark pink-red,Dark red,#860111,134,1,17,353,98.5,26.5
red,medium dark pink-red,Dark red,#9B111E,155,17,30,354,80.2,33.7
red,medium dark pink-red,Dark red,#92000A,146,0,10,356,100.0,28.6
red,medium dark pink-red,Dark red,#a72127,167,33,39,357,67.0,39.2
red,medium dark pink-red,Dark red,#8f1d21,143,29,33,357,66.3,33.7
red,medium dark pink-red,Dark red,#9e1316,158,19,22,358,78.5,34.7
red,medium dark pink-red,Dark red,#8b171a,139,23,26,358,71.6,31.8
red,medium dark pink-red,Dark red,#841617,132,22,23,360,71.4,30.2
red,medium dark pink-red,Dark red,#B10304,177,3,4,360,96.7,35.3
brown,medium dark red,Dark brown,#922724,147,39,36,2,60.4,35.7
brown,medium dark red,Dark brown,#9d2b22,157,43,34,4,64.4,37.5
brown,medium dark red,Dark brown,#913228,145,50,40,5,56.8,36.3
brown,medium dark red,Dark brown,#913225,145,50,37,7,59.3,35.7
brown,medium dark red,Dark brown,#752e23,117,46,35,8,53.9,29.8
brown,medium dark red,Dark brown,#8A3324,138,51,36,9,58.6,34.1
brown,medium dark red,Dark brown,#ab381f,171,56,31,10,69.3,39.6
red,medium dark red,Medium dark red,#820000,130,0,0,0,100.0,25.5
red,medium dark red,Medium dark red,#850101,133,1,1,0,98.5,26.3
red,medium dark red,Medium dark red,#8a0303,138,3,3,0,95.7,27.6
red,medium dark red,Medium dark red,#8B0000,139,0,0,0,100.0,27.3
red,medium dark red,Medium dark red,#a41313,164,19,19,0,79.2,35.9
red,medium dark red,Medium dark red,#990000,153,0,0,0,100.0,30.0
red,medium dark red,Medium dark red,#801818,128,24,24,0,68.4,29.8
red,medium dark red,Medium dark red,#800000,128,0,0,0,100.0,25.1
red,medium dark red,Medium dark red,#9C0D07,156,13,7,2,91.4,32.0
red,medium dark red,Medium dark red,#ae0c00,174,12,0,4,100.0,34.1
red,medium dark red,Medium dark red,#b21807,178,24,7,5,92.4,36.3
red,medium dark red,Medium dark red,#A81C07,168,28,7,8,92.0,34.3
brown,medium dark red-orange,Moderate dark brown,#882D17,136,45,23,12,71.1,31.2
brown,medium dark red-orange,Moderate dark brown,#9F381D,159,56,29,12,69.1,36.9
brown,medium dark red-orange,Moderate dark brown,#7C1C05,124,28,5,12,92.2,25.3
brown,medium dark red-orange,Moderate dark brown,#9b351b,155,53,27,12,70.3,35.7
brown,medium dark red-orange,Moderate dark brown,#832A0D,131,42,34,15,81.9,28.2
red,medium dark red-orange,Moderate dark brown,#AA381E,170,56,30,11,70.0,39.2
red,pink-red,Dark red,#AE2029,174,22,42,352,68.9,40.4
red,pink-red,Dark red,#B21B1C,178,27,28,360,73.7,40.2
brown,red,Dark red,#A52A2A,165,42,42,0,59.4,40.6
brown,red,Dark red,#A83731,168,55,49,3,54.8,42.5
brown,red,Dark red,#a13d2d,161,61,45,8,56.3,40.4
red,red,Dark red,#a62c2b,166,44,43,0,58.9,41.0
red,red,Dark red,#B22222,178,34,34,0,67.9,41.6
brown,red-orange,Brown,#b14a30,177,74,48,12,57.3,44.1
purple,blue-magenta,Dark violet,#6F2DA8,111,45,168,272,57.7,41.8
purple,medium dark blue-magenta,Dark violet,#32127A,50,18,122,258,74.3,27.5
purple,medium dark blue-magenta,Dark violet,#391285,57,18,133,260,76.2,29.6
purple,medium dark blue-magenta,Dark violet,#512888,81,40,136,266,54.5,34.5
purple,medium dark blue-magenta,Dark violet,#551b8c,85,27,140,270,67.7,32.7
purple,medium dark blue-magenta,Dark violet,#4D1A7F,77,26,127,270,66.0,30.0
purple,medium dark blue-magenta,Dark violet,#6A0DAD,106,13,173,275,86.0,36.5
purple,medium dark blue-magenta,Dark violet,#4B0082,75,0,130,275,100.0,25.5
purple,medium dark blue-magenta,Dark violet,#5b0a91,91,10,145,276,87.1,30.4
purple,medium dark magenta,Dark violet,#660099,102,0,153,280,100.0,30.0
purple,medium dark magenta,Dark violet,#720b98,114,11,152,283,86.5,32.0
grey,dark yellow,Dark olive,#737000,115,112,0,58,100.0,22.5
brown,medium dark yellow,Dark yellow-olive,#A57C00,165,124,0,46,100.0,32.4
brown,medium dark yellow,Dark yellow-olive,#b29700,178,151,0,50,100.0,34.9
brown,medium dark yellow,Dark yellow-olive,#9b870c,155,135,12,51,85.6,32.7
green,medium dark yellow-green,Dark yellow-green,#9FA91F,158,169,31,65,69.0,39.2
grey,medium dark yellow-green,Dark yellow-green,#808000,128,128,0,60,100.0,25.1
brown,yellow,Dark yellow brown,#9C7C3B,156,114,56,35,45.1,42.2
brown,yellow,Dark yellow brown,#9C7C38,156,124,56,41,47.2,41.6
brown,yellow,Dark yellow brown,#aa8736,170,135,54,41,51.8,43.9
brown,yellow,Dark yellow brown,#957b38,149,123,56,43,45.4,40.2
grey,medium light grey,Grey,#A6A6A6,166,166,166,0,0.0,65.1
grey,medium light grey,Grey,#A9A9A9,169,169,169,0,0.0,66.3
grey,medium light grey,Grey,#ACACAC,172,172,172,0,0.0,67.5
grey,medium light grey,Grey,#b3b3b3,179,179,179,0,0.0,70.2
grey,medium light grey,Grey,#BEBEBE,190,190,190,0,0.0,74.5
grey,light blue-magenta,Greyish blue,#C4C3D0,196,195,221,242,12.1,79.0
grey,light blue-magenta,Greyish blue,#BDBBD7,189,187,215,244,25.9,78.8
grey,light cyan-blue,Greyish blue,#BFC1C2,191,193,194,200,2.4,75.5
grey,medium light cyan,Greyish blue,#aec6cf,174,198,207,196,25.6,74.7
grey,medium light cyan-blue,Greyish blue,#A9B2C3,169,178,195,219,17.8,71.4
blue,medium light blue,Greyish blue,#A2ADD0,162,173,208,226,32.9,72.5
grey,medium light blue-magenta,Greyish blue,#A2A2D0,162,162,208,240,32.9,72.5
grey,medium light blue-magenta,Greyish blue,#AAA9CD,170,169,205,242,26.5,73.3
grey,medium light cyan-blue,Greyish blue,#8BA8B7,139,168,183,200,23.4,63.1
brown,medium light brown,Greyish brown,#ABA092,71,100,146,217,13.0,62.2
brown,medium light brown,Greyish brown,#AF9E89,175,158,137,33,19.2,61.2
grey,medium light brown,Greyish brown,#A99F95,169,159,149,30,10.4,62.4
green,light cyan,Greyish cyan,#B4CFD3,180,207,211,188,26.1,76.7
cyan,light green-cyan,Greyish cyan,#AFD0CA,175,208,202,169,26.0,75.1
grey,medium light cyan,Grey,#B8C2C2,184,194,194,180,7.6,74.1
grey,light green-cyan,Greyish cyan,#bbd0c9,187,208,201,160,18.3,77.5
grey,medium light green,Grey,#B2BEB5,178,190,181,135,8.5,72.2
grey,medium light green-cyan,Greyish green-cyan,#A3C1AD,163,193,173,140,19.5,69.8
grey,medium light green-cyan,Greyish green-cyan,#A8C3BC,168,195,188,164,18.4,71.2
grey,medium light green,Grey-green,#afb1ae,175,177,174,99,1.9,68.8
grey,medium light green,Greyish green,#a5ba93,165,186,147,92,22.0,65.3
grey,medium light green,Greyish green,#A9BA9D,169,186,157,95,17.4,67.3
grey,medium light green,Greyish green,#AEBEA6,142,190,166,150,15.6,69.8
grey,medium light yellow-green,Greyish green,#ACB78E,172,183,142,76,22.2,63.7
grey,medium light green-cyan,Greyish green-cyan,#96ABA5,134,171,165,170,11.1,62.9
green,medium light green,Greyish lime green,#8FBC8F,143,188,143,120,25.1,64.9
green,medium light green,Greyish lime green,#96C8A2,150,200,162,134,31.3,68.6
grey,light magenta,Greyish purple,#D8BFD8,216,191,216,300,24.3,79.8
purple,light magenta,Greyish purple,#D8B2D1,219,178,209,315,32.8,77.3
grey,medium light magenta,Greyish purple,#b39eb5,179,158,181,294,13.5,66.5
purple,medium light magenta,Greyish purple,#AB92B3,171,146,179,285,17.8,63.7
purple,medium light magenta,Greyish purple,#B695C0,182,149,192,286,25.4,66.9
purple,medium light magenta,Greyish purple,#CAABD0,202,171,208,290,28.2,74.3
purple,medium light magenta,Greyish purple,#C8A2C8,200,162,200,300,25.7,71.0
purple,medium light magenta,Greyish purple,#CBA2C8,200,162,200,300,28.3,71.6
purple,medium light magenta,Greyish purple,#cb99c9,203,153,201,302,32.5,69.8
purple,medium light magenta,Greyish purple,#C79FC4,231,159,196,329,26.3,70.2
grey,light orange,Greyish brown,#C9C0BB,201,192,187,21,11.5,76.1
brown,medium light brown,Greyish orange,#d1bea8,209,190,168,32,30.8,73.9
grey,medium light orange,Greyish orange,#b9a193,185,161,147,22,21.3,65.1
grey,medium light orange,Greyish orange,#bea493,190,164,147,23,24.9,66.1
grey,medium light yellow,Greyish brown,#BFB8A5,191,184,165,44,16.9,69.8
grey,medium light yellow,Greyish brown,#c6c2b6,198,194,182,44,12.3,74.5
purple,medium light magenta,Greyish pink,#C49FBA,196,159,186,316,23.9,69.6
grey,medium light magenta-pink,Greyish pink,#AA8A9E,170,138,158,323,15.8,60.4
grey,medium light pink,Greyish pink,#B89CA9,184,156,169,332,16.5,66.7
grey,medium light pink,Greyish pink,#C3A6B1,195,166,177,337,19.5,70.8
grey,light pink-red,Greyish red,#CFBCBE,207,188,190,354,16.5,77.5
grey,medium light pink-red,Greyish red,#AF868E,175,134,142,348,20.4,60.6
grey,medium light pink-red,Greyish red,#AD9194,173,145,148,354,14.6,62.4
grey,medium light pink-red,Greyish red,#BFAFB2,191,175,178,349,11.1,71.8
grey,medium light pink-red,Greyish red,#C09396,217,166,169,356,26.3,66.5
brown,medium light red,Greyish red,#BC8F8F,188,143,143,0,25.1,64.9
brown,medium light red,Greyish red,#C09999,192,153,153,0,23.6,67.6
brown,medium light red,Greyish red,#CFA4A4,197,164,164,0,30.9,72.7
grey,medium light red,Greyish red,#C4AEAD,196,174,173,3,16.3,72.4
grey,medium light red-orange,Greyish red,#C1B6B3,193,182,179,13,10.1,72.9
grey,medium light blue-magenta,Greyish violet,#A397B4,163,151,180,265,16.2,64.9
purple,medium light blue-magenta,Greyish violet,#B2A4D4,178,164,202,262,35.8,73.7
grey,medium light magenta,Greyish violet,#BAA8C1,186,168,193,283,16.8,70.8
grey,light yellow-green,Greyish yellow,#cfcfc4,207,207,196,60,10.3,79.0
grey,medium light yellow,Greyish yellow,#a19d94,161,157,148,41,6.5,60.6
grey,medium light yellow,Greyish yellow,#A79E8B,167,158,139,41,13.7,60.0
blue,medium light blue,Medium light blue,#4666FF,70,102,255,230,100.0,63.7
blue,medium light blue-magenta,Medium light blue,#6666ff,102,102,255,240,100.0,70.0
grey,light grey,Light grey,#C0C0C0,192,192,192,0,0.0,75.3
grey,light grey,Light grey,#cccccc,204,204,204,0,0.0,80.0
grey,light grey,Light grey,#D3D3D3,211,211,211,0,0.0,82.7
grey,light grey,Light grey,#cfcfcf,207,207,207,0,0.0,81.2
grey,light grey,Light grey,#d6d6d6,214,214,214,0,0.0,83.9
grey,light grey,Light grey,#D8D8D8,216,216,216,0,0.0,84.7
blue,light blue,Light greyish blue,#C3CDE6,195,205,230,223,41.2,83.3
blue,light blue,Light greyish blue,#C5D0E6,197,208,230,220,39.8,83.7
blue,light blue,Light greyish blue,#C5CBE1,197,203,225,228,31.8,82.7
blue,light blue,Light greyish blue,#bfc0ee,191,192,238,238,58.0,84.1
purple,light blue-magenta,Light greyish purple,#C5C2EF,197,194,239,244,58.4,84.9
blue,light cyan-blue,Light greyish blue,#c4d8e2,196,216,226,199,34.1,82.7
blue,light cyan-blue,Light greyish blue,#BCD4E6,188,212,230,206,45.7,82.0
grey,very light blue,Very light greyish blue,#e9edf6,233,237,246,221,41.9,93.9
grey,very light blue,Very light greyish blue,#ebecf0,235,236,240,227,14.3,93.1
grey,very light blue-magenta,Very light greyish purple,#F5F5FD,245,245,253,240,66.7,97.6
grey,very light blue-magenta,Light greyish purple,#D9D8EA,217,216,234,243,30.0,88.2
purple,very light blue-magenta,Light greyish purple,#E6E6FA,230,230,250,240,66.7,94.1
purple,very light blue-magenta,Light greyish purple,#CEC8EF,206,200,239,249,54.9,86.1
purple,very light blue-magenta,Light greyish purple,#D8D0F5,216,208,245,253,64.9,88.8
purple,very light blue-magenta,Very light greyish purple,#F0EEFD,249,238,253,284,78.9,96.3
white,very light blue-magenta,Very light greyish purple,#F9F8FE,249,248,254,250,75.0,98.4
blue,very light cyan-blue,Light greyish purple,#dbe9f4,219,233,244,206,53.2,90.8
grey,very light cyan-blue,Very light grey,#f2f3f4,242,243,244,210,8.3,95.3
grey,light cyan,Light greyish cyan,#d2d9db,210,217,219,193,11.1,84.1
blue,very light cyan,Light greyish cyan,#d4f1f9,212,241,249,192,75.5,90.4
grey,very light cyan,Very light greyish cyan,#ebf6f7,235,246,247,184,42.9,94.5
grey,very light cyan,Light greyish cyan,#DEEBEC,222,235,236,184,26.9,89.8
green,light green-cyan,Light greyish green-cyan,#CBE3D7,200,227,215,153,30.0,84.3
green,light green-cyan,Light greyish green-cyan,#BFDCD4,191,220,212,163,29.3,80.6
green,very light green-cyan,Very light greyish cyan,#e9f6ef,233,246,239,147,41.9,93.9
green,very light green-cyan,Very light greyish cyan,#E6F8F3,230,248,243,163,56.3,93.7
grey,light green,Light greyish green,#DDECC0,221,236,192,80,53.7,83.9
grey,light yellow-green,Light greyish green,#d8e4bc,216,228,188,78,42.6,81.6
grey,very light green,Light grey,#e2e5de,226,229,222,85,11.9,88.4
grey,light magenta,Light greyish purple,#DFD2DF,223,210,222,305,16.9,84.9
purple,very light magenta,Very light purple,#F1D4F1,241,212,241,300,50.9,88.8
purple,very light magenta,Very light purple,#FAE6FA,250,230,250,300,66.7,94.1
grey,light brown,Light greyish brown,#DBD7D2,219,215,210,33,11.1,84.1
grey,light brown,Light greyish brown,#E3DAC9,227,218,201,39,31.7,83.9
brown,light orange,Light brown,#ECD5C5,236,213,197,25,50.6,84.9
grey,light orange,Light greyish brown,#DCD7D4,220,215,212,22,10.3,84.7
grey,very light brown,Very light brown,#FAF0E6,250,240,230,30,66.7,94.1
grey,very light brown,Very light brown,#e6e0d4,230,224,212,39,26.5,86.7
grey,very light orange,Very light brown,#F1DDCF,241,221,207,25,54.8,87.8
grey,very light yellow,Very light yellow,#eae0c8,234,224,200,42,44.7,85.1
brown,very light brown,Light greyish brown,#EFDECD,239,222,205,30,51.5,87.1
grey,very light brown,Light greyish brown,#FAEBD7,250,235,215,34,77.8,91.2
grey,very light brown,Light greyish brown,#ECDEC9,236,222,201,36,47.9,85.7
grey,very light brown,Light greyish brown,#F7E7CE,247,231,206,37,71.9,88.8
grey,very light brown,Light greyish brown,#F2E8D7,242,232,215,38,50.9,89.6
grey,very light brown,Very light grey,#f5f3ef,245,243,239,39,23.1,94.9
grey,very light brown,Very light greyish brown,#FDF5E6,253,245,230,39,85.2,94.7
grey,very light orange,Very light greyish brown,#F4F0EC,244,240,236,30,26.7,94.1
grey,very light yellow,Light grey,#E5E4E2,229,228,226,40,5.5,89.2
grey,very light yellow,Light greyish brown,#ede6d6,237,230,214,41,39.0,88.4
grey,very light yellow,Light greyish brown,#ECE2C6,236,226,198,44,50.0,85.1
purple,light magenta-pink,Light greyish purple,#E4C2D5,228,194,213,326,38.6,82.7
white,very light magenta-pink,Very light greyish purple,#FDF6FA,253,246,250,326,63.6,97.8
grey,very light magenta-pink,Very light greyish purple,#F4E5ED,244,229,237,328,40.5,92.7
pink,very light magenta-pink,Very light greyish purple,#F9EAF3,249,234,243,324,55.6,94.7
pink,very light magenta-pink,Very light greyish purple,#FDE9F5,253,233,245,324,83.3,95.3
pink,very light magenta-pink,Very light greyish purple,#FCE5F2,252,229,242,326,79.3,94.3
pink,very light magenta-pink,Very light greyish purple,#F5D3E6,245,211,230,326,63.0,89.4
pink,very light magenta-pink,Very light greyish purple,#FBCCE7,251,204,231,326,85.5,89.2
grey,very light pink,Light greyish pink,#E8CCD7,232,204,215,336,37.8,85.5
grey,very light pink,Light greyish pink,#EBCBD6,237,203,214,341,44.4,85.9
pink,very light pink,Light greyish pink,#FDE3F0,253,227,240,330,86.7,94.1
pink,very light pink,Light greyish pink,#F6C6D8,246,198,216,338,72.7,87.1
pink,very light pink,Light greyish pink,#FDDDE6,253,221,230,343,88.9,92.9
grey,light pink-red,Light greyish red,#DDBEC3,221,190,195,350,31.3,80.6
brown,light red,Light greyish red,#E2CACA,226,202,202,0,29.3,83.9
grey,light red,Light greyish red,#E5CCC9,229,204,201,6,35.0,84.3
grey,light red,Light greyish red,#E1C7C3,225,199,195,8,33.3,82.4
grey,very light red,Light greyish red,#F5E2DE,245,226,222,10,53.5,91.6
pink,very light pink-red,Very light pink-red,#FADADD,250,218,221,354,76.2,91.8
pink,very light pink-red,Very light pink-red,#F9C8CB,249,200,203,356,80.3,88.0
brown,very light red,Light greyish red,#EBDBDB,235,219,219,0,28.6,89.0
brown,very light red,Light greyish red,#eccfcf,236,207,207,0,43.3,86.9
grey,very light red,Light greyish red,#E4D3D2,228,211,210,3,25.0,85.9
grey,very light red,Light greyish red,#F4E9E8,244,233,232,5,35.3,93.3
grey,very light red,Light greyish red,#EBE1DF,235,225,223,10,23.1,89.8
pink,very light red,Very light pink-red,#FACCCA,249,204,202,3,82.8,88.6
purple,light blue-magenta,Light greyish violet,#D0C0E5,208,192,229,266,41.6,82.5
grey,light blue-magenta,Light greyish violet,#D5CFDE,213,207,222,264,18.5,84.1
purple,light blue-magenta,Light greyish violet,#CFB8DE,207,184,222,276,36.5,79.6
purple,light blue-magenta,Light greyish violet,#D6CADD,214,202,221,278,21.8,82.9
purple,light blue-magenta,Light greyish violet,#D4BEEB,228,190,235,291,52.9,83.3
grey,very light blue-magenta,Very light grey,#E7E4EF,231,228,255,247,25.6,91.6
purple,very light blue-magenta,Light greyish violet,#EBE3FC,235,227,252,259,80.6,93.9
purple,very light blue-magenta,Light greyish violet,#EBE4F4,235,228,244,266,42.1,92.5
grey,light yellow,Light greyish yellow,#ECEBBD,236,235,189,59,55.3,83.3
grey,light yellow,Light greyish yellow,#e8e4c9,232,228,201,52,40.3,84.9
grey,very light yellow,Very light greyish yellow,#EDEAE0,237,234,224,50,26.5,90.4
brown,very light yellow,White,#fefdfa,254,253,250,45,66.7,98.8
grey,very light yellow,Very light greyish yellow,#F0EAD6,240,234,214,46,46.4,89.0
grey,very light yellow,Very light greyish yellow,#F4EED7,244,238,215,48,56.9,90.0
grey,very light yellow,Very light greyish yellow,#f2f0e6,242,240,230,50,31.6,92.5
grey,very light yellow-green,Very light greyish yellow,#FAFAD2,250,250,210,60,80.0,90.2
white,very light yellow-green,White,#FEFEFA,254,254,250,60,66.7,98.8
white,very light yellow-green,Very light greyish yellow,#F5F5DC,245,245,220,60,55.6,91.2
green,medium light green,Light lime green,#66FF66,102,255,102,120,100.0,70.0
green,medium light green,Light lime green,#7FFF55,127,255,85,105,100.0,66.7
green,medium light green,Light lime green,#5cff67,92,255,103,124,100.0,68.0
purple,medium light magenta,Light magenta,#FF66FF,255,102,255,300,100.0,70.0
orange,medium light brown,Light orange,#FFAE42,255,174,66,34,100.0,62.9
orange,medium light red-orange,Light orange,#FF9966,255,153,102,20,100.0,70.0
yellow,medium light yellow,Medium light yellow,#ffce44,255,206,68,44,100.0,63.3
brown,medium light brown,Light orange,#FFA343,255,163,67,31,100.0,63.1
brown,medium light brown,Light orange,#ffb95a,255,185,90,34,100.0,67.6
brown,medium light brown,Light orange,#ffb347,255,179,71,35,100.0,63.9
brown,medium light brown,Light orange,#ffb94e,255,185,78,36,100.0,65.3
orange,medium light brown,Light orange,#ffc34d,255,195,77,39,100.0,65.1
orange,medium light orange,Light orange,#FF8243,255,130,67,20,100.0,63.1
orange,medium light orange,Light orange,#ffa565,255,165,101,24,100.0,69.8
orange,medium light orange,Light orange,#ff8936,255,137,54,24,100.0,60.6
orange,medium light red-orange,Light orange,#ff6d3a,255,109,58,15,100.0,61.4
orange,medium light red-orange,Light orange,#FF7F50,255,127,80,16,100.0,65.7
orange,medium light red-orange,Light orange,#FF7538,255,117,56,18,100.0,61.0
pink,medium light magenta,Light pink,#FF5CCD,255,92,205,318,100.0,68.0
pink,medium light magenta-pink,Light pink,#FF66CC,255,102,204,320,100.0,70.0
pink,medium light magenta-pink,Light pink,#FF64C5,255,100,197,322,100.0,69.6
pink,medium light magenta-pink,Light pink,#FF43A4,255,67,164,329,100.0,63.1
pink,medium light pink,Light pink,#FF55A3,255,85,163,332,100.0,66.7
pink,medium light pink,Light pink,#ff3988,255,57,136,336,100.0,61.2
pink,medium light pink,Light pink,#ff4681,255,70,129,340,100.0,63.7
pink,medium light pink-red,Light red,#FF355E,255,53,94,348,100.0,60.4
pink,medium light pink-red,Light red,#FF476C,255,73,108,348,100.0,63.9
pink,medium light pink-red,Light red,#ff496c,255,73,108,348,100.0,64.3
pink,medium light pink-red,Light red,#FF4466,255,68,102,349,100.0,63.3
pink,medium light pink-red,Light red,#FF5470,255,84,112,350,100.0,66.5
pink,medium light pink-red,Light red,#FF4E6A,255,78,106,351,100.0,65.3
pink,medium light pink-red,Light red,#FF3855,255,56,85,351,100.0,61.0
pink,medium light pink-red,Light red,#FF5771,255,87,113,351,100.0,67.1
red,medium light pink-red,Light red,#ff404c,255,64,76,356,100.0,62.5
orange,medium light red,Light red,#FF5349,255,83,73,3,100.0,64.3
orange,medium light red,Light red,#FF6347,255,99,71,9,100.0,63.9
orange,medium light red,Light red,#FF5A36,255,90,54,11,100.0,60.6
red,medium light red,Light red,#FF4040,255,64,64,0,100.0,62.5
red,medium light red,Light red,#FF3F34,255,63,52,3,100.0,60.2
red,medium light red,Light red,#ff6961,255,105,97,3,100.0,69.0
orange,medium light red-orange,Light red,#FF6037,255,96,55,12,100.0,60.8
orange,medium light red-orange,Light red,#FF6E4A,255,110,74,12,100.0,64.5
orange,medium light red-orange,Light red,#ff7952,255,121,82,13,100.0,66.1
purple,medium light blue-magenta,Light violet,#9966FF,153,102,255,260,100.0,70.0
yellow,medium light yellow-green,Light yellow,#FFFF66,255,255,102,60,100.0,70.0
yellow,medium light yellow,Medium light yellow,#FFDB58,255,219,88,47,100.0,67.3
yellow,medium light yellow,Medium light yellow,#ffdf46,255,223,70,49,100.0,63.7
yellow,medium light yellow,Medium light yellow,#ffe135,255,225,53,51,100.0,60.4
yellow,medium light yellow,Light yellow,#FFF44F,255,244,79,56,100.0,65.5
purple,medium dark blue-magenta,Medium dark blue-purple,#553592,85,53,146,260,46.7,39.0
purple,medium dark blue-magenta,Medium dark blue-purple,#58427C,88,66,124,263,30.5,37.3
purple,medium dark blue-magenta,Medium dark blue-purple,#4C2882,76,40,130,264,52.9,33.3
purple,medium dark blue-magenta,Medium dark blue-purple,#522d80,82,45,128,266,48.0,33.9
brown,medium dark brown,Medium dark brown,#81613C,129,97,60,32,36.5,37.1
brown,medium dark brown,Medium dark brown,#826644,130,102,68,33,31.3,38.8
brown,medium dark brown,Medium dark brown,#896c39,137,108,57,38,41.2,38.0
brown,medium dark orange,Medium dark brown,#8f583c,143,88,60,20,40.9,39.8
brown,medium dark orange,Medium dark brown,#84563c,132,86,60,21,37.5,37.6
brown,medium dark orange,Medium dark brown,#8c5939,140,89,57,23,42.1,38.6
brown,medium dark orange,Medium dark brown,#7d4e2d,125,78,45,24,47.1,33.3
brown,medium dark orange,Medium dark brown,#7f5d3b,127,93,59,29,36.6,36.5
brown,medium dark red-orange,medium dark brown,#824b35,130,75,53,17,42.1,35.9
brown,medium dark red-orange,Medium dark brown,#8c4736,140,71,54,11,44.3,38.0
green,green,Medium dark green,#4D8C57,77,140,87,130,29.0,42.5
green,medium dark green,Medium dark green,#2f7532,47,117,50,122,42.7,32.2
green,medium dark green,Medium dark green,#407a52,64,122,82,138,31.2,36.5
green,medium dark green,Medium dark green,#5b8930,91,137,48,91,48.1,36.3
green,medium dark green,Medium dark green,#507D2A,80,125,42,93,49.7,32.7
green,medium dark green,Medium dark green,#3C8043,60,128,67,126,36.2,36.9
green,medium dark green-cyan,Medium dark green,#0e7c61,14,124,97,165,79.7,27.1
green,medium dark green-cyan,Medium dark green,#009874,0,152,116,166,100.0,29.8
green,medium dark green-cyan,Medium dark green,#009975,0,153,117,166,100.0,30.0
green,medium dark green-cyan,Medium dark green,#14A989,20,169,137,167,78.8,37.1
green,medium dark green-cyan,Medium dark green,#009B7D,0,155,125,168,100.0,30.4
green,medium dark green-cyan,Medium dark green,#01826B,1,130,107,169,98.5,25.7
green,medium dark green-cyan,Medium dark green,#25937E,37,147,126,169,59.8,36.1
green,medium dark green-cyan,Medium dark green,#069B81,6,155,129,170,92.5,31.6
green,medium dark green-cyan,Medium dark green-cyan,#2E8B57,46,139,87,146,50.3,36.3
green,medium dark green-cyan,Medium dark green-cyan,#3B7A57,59,122,87,147,34.8,35.5
green,medium dark green-cyan,Medium dark green-cyan,#3B7861,59,120,97,157,34.1,35.1
green,medium dark green-cyan,Medium dark green-cyan,#40826D,64,130,109,161,34.0,38.0
green,medium dark green-cyan,Medium dark green-cyan,#319177,49,145,119,164,49.5,38.0
purple,medium dark pink,Medium dark pink,#843F5B,132,63,91,336,35.4,38.2
purple,medium dark pink,Medium dark pink,#993366,153,51,102,330,50.0,40.0
purple,medium dark pink,Medium dark pink,#892D52,137,45,82,336,50.5,35.7
purple,medium dark pink,Medium dark pink,#8E3A59,142,58,89,338,42.0,39.2
purple,medium dark pink,Medium dark pink,#7E314D,126,49,77,338,44.0,34.3
purple,medium dark blue-magenta,Medium dark purple,#663399,102,51,153,270,50.0,40.0
purple,medium dark magenta,Medium dark purple,#733380,115,51,128,290,43.0,35.1
purple,medium dark magenta,Medium dark purple,#843179,132,49,121,308,45.9,35.5
purple,medium dark magenta,Medium dark purple,#763568,118,53,104,312,38.0,33.5
purple,medium dark magenta,Medium dark purple,#8E3975,143,57,117,318,42.7,39.0
purple,medium dark magenta,Medium dark purple,#6C3082,108,48,130,284,46.1,34.9
purple,medium dark magenta-pink,Medium dark pink,#873260,135,50,96,328,45.9,36.3
purple,medium dark magenta-pink,Medium dark pink,#82305A,130,48,90,329,46.1,34.9
purple,medium dark pink,Medium dark pink,#763950,118,57,93,325,34.9,34.3
brown,medium dark red,Medium dark brown,#804040,128,64,64,0,33.3,37.6
brown,medium dark red,Medium dark brown,#733635,115,54,53,0,36.9,32.9
brown,medium dark red,Medium dark brown,#7B3636,123,54,54,0,39.0,34.7
brown,medium dark red,Medium dark brown,#7b3b3a,123,59,58,0,35.9,35.5
brown,medium dark red,Medium dark brown,#87413F,135,65,63,2,36.4,38.8
brown,medium dark red,Medium dark red,#8b352d,139,53,45,5,51.1,36.1
brown,medium dark red,Medium dark brown,#934337,147,67,55,7,45.5,39.6
brown,medium dark red,Medium dark brown,#79443B,121,68,59,9,34.4,35.3
brown,medium dark red,Medium dark brown,#954535,149,69,53,10,47.5,39.6
brown,medium dark yellow,Medium dark yellow,#8b7d3a,139,125,58,50,41.1,38.6
grey,medium dark yellow,Medium dark yellow,#807532,128,117,50,52,43.8,34.9
grey,medium dark yellow,Medium dark yellow,#867e36,134,126,54,54,42.6,36.9
green,medium dark yellow-green,Medium dark yellow-green,#7a942e,122,148,46,75,52.6,38.0
grey,medium dark yellow-green,Medium dark yellow-green,#7C7C40,124,124,64,60,31.9,36.9
brown,medium light brown,Medium light brown,#faa945,250,169,69,33,94.8,62.5
pink,medium light pink-red,Medium light pink-red,#fe4164,254,65,100,348,99.0,62.5
pink,medium light pink-red,Medium light pink-red,#FD3A4A,253,58,74,355,98.0,61.0
red,medium light red,Medium light pink-red,#FB4D46,251,77,70,2,95.8,62.9
orange,medium light red,Medium light red,#fd5240,253,82,64,5,97.9,62.2
orange,medium light red,Medium light red,#FA5B3D,250,91,61,10,95.0,61.0
blue,blue,Moderate blue,#5A7CC2,90,124,194,220,46.0,55.7
blue,blue,Moderate blue,#446CCF,68,108,207,223,59.1,53.9
blue,blue,Moderate blue,#5D76CB,93,118,203,226,51.4,58.0
blue,blue,Moderate blue,#4F69C6,79,105,198,227,51.1,54.3
purple,blue-magenta,Moderate blue-purple,#5A4FCF,90,79,207,245,57.1,56.1
purple,blue-magenta,Moderate blue-purple,#4F42B5,79,66,181,247,46.6,48.4
purple,blue-magenta,Moderate blue-purple,#6A5ACD,106,90,205,248,53.5,57.8
blue,cyan-blue,Moderate cyan-blue,#56A0D3,86,160,211,204,58.7,58.2
blue,cyan-blue,Moderate cyan-blue,#4997D0,73,151,208,205,59.0,55.1
blue,cyan-blue,Moderate cyan-blue,#4682B4,70,130,180,207,44.0,49.0
blue,cyan-blue,Moderate cyan-blue,#417DC1,72,145,206,207,50.8,50.6
blue,cyan-blue,Moderate cyan-blue,#357AB7,53,122,183,208,55.1,46.3
blue,cyan-blue,Moderate cyan-blue,#458AC6,69,138,198,208,53.1,52.4
blue,cyan-blue,Moderate cyan-blue,#4e82b4,78,130,180,209,40.5,50.6
blue,cyan-blue,Moderate cyan-blue,#4682bf,70,130,191,210,48.6,51.2
blue,cyan-blue,Moderate cyan-blue,#5D89BA,93,137,186,212,40.3,54.7
blue,medium light cyan-blue,Medium light cyan-blue,#6699CC,102,153,204,210,50.0,60.0
brown,brown,Moderate brown,#b07939,176,121,57,32,51.1,45.7
brown,orange,Moderate brown,#AF6E4D,175,110,77,20,38.9,49.4
brown,orange,Moderate brown,#ab6134,171,97,52,22,53.4,43.7
brown,orange,Moderate brown,#AE6938,174,105,56,25,51.3,45.1
brown,orange,Moderate brown,#A67B5B,166,123,91,26,29.6,50.4
brown,orange,Moderate brown,#aa6c39,170,108,57,27,49.8,44.5
brown,orange,Moderate brown,#a97142,169,113,66,27,43.8,46.1
brown,orange,Moderate brown,#9b7653,155,118,83,29,30.3,46.7
brown,orange,Moderate brown,#976638,151,102,56,29,45.9,40.6
blue,cyan,Moderate cyan,#4EA4BA,78,164,186,192,43.9,51.8
blue,cyan,Moderate cyan,#3AA1C1,58,161,193,194,53.8,49.2
blue,cyan,Moderate cyan,#47ABCC,71,171,204,195,56.6,53.9
cyan,cyan,Moderate cyan,#39D1C2,57,209,194,174,62.3,52.2
cyan,cyan,Moderate cyan,#5fc9bf,95,201,191,174,49.5,58.0
cyan,cyan,Moderate cyan,#43B3AE,67,179,174,177,45.5,48.2
cyan,cyan,Moderate cyan,#48D1CC,72,209,204,178,59.8,55.1
cyan,cyan,Moderate cyan,#30BFBF,48,191,191,180,59.8,46.9
cyan,cyan,Moderate cyan,#4bc7cf,75,199,207,183,57.9,55.3
cyan,cyan,Moderate cyan,#3aa8c1,58,168,193,191,53.8,49.2
green,green-cyan,Moderate cyan,#4cb7a5,76,183,165,169,42.6,50.8
green,green-cyan,Moderate green-cyan,#40C575,84,197,117,138,53.4,51.2
green,green-cyan,Moderate green-cyan,#50C878,80,200,120,140,52.2,54.9
green,green-cyan,Moderate green-cyan,#3CD070,60,208,112,141,61.2,52.5
green,green-cyan,Moderate green-cyan,#3CB371,60,179,113,147,49.8,46.9
green,green-cyan,Moderate green-cyan,#48BF91,72,191,145,157,48.2,51.6
green,green-cyan,Moderate green-cyan,#3EB489,62,180,137,158,48.8,47.5
green,green-cyan,Moderate green-cyan,#44d7a8,68,215,168,160,64.8,55.5
green,green-cyan,Moderate green-cyan,#30BA8F,40,180,143,164,59.0,45.9
cyan,medium light green-cyan,Medium light green-cyan,#66CDAA,102,205,170,160,50.7,60.2
green,green,Moderate green,#7dc242,125,194,66,92,51.2,51.0
green,green,Moderate green,#61B834,97,184,52,100,55.9,46.3
green,green,Moderate green,#66b447,102,180,71,102,43.4,49.2
green,green,Moderate lime green,#34b334,52,179,52,120,55.0,45.3
purple,magenta,Moderate purple,#BA55D3,186,85,211,288,58.9,58.0
purple,magenta,Moderate purple,#B634BB,182,52,187,298,56.5,46.9
purple,magenta,Moderate purple,#C154C1,193,84,193,300,46.8,54.3
purple,magenta,Moderate purple,#BD33A4,189,51,164,311,57.5,47.1
brown,brown,Moderate brown,#bb8141,187,129,65,31,48.4,49.4
brown,brown,Moderate brown,#bb9351,187,147,81,37,43.8,52.5
brown,brown,Moderate brown,#C39953,195,153,83,38,48.3,54.5
brown,medium light orange,Moderate brown,#cc9966,204,153,102,29,50.0,60.0
brown,medium light brown,Medium light brown,#D2A560,210,165,96,36,55.9,60.0
brown,orange,Brown,#C08D5E,192,58,21,13,43.8,56.1
brown,orange,Brown,#BF6935,191,105,53,23,56.6,47.8
brown,orange,Orange brown,#D68A59,214,138,89,24,60.4,59.4
brown,orange,Brown,#be7f51,190,127,81,25,45.6,53.1
brown,orange,Brown,#ba8759,186,135,89,28,41.3,53.9
brown,orange,Brown,#B87333,184,115,51,29,56.6,46.1
brown,orange,Brown,#CD853F,205,133,63,30,58.7,52.5
brown,yellow,Yellow brown,#CBA135,203,161,53,43,59.1,50.2
pink,magenta,Purple-pink,#bd559c,189,85,156,319,44.1,53.7
pink,magenta-pink,Purple-pink,#B53389,181,51,137,320,56.0,45.5
pink,magenta-pink,Purple-pink,#d3419d,211,65,157,322,62.4,54.1
pink,magenta-pink,Purple-pink,#C65EA0,198,94,160,322,47.7,57.3
pink,magenta-pink,Purple-pink,#C0448F,192,68,143,324,49.6,51.0
pink,magenta-pink,Purple-pink,#C24C92,194,76,146,324,49.2,52.9
pink,magenta-pink,Purple-pink,#D74894,215,72,148,328,64.1,56.3
pink,magenta-pink,Purple-pink,#C54B8C,197,75,140,328,51.3,53.3
pink,magenta-pink,Purple-pink,#C7458B,199,69,139,328,53.7,52.5
pink,magenta-pink,Purple-pink,#C84186,200,65,134,329,55.1,52.0
purple,magenta-pink,Purple-pink,#C8509B,200,80,155,323,52.2,54.9
purple,magenta-pink,Purple-pink,#BB3385,187,51,133,324,57.1,46.7
purple,magenta-pink,Purple-pink,#B33A7F,179,58,127,326,51.1,46.5
purple,magenta-pink,Purple-pink,#B55489,181,84,137,327,39.6,52.0
pink,pink,Moderate pink,#B6316C,182,49,108,333,57.6,45.3
pink,pink,Moderate pink,#CC397B,204,57,123,333,59.0,51.2
pink,pink,Moderate pink,#CF3476,207,52,118,334,61.8,50.8
pink,pink,Moderate pink,#D0417E,208,65,126,334,60.3,53.5
pink,pink,Moderate pink,#C74375,199,67,117,337,54.1,52.2
pink,pink,Moderate pink,#CC3A71,204,58,113,337,58.9,51.4
pink,pink,Moderate pink,#D65282,214,82,130,338,61.7,58.0
pink,pink,Moderate pink,#BB466F,187,70,111,339,46.2,50.4
pink,pink,Moderate pink,#CE4676,206,70,118,339,58.1,54.1
pink,pink,Moderate pink,#BE3262,190,50,98,339,58.3,47.1
pink,pink,Moderate pink,#B44668,180,70,104,341,44.0,49.0
pink,pink,Moderate pink,#CD607E,205,96,126,343,52.2,59.0
pink,pink,Moderate pink,#B63157,182,49,87,343,57.6,45.3
purple,pink,Moderate pink,#B3446C,179,68,108,338,44.9,48.4
brown,medium light red,Medium light red,#CC6666,204,102,102,0,50.0,60.0
brown,pink-red,Moderate red,#BC3F4A,188,63,74,355,49.8,49.2
brown,pink-red,Moderate red,#BF4F51,191,79,81,359,46.7,52.9
orange,pink-red,Moderate red,#CC474B,204,71,75,358,56.6,53.9
orange,pink-red,Moderate red,#d73b3e,215,59,62,358,66.1,53.7
pink,pink-red,Moderate red,#cc4e5c,204,78,92,353,55.3,55.3
red,pink-red,Moderate red,#c93756,201,55,86,347,57.5,50.2
red,pink-red,Moderate red,#BE4F62,190,79,98,350,46.1,52.7
red,pink-red,Moderate red,#CB4154,203,65,84,352,57.0,52.5
red,pink-red,Moderate red,#c83f49,200,63,73,355,55.5,51.6
brown,red,Moderate red,#CC5555,204,85,85,0,53.8,56.7
brown,red,Moderate red,#b95754,185,87,84,1,41.9,52.7
brown,red,Moderate red,#B94E48,185,78,72,3,44.7,50.4
brown,red,Moderate red,#b56257,181,98,87,7,38.8,52.5
brown,red,Moderate red,#C95A49,201,90,73,8,54.2,53.7
brown,red,Moderate red,#D34E36,211,78,54,9,64.1,52.0
brown,red,Moderate red,#CD5B45,205,91,69,10,57.6,53.7
brown,red,Moderate red,#C45655,196,86,55,13,48.5,55.1
brown,red,Moderate red,#CC4E3C,204,78,92,353,58.5,51.8
red,red,Moderate red,#CD5C5C,205,92,92,0,53.1,58.2
brown,red-orange,Red-orange,#b35c44,179,92,68,12,44.9,48.4
brown,red-orange,Red-orange,#BC5235,188,82,53,13,56.0,47.3
brown,red-orange,Red-orange,#cb6649,203,102,73,13,55.6,54.1
brown,red-orange,Red-orange,#CB6D51,203,109,81,14,54.0,55.7
brown,red-orange,Red-orange,#C86D51,203,109,81,14,52.0,55.1
purple,magenta,Moderate violet,#9955BB,153,85,187,280,42.9,53.3
purple,magenta,Moderate violet,#9C51B6,156,81,182,285,40.9,51.6
purple,medium light blue-magenta,Moderate violet,#9966CC,153,102,204,270,50.0,60.0
purple,medium light magenta,Moderate violet,#B666D2,182,102,210,284,54.5,61.2
green,medium light yellow-green,Medium light yellow-green,#CBD862,205,216,98,66,60.2,61.6
brown,yellow,Moderate yellow,#C9AE5D,201,174,93,45,50.0,57.6
grey,yellow,Moderate yellow,#b5a642,181,166,66,52,46.6,48.4
grey,yellow,Moderate yellow,#C9B93B,201,185,59,53,56.8,51.0
grey,yellow,Moderate yellow,#B8B654,184,182,84,59,41.3,52.5
yellow,yellow,Moderate yellow,#D3AF37,211,175,55,46,63.9,52.2
yellow,yellow,Moderate yellow,#D4AF37,212,175,55,46,64.6,52.4
yellow,yellow,Moderate yellow,#CFB53B,207,181,59,49,60.7,52.2
yellow,yellow,Moderate yellow,#C5B358,197,179,88,50,48.4,55.9
green,yellow-green,Moderate yellow-green,#B0BC4A,176,188,74,66,46.0,51.4
green,yellow-green,Moderate yellow-green,#b0c24a,176,194,74,69,49.6,52.5
green,yellow-green,Moderate yellow-green,#BDD741,189,215,65,70,65.2,54.9
green,yellow-green,Moderate yellow-green,#A4C639,164,198,57,74,55.3,50.0
blue,blue,Greyish dark blue,#536895,83,104,149,220,28.4,45.5
blue,blue,Greyish dark blue,#4E5180,78,81,128,236,24.3,40.4
grey,blue-magenta,Greyish dark blue-purple,#666699,102,102,153,240,20.0,50.0
purple,blue-magenta,Greyish dark blue-purple,#7573A6,117,115,166,242,22.3,55.1
blue,cyan-blue,Greyish dark cyan-blue,#5D8AA8,93,138,168,204,30.1,51.2
blue,cyan-blue,Greyish dark cyan-blue,#7c98ab,124,152,171,204,21.9,57.8
grey,cyan-blue,Greyish dark cyan-blue,#778BA5,119,139,165,214,20.4,55.7
grey,medium dark cyan-blue,Dark bluish grey,#536878,83,104,120,206,18.2,39.8
blue,cyan,Greyish dark cyan,#68a0b0,104,160,176,193,31.3,54.9
cyan,cyan,Greyish dark cyan,#669999,102,153,153,180,20.0,50.0
cyan,cyan,Greyish dark cyan,#5F9EA0,95,158,160,182,25.5,50.0
grey,cyan,Greyish dark cyan,#5F8A8B,95,138,139,181,18.8,45.9
green,green-cyan,Greyish dark cyan,#5DA493,93,164,147,166,28.1,50.4
green,green-cyan,Greyish dark cyan,#6EAEA1,119,174,161,166,28.3,55.7
green,green-cyan,Greyish dark cyan,#56887D,86,136,125,167,22.5,43.5
green,green-cyan,Greyish dark cyan,#639A8F,99,154,143,168,21.7,49.6
green,green,Greyish dark green,#6d9a79,109,154,121,136,18.2,51.6
green,green-cyan,Greyish dark green-cyan,#5FA777,95,167,119,140,29.0,51.4
green,green-cyan,Greyish dark green-cyan,#5FA778,95,167,120,141,29.0,51.4
green,green-cyan,Greyish dark green-cyan,#749f8d,116,159,141,154,18.3,53.9
green,green-cyan,Greyish dark green-cyan,#7CB0A1,124,176,161,163,24.8,58.8
green,medium dark green-cyan,Dark greyish green-cyan,#49796B,73,121,107,163,24.7,38.0
green,green,Greyish dark green,#87A96B,135,169,107,93,26.5,54.1
green,yellow-green,Greyish dark yellow-green,#8A9A5B,138,154,191,222,25.7,48.0
grey,yellow-green,Greyish dark yellow-green,#8c9e5e,140,158,94,76,25.4,49.4
green,green,Greyish dark lime green,#6b9362,107,147,98,108,20.0,48.0
green,green,Greyish dark lime green,#679267,103,146,103,120,17.3,48.8
purple,magenta,Greyish dark purple,#8F5E99,143,94,153,290,23.9,48.4
purple,magenta,Greyish dark purple,#86608E,134,96,142,290,19.3,46.7
purple,magenta,Greyish dark purple,#976e9a,151,110,154,295,17.9,51.8
purple,magenta,Greyish dark purple,#856088,133,96,136,296,17.2,45.5
purple,magenta,Greyish dark purple,#8d608c,141,96,140,301,19.0,46.5
purple,magenta,Greyish dark purple,#8D4E85,141,78,133,308,28.8,42.9
purple,magenta,Greyish dark purple,#a87ca0,168,124,160,310,20.2,57.3
purple,magenta,Greyish dark purple,#B163A3,177,99,163,311,33.3,54.1
brown,brown,Grey brown,#856D4D,133,109,77,34,26.7,41.2
brown,brown,Grey brown,#A98F64,169,143,100,37,28.6,52.7
brown,brown,Grey brown,#8C7853,140,120,83,39,25.6,43.7
brown,brown,Grey brown,#987654,152,118,54,39,28.8,46.3
grey,brown,Grey brown,#8A795D,138,121,93,37,19.5,45.3
grey,brown,Grey brown,#837050,131,112,80,38,24.2,41.4
brown,medium dark orange,Medium dark greyish brown,#785e49,120,94,73,26,24.4,37.8
brown,medium light orange,Medium light greyish brown,#B29784,178,151,132,25,23.0,60.8
brown,orange,Greyish dark brown,#926F5B,146,111,91,22,23.2,46.5
brown,orange,Greyish dark brown,#9F8170,159,129,112,22,19.7,53.1
brown,orange,Greyish dark brown,#88654e,136,101,78,23,27.1,42.0
brown,orange,Greyish dark brown,#a0785a,160,120,90,25,28.0,49.0
brown,orange,Greyish dark brown,#b0927a,176,146,122,26,25.5,58.4
brown,orange,Greyish dark brown,#836953,131,105,83,27,22.4,42.0
brown,orange,Greyish dark brown,#987456,152,116,86,27,27.7,46.7
brown,orange,Greyish dark brown,#826b58,130,107,88,27,19.3,42.7
grey,orange,Greyish dark brown,#7f6b5d,127,107,93,24,15.5,43.1
brown,red-orange,Greyish brown,#A87C6D,168,124,109,15,25.3,54.3
brown,red-orange,Greyish brown,#8b5f4d,139,95,77,17,28.7,42.4
brown,red-orange,Greyish brown,#9F7462,159,116,98,18,24.1,50.4
grey,red-orange,Greyish brown,#906652,144,102,82,19,27.4,44.3
grey,yellow,Grey yellow,#85754E,133,117,78,43,26.1,41.4
purple,magenta,Greyish purple,#915C83,145,92,131,316,22.4,46.5
brown,pink,Greyish dark pink,#9E5E6F,158,94,111,344,25.4,49.4
grey,pink,Greyish dark pink,#976F7B,151,111,123,342,16.1,51.4
purple,pink,Greyish dark pink,#99637B,153,99,123,333,21.4,49.4
purple,pink,Greyish dark pink,#A65E7E,166,94,126,333,28.8,51.0
purple,pink,Greyish dark pink,#915F6D,145,95,109,343,20.8,47.1
grey,medium dark pink-red,Greyish dark purple,#755258,117,77,82,353,17.6,39.0
brown,medium dark red,Greyish dark red,#7C4848,124,72,72,0,26.5,38.4
brown,pink-red,Greyish dark pink-red,#8E616A,142,97,106,348,18.8,46.9
grey,pink-red,Greyish dark pink-red,#7E5E60,126,94,96,356,14.5,43.1
brown,red,Dark greyish brown,#905D5D,144,93,93,0,21.5,46.5
brown,red,Dark greyish brown,#956666,153,102,102,0,18.7,49.2
brown,red,Dark greyish brown,#996666,149,102,102,0,20.0,50.0
brown,red,Dark greyish brown,#AC8181,172,129,129,0,20.6,59.0
brown,red,Dark greyish brown,#AD6F69,173,111,105,5,29.3,54.5
brown,red,Dark greyish brown,#A17A74,161,122,116,8,19.3,54.3
brown,red,Dark greyish brown,#97645a,151,100,90,9,25.3,47.3
brown,red,Dark greyish brown,#986960,152,105,96,10,22.6,48.6
brown,red,Dark greyish brown,#AA786D,170,120,109,11,26.4,54.7
brown,red-orange,Dark greyish brown,#865E55,134,94,85,11,22.4,42.9
brown,red-orange,Dark greyish brown,#A57164,165,113,100,12,26.5,52.0
grey,red-orange,Dark greyish brown,#A18178,161,129,120,13,17.9,55.1
purple,blue-magenta,Greyish dark violet,#89729e,137,114,158,271,18.5,53.3
purple,blue-magenta,Greyish dark violet,#926EAE,146,110,174,274,28.3,55.7
purple,magenta,Greyish dark violet,#875f9a,135,95,154,280,23.7,48.8
grey,medium dark blue-magenta,Dark greyish blue-purple,#5a4f74,90,79,116,257,19.0,38.2
grey,yellow,Greyish dark yellow,#918151,145,129,81,45,28.3,44.3
grey,yellow,Greyish dark yellow,#857c55,133,124,85,48,22.0,42.7
brown,yellow,Orange yellow,#e5b73b,229,183,59,43,76.6,56.5
brown,yellow,Orange yellow,#e3b130,227,177,48,43,76.2,53.9
yellow,yellow,Orange yellow,#e2b13c,226,177,60,42,74.1,56.1
yellow,yellow,Orange yellow,#f3c13a,243,193,58,43,88.5,59.0
yellow,yellow,Orange yellow,#F1B82D,241,184,45,43,87.5,56.1
blue,light cyan,Pale blue,#a0e6ff,160,230,255,195,100.0,81.4
blue,light cyan,Pale blue,#a6e7ff,166,231,255,196,100.0,82.5
blue,light cyan-blue,Pale blue,#9BDDFF,155,221,255,200,100.0,80.4
cyan,light cyan,Pale cyan,#B2FFFF,178,255,255,180,100.0,84.9
blue,very light cyan,Pale cyan,#b9f2ff,185,242,255,191,100.0,86.3
purple,very light magenta,Pale magenta,#F4BBFF,249,192,255,294,100.0,86.7
brown,light brown,Pale orange,#FFD9B2,255,217,178,30,100.0,84.9
brown,light brown,Pale orange,#ffd59a,255,213,154,35,100.0,80.2
brown,light brown,Pale orange,#FFDEAD,255,222,173,36,100.0,83.9
orange,light orange,Pale orange,#FFCBA4,255,203,164,26,100.0,82.2
brown,light red-orange,Pale orange,#FFB79B,255,185,123,28,100.0,80.4
brown,very light brown,Pale orange,#FFE5B4,255,229,180,39,100.0,85.3
brown,very light brown,Pale orange,#ffdfbf,255,223,191,30,100.0,87.5
brown,very light brown,Pale orange,#FFE4B5,255,228,181,38,100.0,85.5
brown,very light orange,Pale orange,#FFDAB9,255,218,185,28,100.0,86.3
pink,light pink,Pale pink,#FFA6C9,246,166,201,334,100.0,82.5
brown,light magenta-pink,Pale pink,#FF9EDA,255,158,218,323,100.0,81.0
pink,light pink,Pale pink,#FFAFC8,255,175,200,341,100.0,84.3
pink,very light magenta-pink,Pale pink,#FFB3DE,255,179,222,326,100.0,85.1
pink,very light pink,Pale pink,#FFBCD9,255,188,217,334,100.0,86.9
pink,very light pink,Pale pink,#FFB7D5,255,183,213,335,100.0,85.9
pink,very light pink-red,Pale red,#FFB7C5,255,183,197,348,100.0,85.9
pink,very light pink-red,Pale red,#FFB6C1,255,182,193,351,100.0,85.7
pink,light red,Pale red-pink,#ffb3a7,255,179,167,8,100.0,82.7
purple,light blue-magenta,Pale violet,#E0B0FF,224,176,255,276,100.0,84.5
yellow,light yellow-green,Pale yellow,#FFFF9F,255,255,159,60,100.0,81.2
yellow,light yellow-green,Pale yellow,#FCFFA4,252,255,164,62,100.0,82.2
yellow,very light yellow-green,Very pale yellow,#ffffbf,255,255,191,60,100.0,87.5
pink,pink-red,Pink-red,#F03865,240,56,101,345,86.0,58.0
pink,pink-red,Pink-red,#E63E62,230,62,98,347,77.1,57.3
pink,pink-red,Pink-red,#ea3c53,234,60,83,352,80.6,57.6
pink,pink-red,Pink-red,#DA2C43,218,44,67,352,70.2,51.4
pink,pink-red,Pink-red,#ED2939,237,41,57,355,84.5,54.5
pink,pink-red,Pink-red,#E53D43,229,61,67,358,76.4,56.9
blue,Blue-magenta,Blue-violet,#0000FF,0,0,255,240,100.0,50.0
blue,blue-magenta,Blue-violet,#3F00FF,63,0,255,255,100.0,50.0
blue,cyan,Blue,#00BFFF,0,191,255,195,100.0,50.0
blue,cyan,Blue,#00B9FB,0,185,251,196,100.0,49.2
blue,cyan,Blue,#00aaee,0,170,238,197,100.0,46.7
blue,cyan,Blue,#00a2ed,0,162,237,198,100.0,46.5
blue,cyan-blue,Blue,#0088dc,0,136,220,202,100.0,43.1
blue,cyan-blue,Blue,#007FFF,0,127,255,210,100.0,50.0
blue,cyan-blue,Blue,#0070FF,0,112,255,214,100.0,50.0
blue,cyan-blue,Blue,#0066FF,0,102,255,216,100.0,50.0
blue,cyan,Cyan,#00c3e3,0,195,227,188,100.0,44.5
blue,cyan,Cyan,#00B6D9,0,182,217,190,100.0,42.5
blue,cyan,Cyan,#00CCFF,0,204,255,192,100.0,50.0
cyan,cyan,Cyan,#00FFEF,0,255,239,176,100.0,50.0
cyan,cyan,Cyan,#00FFFF,0,255,255,180,100.0,50.0
cyan,cyan,Cyan,#00DDDD,0,221,221,180,100.0,43.3
cyan,cyan,Cyan,#00DED1,0,206,209,181,100.0,43.5
cyan,cyan,Cyan,#00B7EB,0,180,247,196,100.0,46.1
cyan,green-cyan,Cyan,#00FFCD,0,255,205,168,100.0,50.0
green,green,Lime-green,#00FF40,0,255,64,135,100.0,50.0
cyan,green-cyan,Green-cyan,#00dea4,0,222,164,164,100.0,43.5
green,green-cyan,Green-cyan,#00FF7F,0,255,127,150,100.0,50.0
green,green-cyan,Green-cyan,#00FA9A,0,250,154,157,100.0,49.0
green,green-cyan,Green-cyan,#00E39A,0,227,154,161,100.0,44.5
green,green,Green,#A7FC00,167,252,0,80,100.0,49.4
green,green,Green,#96ff00,150,255,0,84,100.0,50.0
green,green,Green,#7FFF00,127,255,0,90,100.0,50.0
green,green,Green,#7CFC00,124,252,0,90,100.0,49.4
green,green,Green,#65ff00,101,255,0,96,100.0,50.0
green,green,Green,#66FF00,102,255,0,96,100.0,50.0
green,green,Green,#4aff00,74,255,0,102,100.0,50.0
green,green,Green,#3AE500,58,229,0,105,100.0,44.9
green,yellow-green,Green,#BFFF00,191,255,0,75,100.0,50.0
green,green,Lime-green,#3FFF00,63,255,0,105,100.0,50.0
green,green,Lime-green,#00FF00,0,255,0,120,100.0,50.0
green,green,Lime-green,#00FF3F,0,255,63,135,100.0,50.0
pink,magenta,Purple,#FF00FF,255,0,255,300,100.0,50.0
pink,magenta,Purple,#FF00CC,255,0,204,312,100.0,50.0
purple,magenta,Purple,#C400FF,191,0,255,285,100.0,50.0
purple,magenta,Purple,#CC00FF,204,0,255,288,100.0,50.0
purple,magenta,Purple,#CB00F5,203,0,245,290,100.0,48.0
purple,magenta,Purple,#DD00FF,221,0,255,292,100.0,50.0
purple,magenta,Purple,#DF00FF,223,0,255,292,100.0,50.0
brown,brown,Brown,#E48400,228,132,0,35,100.0,44.7
brown,brown,Brown,#DA9100,218,145,0,40,100.0,42.7
orange,brown,Orange,#FF8100,255,129,0,30,100.0,50.0
orange,brown,Orange,#f77f00,247,127,0,30,100.0,48.4
orange,brown,Orange,#ff8b00,255,139,0,32,100.0,50.0
orange,brown,Orange,#F28500,243,132,0,33,100.0,47.5
orange,brown,Orange,#FF8C00,255,140,0,33,100.0,50.0
orange,brown,Orange,#ff9a00,255,154,0,36,100.0,50.0
orange,brown,Orange,#ff9900,255,153,0,36,100.0,50.0
orange,brown,Orange,#FF9F00,255,159,0,37,100.0,50.0
orange,brown,Orange,#ffa400,255,164,0,38,100.0,50.0
orange,brown,Orange,#FFA000,255,160,0,38,100.0,50.0
orange,brown,Orange,#FFA500,255,165,0,39,100.0,50.0
orange,brown,Orange,#ffa600,255,166,0,39,100.0,50.0
orange,brown,Orange,#FFA700,255,167,0,39,100.0,50.0
orange,orange,Orange,#ff5500,255,85,0,19,100.0,50.0
orange,orange,Orange,#fd5800,253,88,0,20,100.0,49.6
orange,orange,Orange,#FF5800,255,88,0,21,100.0,50.0
orange,orange,Orange,#ff5b00,255,91,0,21,100.0,50.0
orange,orange,Orange,#EC5800,236,88,0,22,100.0,46.3
orange,orange,Orange,#ff5f00,255,95,0,22,100.0,50.0
orange,orange,Orange,#FF6600,255,102,0,24,100.0,50.0
orange,orange,Orange,#FF6700,255,103,0,24,100.0,50.0
orange,orange,Orange,#E86100,232,97,0,25,100.0,45.5
orange,orange,Orange,#ff7300,255,115,0,27,100.0,50.0
orange,orange,Orange,#FF7700,255,119,0,28,100.0,50.0
orange,orange,Orange,#FF7800,255,120,0,28,100.0,50.0
orange,orange,Orange,#FF7A00,255,122,0,29,100.0,50.0
orange,orange,Orange,#FF7E00,255,126,0,30,100.0,50.0
orange,orange,Orange,#FF7F00,255,127,0,30,100.0,50.0
orange,red-orange,Red-orange,#FF4F00,255,79,0,19,100.0,50.0
orange,red-orange,Red-orange,#F94D00,249,77,0,19,100.0,48.8
red,red-orange,Red-orange,#ff4200,255,66,0,15,100.0,50.0
red,red-orange,Red-orange,#FF4500,255,69,0,16,100.0,50.0
red,red-orange,Red-orange,#fd4900,253,73,0,17,100.0,49.6
orange,yellow,Yellow,#ffb300,255,179,0,42,100.0,50.0
orange,yellow,Yellow,#FFB200,255,178,0,42,100.0,50.0
orange,yellow,Yellow,#fdb900,253,185,0,43,100.0,49.6
orange,yellow,Yellow,#FFBF00,255,191,0,45,100.0,50.0
yellow,yellow,Yellow,#f2b400,242,180,0,44,100.0,47.5
yellow,yellow,Yellow,#FFBA00,255,186,0,44,100.0,50.0
pink,magenta,Pink,#FF00AF,255,0,175,319,100.0,50.0
pink,magenta-pink,Pink,#F400A1,244,0,161,320,100.0,47.8
pink,magenta-pink,Pink,#FF009F,255,0,159,323,100.0,50.0
pink,magenta-pink,Pink,#FF0090,255,0,144,326,100.0,50.0
pink,magenta-pink,Pink,#FF008F,255,0,143,326,100.0,50.0
pink,magenta-pink,Pink,#E4007C,228,0,124,327,100.0,44.7
pink,magenta-pink,Pink,#E40078,228,0,120,328,100.0,44.7
pink,magenta-pink,Pink,#FB0081,251,0,129,329,100.0,49.2
pink,pink,Pink-red,#FF007F,255,0,127,330,100.0,50.0
pink,pink,Pink-red,#FF007C,255,0,124,331,100.0,50.0
pink,pink,Pink-red,#ff006c,255,0,108,334,100.0,50.0
red,pink,Pink-red,#E30052,227,0,82,338,100.0,44.5
red,pink,Pink-red,#D9004C,217,0,76,339,100.0,42.5
red,pink,Pink-red,#FF0057,255,0,87,340,100.0,50.0
red,pink,Pink-red,#FF004F,255,0,79,341,100.0,50.0
red,pink,Pink-red,#FF0047,255,0,71,343,100.0,50.0
red,pink,Pink-red,#EB003C,235,0,60,345,100.0,46.1
pink,pink-red,Red,#ff0028,255,0,40,350,100.0,50.0
red,pink-red,Red,#FF003F,255,0,63,345,100.0,50.0
red,pink-red,Red,#F2003C,242,0,60,345,100.0,47.5
red,pink-red,Red,#FF0038,255,0,56,347,100.0,50.0
red,pink-red,Red,#E60026,230,0,38,350,100.0,45.1
red,pink-red,Red,#E30022,227,0,34,351,100.0,44.5
red,pink-red,Red,#e8000d,232,0,13,356,100.0,45.5
red,pink-red,Red,#e4000f,228,0,15,356,100.0,44.7
red,red,Red,#e60000,230,0,0,0,100.0,45.1
red,red,Red,#E00000,255,0,0,0,100.0,43.9
red,red,Red,#FF0000,255,0,0,0,100.0,50.0
red,red,Red,#FF0800,255,8,0,2,100.0,50.0
red,red,Red,#FF2400,255,36,0,8,100.0,50.0
red,red,Red,#ff2800,255,40,0,9,100.0,50.0
red,red-orange,Red-orange,#FF3800,255,56,0,13,100.0,50.0
red,red-orange,Red-orange,#FF3F00,255,63,0,15,100.0,50.0
purple,blue-magenta,Violet,#5F00FF,95,0,255,262,100.0,50.0
purple,blue-magenta,Violet,#6700FF,103,0,255,264,100.0,50.0
purple,blue-magenta,Violet,#6600FF,102,0,255,264,100.0,50.0
purple,blue-magenta,Violet,#6F00FF,111,0,255,266,100.0,50.0
purple,blue-magenta,Violet,#7700FF,119,0,255,268,100.0,50.0
purple,blue-magenta,Blue-purple,#7F00FF,127,0,255,270,100.0,50.0
purple,blue-magenta,Blue-purple,#8B00FF,139,0,255,273,100.0,50.0
purple,blue-magenta,Purple,#8F00FF,143,0,255,274,100.0,50.0
purple,blue-magenta,Purple,#9F00FF,159,0,255,277,100.0,50.0
purple,magenta,Purple,#AA00FF,170,0,255,280,100.0,50.0
purple,magenta,Purple,#AF00FF,175,0,255,281,100.0,50.0
purple,magenta,Purple,#BF00FF,191,0,255,285,100.0,50.0
yellow,yellow,Yellow,#FCC200,252,194,0,46,100.0,49.4
yellow,yellow,Yellow,#fecb00,254,203,0,47,100.0,49.8
yellow,yellow,Yellow,#FFCC00,255,204,0,48,100.0,50.0
yellow,yellow,Yellow,#FFD300,255,211,0,50,100.0,50.0
yellow,yellow,Yellow,#FFD700,255,215,0,51,100.0,50.0
yellow,yellow,Yellow,#EFCC00,239,204,0,51,100.0,46.9
yellow,yellow,Yellow,#FFD800,255,216,0,51,100.0,50.0
yellow,yellow,Yellow,#FFDB00,255,219,0,52,100.0,50.0
yellow,yellow,Yellow,#FFDF00,255,223,0,52,100.0,50.0
yellow,yellow,Yellow,#FEDF00,254,223,0,53,100.0,49.8
yellow,yellow,Yellow,#FEE600,254,230,0,54,100.0,49.8
yellow,yellow,Yellow,#FFEB00,255,235,0,55,100.0,50.0
yellow,yellow,Yellow,#FDEE00,253,238,0,56,100.0,49.6
yellow,yellow,Yellow,#FFEF00,255,239,0,56,100.0,50.0
yellow,yellow,Yellow,#fff000,255,240,0,56,100.0,50.0
yellow,yellow,Yellow,#e6e200,230,226,0,58,100.0,45.1
yellow,yellow,Yellow,#FFF600,255,246,0,58,100.0,50.0
yellow,yellow,Yellow,#eee600,238,230,0,58,100.0,46.7
yellow,yellow,Yellow,#FFF700,255,247,0,58,100.0,50.0
green,yellow-green,Yellow-green,#E3FF00,227,255,0,67,100.0,50.0
green,yellow-green,Yellow-green,#DFFF00,223,255,0,68,100.0,50.0
green,yellow-green,Yellow-green,#CCFF00,204,255,0,72,100.0,50.0
green,yellow-green,Yellow-green,#CEFF00,206,255,0,72,100.0,50.0
green,yellow-green,Yellow-green,#C7FF00,199,255,0,73,100.0,50.0
yellow,yellow-green,Bright yellow,#FFFF00,255,255,0,60,100.0,50.0
yellow,yellow-green,Bright yellow,#FDFF00,253,255,0,60,100.0,50.0
brown,red-orange,Red-orange,#e35c38,227,92,56,12,75.3,55.5
brown,red-orange,Red-orange,#D9603B,217,96,59,14,67.5,54.1
blue,blue,Greyish blue,#6576B4,101,118,180,227,34.5,55.1
purple,blue-magenta,Greyish blue,#746CC0,116,108,192,246,40.0,58.8
purple,blue-magenta,Greyish blue,#7366BD,115,102,189,249,39.7,57.1
purple,blue-magenta,Greyish blue,#7E73B8,126,115,184,250,32.7,58.6
blue,cyan-blue,Greyish blue,#6D9BC3,109,155,195,208,41.7,59.6
blue,cyan-blue,Greyish blue,#6082B6,96,130,182,216,37.1,54.5
blue,medium light blue,Medium greyish blue,#8A9CC4,138,156,196,221,33.0,65.5
blue,medium light blue,Medium greyish blue,#92a1cf,146,161,207,225,38.9,69.2
blue,medium light blue,Medium greyish blue,#7A83BF,122,131,191,232,35.0,61.4
purple,medium light blue-magenta,Medium greyish purple,#766EC8,118,110,200,246,45.0,60.8
purple,medium light blue-magenta,Medium greyish purple,#7F76D3,127,118,211,246,51.4,64.5
purple,medium light blue-magenta,Medium greyish purple,#8878C3,136,120,195,253,38.5,61.8
purple,medium light blue-magenta,Medium greyish purple,#9F91CF,159,145,207,254,39.2,69.0
purple,medium light blue-magenta,Medium greyish purple,#8C82B6,140,52,182,281,26.3,61.2
blue,medium light cyan,Medium greyish cyan,#6ab2ca,106,178,202,195,47.5,60.4
blue,medium light cyan,Medium greyish cyan,#73A9C2,115,169,194,199,39.3,60.6
blue,medium light cyan,Medium greyish cyan,#8CBED6,140,190,214,199,47.4,69.4
blue,medium light cyan-blue,Medium greyish cyan,#72A0C1,114,160,193,205,38.9,60.2
blue,medium light cyan-blue,Medium greyish cyan,#70A3CC,112,163,204,207,47.4,62.0
blue,medium light cyan-blue,Medium greyish cyan,#71A6D2,113,166,210,207,51.9,63.3
blue,medium light cyan-blue,Medium greyish cyan,#9EB9D4,158,185,212,210,38.6,72.5
blue,medium light cyan-blue,Medium greyish cyan,#779ecb,119,158,203,212,44.7,63.1
blue,medium light cyan-blue,Medium greyish cyan,#98B4D4,152,180,212,212,41.1,71.4
cyan,medium light cyan,Greyish cyan,#81D8D0,129,216,208,174,52.7,67.6
green,green-cyan,Greyish green-cyan,#66c992,102,201,146,146,47.8,59.4
green,medium light green-cyan,Medium greyish green-cyan,#80c197,128,193,151,141,34.4,62.9
green,medium light green-cyan,Medium greyish green-cyan,#A0D6B4,160,214,180,142,39.7,73.3
green,medium light green-cyan,Medium greyish green-cyan,#88d8c0,136,216,192,162,50.6,69.0
green,green,Greyish green,#9AB973,154,185,115,87,33.3,58.8
green,green,Greyish green,#85bb65,133,187,101,97,38.7,56.5
green,green,Greyish green,#7BB661,123,182,97,102,36.8,54.7
green,medium light green,Greyish green,#A5CA77,165,202,119,87,43.9,62.9
green,medium light green,Greyish green,#93C572,147,197,146,119,41.7,61.0
green,green,Greyish lime green,#74C365,116,195,101,110,43.9,58.0
green,green,Greyish lime green,#71bc78,113,188,120,125,35.9,59.0
purple,medium light magenta,Greyish purple,#B284BE,178,132,190,288,30.9,63.1
purple,medium light magenta,Greyish purple,#B96CCA,185,108,202,289,47.0,60.8
purple,medium light magenta,Greyish purple,#C693C7,198,147,199,299,31.7,67.8
purple,medium light magenta,Greyish purple,#cc99cc,204,153,204,300,33.3,70.0
purple,medium light magenta,Greyish purple,#D473D4,212,115,212,300,53.0,64.1
purple,medium light magenta,Greyish purple,#D498CB,212,152,203,309,41.1,71.4
purple,medium light magenta,Greyish purple,#D39BCB,211,155,203,309,38.9,71.8
brown,brown,Greyish brown,#C19A6B,193,154,107,33,41.0,58.8
brown,brown,Greyish brown,#C3A368,195,163,104,39,43.1,58.6
brown,medium light brown,Greyish brown,#ce9f6f,206,159,111,30,49.2,62.2
brown,medium light brown,Greyish brown,#D2B48C,210,180,140,34,43.8,68.6
brown,medium light brown,Greyish brown,#d3b17d,211,177,125,36,49.4,65.9
brown,medium light brown,Greyish brown,#C8AD7F,200,173,127,38,39.9,64.1
brown,medium light brown,Greyish brown,#CDB891,205,184,145,39,37.5,68.6
brown,medium light brown,Greyish brown,#BFAA80,191,170,128,40,33.0,62.5
grey,medium light brown,Greyish brown,#C3B091,195,176,145,37,29.4,66.7
brown,medium light orange,Greyish brown,#CD9575,205,149,117,22,46.8,63.1
brown,medium light orange,Greyish brown,#BC987E,188,152,26,47,31.6,61.6
brown,orange,Greyish brown,#C88A65,200,138,101,22,47.4,59.0
brown,orange,Greyish brown,#C48E69,196,142,105,24,43.5,59.0
brown,orange,Greyish brown,#B38B6D,179,139,109,26,31.5,56.5
brown,red-orange,Brown,#B4745E,180,116,194,289,36.4,53.7
brown,yellow,Greyish yellow brown,#bba46d,187,164,109,42,36.4,58.0
purple,magenta,Greyish purple,#B768A2,183,104,162,316,35.4,56.3
purple,magenta-pink,Greyish purple,#B37E9A,179,126,154,328,25.9,59.8
purple,medium light magenta,Greyish purple,#CD81B8,205,129,184,317,43.2,65.5
purple,medium light magenta,Greyish purple,#B784A7,183,132,167,319,26.2,61.8
pink,medium light magenta-pink,Greyish purple,#CF71AF,207,113,175,320,49.5,62.7
pink,medium light magenta-pink,Greyish purple,#CA82AF,202,130,175,323,40.4,65.1
pink,medium light magenta-pink,Greyish purple,#CF6BA9,207,107,169,323,51.0,61.6
purple,medium light magenta-pink,Greyish purple,#BB8CAA,187,140,170,322,25.7,64.1
purple,medium light magenta-pink,Greyish purple,#C077A6,198,119,166,324,36.7,61.0
purple,medium light magenta-pink,Greyish purple,#D290B5,210,144,181,326,42.3,69.4
purple,medium light magenta-pink,Greyish purple,#D58EB5,213,142,181,327,45.8,69.6
pink,medium light pink,Greyish pink,#D470A2,212,112,162,330,53.8,63.5
pink,medium light pink,Greyish pink,#D770A2,215,112,162,331,56.3,64.1
pink,medium light pink,Greyish pink,#D597AE,213,151,174,338,42.5,71.4
pink,medium light pink,Greyish pink,#D47494,212,116,148,340,52.7,64.3
pink,medium light pink,Greyish pink,#D591A4,213,145,164,343,44.7,70.2
purple,medium light pink,Greyish pink,#bb7796,187,119,150,332,33.3,60.0
purple,medium light pink,Greyish pink,#B48395,180,131,149,338,24.6,61.0
purple,medium light pink,Greyish pink,#C17E91,193,126,145,343,35.1,62.5
brown,medium light pink-red,Greyish pink-red,#C08081,192,128,129,359,33.7,62.7
purple,medium light pink-red,Greyish pink-red,#d0748b,208,116,139,345,49.5,63.5
purple,medium light pink-red,Greyish pink-red,#CC8899,204,136,153,345,40.0,66.7
purple,medium light pink-red,Greyish pink-red,#D0868E,208,134,142,354,44.0,67.1
brown,medium light red,Greyish brown,#CD9999,205,153,153,0,34.2,70.2
brown,medium light red,Greyish brown,#D66F6C,214,111,108,2,56.4,63.1
brown,medium light red,Greyish brown,#C08181,192,128,125,3,33.3,62.9
brown,medium light red,Greyish brown,#d7837f,215,131,127,3,52.4,67.1
brown,medium light red,Greyish brown,#BB8983,187,137,131,6,29.2,62.4
grey,pink-red,Greyish pink-red,#B57281,181,114,129,347,31.2,57.8
purple,pink-red,Greyish pink-red,#B76E79,183,110,121,351,33.6,57.5
brown,red,Greyish brown,#B76969,183,105,105,0,35.1,56.5
brown,red,Greyish brown,#b56c60,181,108,96,8,36.5,54.3
brown,red-orange,Greyish brown,#B87B6B,184,123,107,12,35.2,57.1
purple,blue-magenta,Greyish violet,#8B72BE,139,114,190,260,36.9,59.6
purple,blue-magenta,Greyish violet,#967bb6,150,123,182,267,28.8,59.8
purple,blue-magenta,Greyish violet,#9678B6,150,120,182,269,29.8,59.2
purple,blue-magenta,Greyish violet,#9978B6,150,120,182,269,29.8,59.2
purple,blue-magenta,Greyish violet,#9771B5,151,113,181,274,31.5,57.6
purple,medium light blue-magenta,Medium greyish purple,#966fd6,150,111,214,262,55.7,63.7
purple,medium light blue-magenta,Medium greyish purple,#9874D3,152,116,211,263,51.9,64.1
purple,medium light blue-magenta,Medium greyish purple,#9C87CD,158,137,193,263,41.2,66.7
purple,medium light blue-magenta,Medium greyish purple,#ba93d8,186,147,216,273,46.9,71.2
purple,medium light blue-magenta,Medium greyish purple,#B898CD,184,152,205,276,34.6,70.0
purple,medium light blue-magenta,Medium greyish purple,#A76BCF,167,107,207,276,51.0,61.6
brown,medium light yellow,Greyish yellow,#C2B280,194,178,128,45,35.1,63.1
grey,medium light yellow,Greyish yellow,#bcb58c,188,181,140,51,26.4,64.3
grey,medium light yellow,Greyish yellow,#BBB477,187,180,119,54,33.3,60.0
grey,medium light yellow,Greyish yellow,#BCB88A,188,184,138,55,27.2,63.9
grey,medium light yellow,Greyish yellow,#D6CE7B,214,206,123,55,52.6,66.1
grey,medium light yellow-green,Greyish yellow-green,#CECF72,206,207,114,61,49.2,62.9
grey,medium light yellow-green,Greyish yellow-green,#D3D86E,211,216,110,63,57.6,63.9
grey,medium light yellow-green,Greyish yellow-green,#B0B583,176,181,131,66,25.3,61.2
brown,yellow,Greyish yellow,#bfbd70,191,189,112,58,38.2,59.4
grey,yellow,Greyish yellow,#BDB76B,189,183,107,56,38.3,58.0
grey,yellow,Greyish yellow,#B5B35C,181,179,92,59,37.6,53.5
green,yellow-green,Greyish yellow-green,#ACBF60,172,191,96,72,42.6,56.3
grey,yellow-green,Greyish yellow-green,#BFBF6C,191,191,108,60,39.3,58.6
purple,blue-magenta,Soft blue-purple,#6050DC,96,80,220,247,66.7,58.8
blue,light cyan,Soft blue,#87d3f8,135,211,248,199,89.0,75.1
blue,light cyan-blue,Soft blue,#89CFFD,137,207,240,199,96.7,76.5
blue,light cyan-blue,Soft blue,#87CEFA,135,206,250,203,92.0,75.5
blue,medium light blue,Soft blue,#4f86f7,79,134,247,220,91.3,63.9
purple,medium light blue-magenta,Soft blue-purple,#7B68EE,123,104,238,249,79.8,67.1
purple,medium light blue-magenta,Soft blue-purple,#8366f4,131,102,244,252,86.6,67.8
blue,medium light cyan-blue,Medium soft blue,#73C2FB,115,194,215,193,94.4,71.8
blue,medium light cyan-blue,Medium soft blue,#7CB9E8,124,185,232,206,70.1,69.8
blue,medium light cyan-blue,Medium soft blue,#5DADEC,93,173,236,206,79.0,64.5
blue,medium light cyan-blue,Medium soft blue,#74bbfb,116,187,251,208,94.4,72.0
blue,medium light cyan-blue,Medium soft blue,#74ACDF,116,172,223,209,62.6,66.5
blue,medium light cyan-blue,Medium soft blue,#6CA0DC,108,160,220,212,61.5,64.3
blue,medium light cyan-blue,Medium soft blue,#77B5FE,119,181,254,212,98.5,73.1
blue,medium light cyan-blue,Medium soft blue,#5B92E5,91,146,229,216,72.6,62.7
blue,medium light cyan-blue,Medium soft blue,#4c8bf5,76,139,245,217,89.4,62.9
blue,medium light cyan-blue,Medium soft blue,#6495ED,100,149,237,219,79.2,66.1
blue,medium light cyan,Soft cyan,#76D7EA,118,215,234,190,73.4,69.0
blue,medium light cyan,Soft cyan,#71D9E2,113,217,226,185,66.1,66.5
blue,medium light cyan,Soft cyan,#80daeb,128,218,235,189,72.8,71.2
blue,medium light cyan,Soft cyan,#7ED4E6,126,212,230,190,67.5,69.8
green,medium light green,Soft lime green,#64e986,100,233,134,135,75.1,65.3
green,medium light green-cyan,Soft lime green,#66DDAA,102,205,170,160,63.6,63.3
green,medium light green,Soft green,#B2EC5D,178,236,53,79,79.0,64.5
green,medium light yellow-green,Soft green,#BBE261,187,226,97,78,69.0,63.3
green,medium light green,Soft lime green,#77DD77,119,221,119,120,60.0,66.7
pink,medium light magenta,Soft purple,#f984e5,249,132,229,310,90.7,74.7
pink,medium light magenta,Soft purple,#F984EF,249,132,229,310,90.7,74.7
pink,medium light magenta,Soft purple,#FE4EDA,254,78,218,312,98.9,65.1
purple,medium light magenta,Soft purple,#DF63E6,223,99,230,297,72.4,64.5
purple,medium light magenta,Soft purple,#FC74FD,252,116,253,300,97.2,72.4
purple,medium light magenta,Soft purple,#EE82EE,238,130,238,300,76.1,72.2
purple,medium light magenta,Soft purple,#DA70D6,218,112,214,302,58.9,64.7
brown,brown,Soft brown,#e29c45,226,156,69,33,73.0,57.8
brown,medium light brown,Soft brown,#F8B878,248,184,120,30,90.1,72.2
brown,medium light brown,Soft brown,#f7bb7d,247,187,125,30,88.4,72.9
brown,medium light brown,Soft brown,#E1A95F,225,169,95,34,68.4,62.7
brown,medium light brown,Soft brown,#E3A857,227,168,87,35,71.4,61.6
brown,medium light brown,Soft brown,#E3AB57,227,171,87,36,71.4,61.6
brown,medium light orange,Soft orange,#e88e5a,232,142,90,21,75.5,63.1
brown,medium light orange,Soft orange,#E69966,230,153,102,24,71.9,65.1
brown,medium light orange,Soft orange,#F4A460,244,164,96,28,87.1,66.7
brown,medium light orange,Soft orange,#ECB176,236,177,118,30,75.6,69.4
brown,medium light orange,Soft orange,#E5AA70,229,170,112,30,69.2,66.9
brown,medium light orange,Soft orange,#D99A6C,217,154,108,34,58.9,63.7
orange,medium light orange,Soft orange,#fca474,252,164,116,21,95.8,72.2
orange,medium light orange,Soft orange,#fa9258,250,146,88,21,94.2,66.3
orange,medium light orange,Soft orange,#FAA76C,250,167,108,25,93.4,70.2
orange,medium light orange,Soft orange,#FAB57F,250,181,127,26,92.5,73.9
orange,medium light orange,Soft orange,#FBAB60,251,171,96,29,95.1,68.0
brown,medium light red-orange,Soft brown,#E9967A,233,150,122,15,71.6,69.6
brown,medium light red-orange,Soft brown,#EB9373,235,147,115,16,75.0,68.6
brown,medium light red-orange,Soft red-orange,#f57f4f,245,127,79,17,89.2,63.5
brown,medium light red-orange,Soft brown,#DA8A67,218,138,103,18,60.8,62.9
brown,medium light red-orange,Soft brown,#D99376,217,147,118,18,56.6,65.7
brown,medium light red-orange,Soft red-orange,#ec8254,236,130,84,18,80.0,62.7
brown,medium light red-orange,Soft red-orange,#ec956c,236,149,108,19,77.1,67.5
brown,medium light yellow,Soft yellow,#e0bc5b,224,188,91,43,68.2,61.8
yellow,medium light yellow,Soft yellow,#F2BA49,242,186,73,40,86.7,61.8
yellow,medium light yellow,Soft yellow,#F2C649,242,198,73,44,86.7,61.8
yellow,medium light yellow,Soft yellow,#FCD667,252,214,103,45,96.1,69.6
brown,orange,Soft brown,#D99058,217,144,88,26,62.9,59.8
brown,orange,Soft brown,#de8f4e,222,143,78,27,68.6,58.8
pink,light pink,Soft pink,#FC89AC,252,137,172,342,95.0,76.3
pink,medium light magenta,Soft pink-purple,#EB6FCB,235,111,203,315,75.6,67.8
pink,medium light magenta-pink,Soft pink,#FC51AF,252,81,175,327,96.6,65.3
pink,medium light magenta-pink,Soft pink,#F653A6,246,83,166,329,90.1,64.5
pink,medium light magenta-pink,Soft pink,#F77FBE,247,127,190,329,88.2,73.3
pink,medium light pink,Soft pink,#DE6FA1,222,111,61,19,62.7,65.3
pink,medium light pink,Soft pink,#E25098,226,80,155,329,71.6,60.0
pink,medium light pink,Soft pink,#de70a1,222,112,161,333,62.5,65.5
pink,medium light pink,Soft pink,#f364a2,243,100,162,333,85.6,67.3
pink,medium light pink,Soft pink,#e85395,232,83,149,333,76.4,61.8
pink,medium light pink,Soft pink,#DD5A91,221,90,145,335,65.8,61.0
pink,medium light pink,Soft pink,#F75394,247,83,148,336,91.1,64.7
pink,medium light pink,Soft pink,#F56FA1,245,111,161,338,87.0,69.8
pink,medium light pink,Soft pink,#F64A8A,246,74,138,338,90.5,62.7
pink,medium light pink,Soft pink,#FD6C9E,253,108,158,339,97.3,70.8
pink,medium light pink,Soft pink,#EC5486,236,84,134,340,80.0,62.7
pink,medium light pink,Soft pink,#DB7093,219,112,147,340,59.8,64.9
pink,medium light pink,Soft pink,#E47698,228,118,152,341,67.1,67.8
pink,medium light pink,Soft pink,#fc5a8d,252,90,141,341,96.4,67.1
pink,medium light pink,Soft pink,#E75480,234,84,128,342,75.4,61.8
pink,medium light pink,Soft pink,#FC80A5,252,128,165,342,95.4,74.5
pink,medium light pink,Soft pink,#f56991,245,105,145,342,87.5,68.6
pink,medium light pink,Soft pink,#FA4F7B,250,79,123,345,94.5,64.5
red,medium light pink,Soft pink,#DE5D83,222,93,131,342,66.2,61.8
pink,pink,Soft pink,#DD4384,221,67,132,335,69.4,56.5
pink,pink,Soft pink,#DE4C8A,222,76,138,335,68.9,58.4
pink,pink,Soft pink,#DE5285,222,82,133,338,68.0,59.6
pink,pink,Soft pink,#D94972,217,73,114,343,65.5,56.9
pink,light pink-red,Soft red,#FE828C,254,130,140,355,98.4,75.3
pink,medium light pink-red,Soft red,#F05B78,253,91,153,337,83.2,64.9
pink,medium light pink-red,Soft red,#FB607F,251,96,127,348,95.1,68.0
pink,medium light pink-red,Soft red,#FC6C85,252,109,133,350,96.0,70.6
pink,medium light pink-red,Soft red,#db5a6b,219,90,107,352,64.2,60.6
pink,medium light pink-red,Soft red,#F26476,242,100,118,352,84.5,67.1
pink,medium light pink-red,Soft red,#F57584,245,117,132,353,86.5,71.0
pink,medium light pink-red,Soft red,#E4717A,228,113,122,355,68.0,66.9
pink,medium light pink-red,Soft red,#e66771,230,103,113,355,71.8,65.3
pink,medium light pink-red,Soft red,#f47983,244,121,131,355,84.8,71.6
pink,medium light pink-red,Soft red,#fa6e79,250,110,121,355,93.3,70.6
brown,medium light red,Soft red,#E2725B,226,114,91,10,69.9,62.2
orange,medium light red,Soft red,#fd5e53,253,94,83,3,97.7,65.9
orange,medium light red,Soft red,#f7665a,247,102,90,4,90.8,66.1
orange,medium light red,Soft red,#f8674f,248,103,79,8,92.3,64.1
orange,medium light red,Soft red,#fa7b62,250,123,98,9,93.8,68.2
pink,medium light red,Soft red,#f58f84,245,143,132,5,85.0,73.9
pink,medium light red,Soft red,#fd7c6e,253,124,110,5,97.3,71.2
pink,medium light red,Soft red,#F88379,248,131,121,5,90.1,72.4
pink,medium light red,Soft red,#FA8072,250,128,114,6,93.2,71.4
pink,medium light red,Soft red,#FE6F5E,254,111,94,6,98.8,68.2
red,medium light red,Soft red,#F08080,240,128,128,0,78.9,72.2
red,medium light red,Soft red,#E66761,230,103,97,3,72.7,64.1
red,medium light red,Soft red,#E95C4B,233,92,75,6,78.2,60.4
brown,medium light red-orange,Soft brown,#e68364,230,131,100,14,72.2,64.7
brown,medium light red-orange,Soft brown,#f9906f,249,144,111,14,92.0,70.6
brown,medium light red-orange,Soft brown,#E58E73,229,142,115,15,68.7,67.5
orange,medium light red-orange,Soft brown,#F99379,248,131,121,5,91.4,72.5
orange,medium light red-orange,Soft brown,#f07f5e,240,127,94,13,83.0,65.5
orange,medium light red-orange,Soft brown,#E97451,233,116,81,13.8,77.6,61.6
brown,red,Soft red-brown,#de5246,222,82,70,4,69.7,57.3
brown,red,Soft red-brown,#da614e,218,97,78,8,65.4,58.0
red,red,Soft red-brown,#dc5349,220,83,73,4,67.7,57.5
purple,medium light blue-magenta,Soft violet,#9370DB,147,112,219,260,59.8,64.9
purple,medium light blue-magenta,Soft violet,#9457EB,148,87,235,265,78.7,63.1
purple,medium light blue-magenta,Soft violet,#C77DF3,199,125,243,278,83.1,72.2
purple,medium light magenta,Soft violet,#D46FF9,212,111,249,284,92.0,70.6
yellow,light yellow,Soft yellow,#FCE883,252,232,131,50,95.3,75.1
green,light yellow-green,Soft yellow,#E3F988,227,249,136,72,90.4,75.5
yellow,medium light yellow,Soft yellow,#F8D568,248,213,104,45,91.1,69.0
yellow,medium light yellow,Soft yellow,#fddb6d,253,219,109,45,97.3,71.0
yellow,medium light yellow,Soft yellow,#FED85D,254,216,93,46,98.8,68.0
yellow,medium light yellow,Soft yellow,#F8DE7E,248,222,126,47,89.7,73.3
yellow,medium light yellow,Soft yellow,#FADA5E,250,218,94,48,94.0,67.5
yellow,medium light yellow,Soft yellow,#F0DC82,240,220,130,49,78.6,72.5
yellow,medium light yellow,Soft yellow,#EEDC82,238,220,130,50,76.1,72.2
yellow,medium light yellow,Soft yellow,#F8DD5C,248,221,92,50,91.8,66.7
yellow,medium light yellow,Soft yellow,#E9D66B,233,214,107,51,74.1,66.7
yellow,medium light yellow,Soft yellow,#F5E050,245,224,80,52,89.2,63.7
yellow,medium light yellow,Soft yellow,#F5E25C,245,226,92,53,88.4,66.1
yellow,medium light yellow,Soft yellow,#FEEF61,254,239,97,54,98.7,68.8
yellow,medium light yellow,Soft yellow,#FBEC5D,251,236,93,54,95.2,67.5
yellow,medium light yellow,Soft yellow,#E4D96F,228,217,111,54,68.4,66.5
yellow,medium light yellow,Soft yellow,#fef65b,254,246,91,57,98.8,67.6
yellow,medium light yellow,Soft yellow,#FCF75E,252,247,94,58,96.3,67.8
yellow,medium light yellow,Soft yellow,#EEDD62,238,221,98,53,80.5,65.9
green,medium light yellow-green,Soft yellow-green,#D9E650,217,230,80,65,75.0,60.8
green,medium light yellow-green,Soft yellow-green,#E6F554,230,245,84,66,89.0,64.5
green,medium light yellow-green,Soft yellow-green,#D6E94B,214,233,75,67,78.2,60.4
grey,medium light yellow-green,Soft yellow-green,#dde26a,221,226,106,62,67.4,65.1
grey,medium light yellow-green,Soft yellow-green,#DDE454,221,228,84,63,72.7,61.2
grey,medium light yellow-green,Soft yellow-green,#E8F24E,232,242,78,64,86.3,62.7
yellow,medium light yellow-green,Soft yellow-green,#f2f27a,242,242,122,60,82.2,71.4
yellow,medium light yellow-green,Soft yellow-green,#d0db61,208,219,97,65,62.9,62.0
green,yellow-green,Soft yellow-green,#D4E646,212,230,70,67,76.2,58.8
green,yellow-green,Soft yellow-green,#BDDA57,189,218,87,73,63.9,59.8
blue,blue,Strong blue,#214fc6,33,79,198,223,71.4,45.3
blue,blue,Strong blue,#2A52BE,42,82,190,224,63.8,45.5
blue,blue,Strong blue,#2243B6,34,67,182,227,68.5,42.4
blue,blue,Strong blue,#1C39BB,28,57,187,229,74.0,42.2
blue,Blue-magenta,Strong blue-purple,#0000CD,0,0,205,240,100.0,40.2
blue,blue-magenta,Strong blue-purple,#360CCC,54,12,204,253,88.9,42.4
blue,cyan,Strong cyan,#0096D6,0,150,210,197,100.0,42.0
blue,cyan,Strong cyan,#0892D0,8,146,208,199,92.6,42.4
blue,cyan,Strong cyan,#188bc2,24,139,194,199,78.0,42.7
blue,cyan,Strong cyan,#2496cd,36,150,205,199,70.1,47.3
blue,cyan-blue,Strong cyan-blue,#2887C8,40,135,200,204,66.7,47.1
blue,cyan-blue,Strong cyan-blue,#0078d7,0,120,215,206,100.0,42.2
blue,cyan-blue,Strong cyan-blue,#2D68C4,45,104,196,207,62.7,47.3
blue,cyan-blue,Strong cyan-blue,#0073CF,0,115,207,207,100.0,40.6
blue,cyan-blue,Strong cyan-blue,#1974D2,25,116,210,210,78.7,46.1
blue,cyan-blue,Strong cyan-blue,#0066CD,0,102,205,210,100.0,40.2
blue,cyan-blue,Strong cyan-blue,#1560BD,21,96,189,213,80.0,41.2
blue,cyan-blue,Strong cyan-blue,#246BCE,36,107,206,215,70.2,47.5
blue,cyan-blue,Strong cyan-blue,#216bd6,33,107,214,215,73.3,48.4
blue,medium dark cyan,Medium dark cyan,#0087BD,0,135,189,197,100.0,37.1
blue,medium dark cyan,Medium dark cyan,#007BB8,0,123,184,200,100.0,36.1
blue,medium dark cyan-blue,Medium dark cyan-blue,#0066CC,0,102,204,210,100.0,40.0
purple,medium dark blue-magenta,Medium dark blue-purple,#1C05B3,28,5,179,248,94.6,36.1
blue,medium dark cyan-blue,Medium dark cyan-blue,#0077be,0,119,190,202,100.0,37.3
blue,medium dark cyan-blue,Medium dark cyan-blue,#0070B8,0,112,184,203,100.0,36.1
blue,medium dark cyan-blue,Medium dark cyan-blue,#006DBA,0,109,176,203,100.0,36.5
blue,medium dark cyan-blue,Medium dark cyan-blue,#0072BB,0,114,187,203,100.0,36.7
blue,medium dark cyan-blue,Medium dark cyan-blue,#1164B4,17,100,180,209,82.7,38.6
blue,medium dark cyan-blue,Strong dark blue,#0F52BA,15,82,186,216,85.1,39.4
blue,medium dark cyan-blue,Strong dark blue,#0048BA,0,72,186,217,100.0,36.5
blue,medium dark cyan-blue,Strong dark blue,#0040be,0,64,190,220,100.0,37.3
blue,cyan,Strong cyan,#18A7B5,24,167,181,185,76.6,40.2
blue,cyan,Strong cyan,#1CA9C9,28,169,201,191,75.5,44.9
blue,cyan,Strong cyan,#219EBD,33,158,189,192,70.3,43.5
blue,cyan,Strong cyan,#21ABCD,33,171,205,192,72.3,46.7
blue,cyan,Strong cyan,#02A4D3,2,164,211,193,98.1,41.8
blue,cyan,Strong cyan,#1DACD6,29,172,214,194,76.1,47.6
cyan,cyan,Strong cyan,#1CC3B4,28,195,180,175,74.9,43.7
cyan,cyan,Strong cyan,#30D5C8,48,213,200,175,66.3,51.2
cyan,cyan,Strong cyan,#00CED1,0,206,209,181,100.0,41.0
cyan,cyan,Strong cyan,#00c5cd,0,197,205,182,100.0,40.2
blue,medium dark cyan,Strong dark cyan,#0095B6,0,149,182,191,100.0,35.7
cyan,medium dark cyan,Strong dark cyan,#00CCCC,0,204,204,180,100.0,40.0
green,medium dark green-cyan,Strong dark cyan,#00CC99,0,204,153,165,100.0,40.0
blue,medium dark cyan,Strong dark cyan,#00B2CA,0,178,202,187,100.0,39.6
blue,medium dark cyan,Strong dark cyan,#00AFCA,0,175,202,188,100.0,39.6
blue,medium dark cyan,Strong dark cyan,#0D98BA,13,152,186,192,86.9,39.0
cyan,medium dark cyan,Strong dark cyan,#0ABAB5,10,186,181,178,89.8,38.4
green,green-cyan,Strong green-cyan,#1AB385,26,179,33,123,74.6,40.2
green,medium dark green,Strong green-cyan,#00cc33,0,204,51,135,100.0,40.0
green,medium dark green,Strong green-cyan,#03C03C,3,192,60,138,96.9,38.2
green,green,Strong green,#6BBE23,107,142,35,80,68.9,44.1
green,green,Strong green,#76BD17,118,189,23,86,78.3,41.6
green,green,Strong green,#57D200,87,210,0,95,100.0,41.2
green,green,Strong green,#4CBB17,76,187,23,101,78.1,41.2
green,green,Strong green,#46cb18,70,203,24,104,78.9,44.5
green,medium dark green,Strong green,#50B708,80,183,8,95,91.6,37.5
green,medium dark green,Strong green,#33CC00,51,204,0,105,100.0,40.0
green,medium dark yellow-green,Strong green,#7db700,125,183,0,79,100.0,35.9
green,yellow-green,Strong yellow-green,#8bbe1b,139,190,27,78,75.1,42.5
green,yellow-green,Strong yellow-green,#9ACD32,154,205,50,80,60.8,50.0
green,yellow-green,Strong yellow-green,#8FD400,143,212,0,80,100.0,41.6
green,green,Strong lime green,#32CD32,50,205,50,120,60.8,50.0
pink,magenta,Strong purple,#D500B6,213,0,182,309,100.0,41.8
purple,magenta,Strong purple,#CD00CC,205,0,204,300,100.0,40.2
purple,magenta,Strong purple,#CC33CC,204,51,204,300,60.0,50.0
purple,magenta,Strong purple,#C120A2,193,32,162,312,71.6,44.1
purple,medium dark magenta,Strong dark purple,#9F00C5,159,0,197,288,100.0,38.6
purple,medium dark magenta,Strong dark purple,#aa00bb,170,0,187,294,100.0,36.7
purple,medium dark magenta,Strong dark purple,#CC00CC,204,0,204,300,100.0,40.0
brown,brown,Strong brown,#CC7722,204,119,34,30,71.4,46.7
brown,brown,Strong brown,#cd8032,205,128,50,30,60.8,50.0
brown,brown,Strong brown,#c57f2e,197,127,46,32,62.1,47.6
brown,brown,Strong brown,#ca7309,202,115,9,32,91.5,41.4
brown,brown,Strong brown,#cb7e1f,203,126,31,33,73.5,45.9
brown,brown,Strong brown,#BA7827,186,120,42,33,65.3,44.1
brown,brown,Strong brown,#cd7a00,205,122,0,35,100.0,40.2
brown,medium dark brown,Medium dark brown,#c86500,200,101,0,30,100.0,39.2
brown,medium dark orange,Medium dark red-orange,#C04000,192,64,0,20,100.0,37.6
brown,medium dark orange,Medium dark brown,#CC5500,204,85,0,25,100.0,40.0
brown,medium dark red-orange,Medium dark red-orange,#B7410E,183,65,14,18,85.8,38.6
red,medium dark red-orange,Medium dark red-orange,#bd3000,189,48,0,15,100.0,37.1
brown,medium dark yellow,Medium dark yellow-brown,#B8860B,184,134,11,43,88.7,38.2
brown,orange,Medium brown,#bb6528,187,101,40,24,64.8,44.5
brown,orange,Medium brown,#ca6924,202,105,36,25,69.7,46.7
brown,orange,Medium brown,#c66b27,198,107,39,25,67.1,46.5
brown,orange,Medium brown,#d57835,213,120,53,25,65.6,52.2
brown,orange,Medium brown,#CD5700,205,87,0,25,100.0,40.2
brown,orange,Medium brown,#D2691E,210,105,30,25,75.0,47.1
brown,orange,Medium brown,#c46210,196,98,16,27,84.9,41.6
brown,orange,Medium brown,#B5651D,181,101,29,28,72.4,41.2
brown,orange,Medium brown,#b5651e,181,101,30,28,71.6,41.4
brown,orange,Medium brown,#b7702d,183,112,45,29,60.5,44.7
brown,orange,Medium brown,#B86D29,184,109,41,29,63.6,44.1
brown,orange,Medium brown,#CD7F32,205,127,50,30,60.8,50.0
red,red-orange,Strong red-orange,#CB410B,203,65,11,17,89.7,42.0
brown,yellow,Yellowish brown,#C18D25,193,141,37,40,67.8,45.1
brown,yellow,Yellowish brown,#B78727,183,135,39,40,64.9,43.5
brown,yellow,Yellowish brown,#C6930A,198,147,10,44,90.4,40.8
yellow,yellow,Yellowish brown,#CCA01D,204,160,29,45,75.1,45.7
pink,magenta-pink,Strong dark pink,#CA2C92,202,44,146,321,64.2,48.2
pink,magenta-pink,Strong dark pink,#D02090,208,32,144,322,73.3,47.1
pink,magenta-pink,Strong dark pink,#C71585,199,21,133,322,80.9,43.1
pink,magenta-pink,Strong dark pink,#cc338b,204,51,139,325,60.0,50.0
pink,magenta-pink,Strong dark pink,#D40D7D,212,13,125,326,88.4,44.1
pink,magenta-pink,Strong dark pink,#CD2682,205,38,130,327,68.7,47.6
pink,magenta-pink,Strong dark pink,#CA1F7B,202,31,123,328,73.4,45.7
pink,medium dark magenta-pink,Strong dark pink,#B41880,180,24,128,320,76.5,40.0
pink,medium dark magenta-pink,Strong dark pink,#BA067A,186,6,122,321,93.8,37.6
red,medium dark pink,Strong dark red,#B80049,184,0,73,336,100.0,36.1
red,medium dark pink,Strong dark red,#BE0032,190,0,50,344,100.0,37.3
red,medium dark pink,Strong dark red,#C40233,196,2,51,345,98.0,38.8
pink,pink,Strong pink,#d00060,208,0,96,332,100.0,40.8
pink,pink,Strong pink,#D71868,215,24,104,335,79.9,46.9
pink,pink,Strong pink,#D72D6D,215,45,109,337,68.0,51.0
pink,pink,Strong pink,#d70a53,215,10,83,338,91.1,44.1
pink,pink,Strong pink,#C30B4E,195,11,78,338,89.3,40.4
pink,pink,Strong pink,#C21E56,194,30,86,340,73.2,43.9
pink,pink,Strong pink,#D3003F,211,0,63,342,100.0,41.4
pink,pink,Strong pink,#BC2350,188,35,80,342,68.6,43.7
pink,pink,Strong pink,#D70040,215,0,64,342,100.0,42.2
pink,pink,Strong pink,#D72D5C,215,45,92,343,68.0,51.0
red,pink,Strong pink,#D10056,209,0,86,335,100.0,41.0
red,pink,Strong pink,#C51C56,197,28,86,339,75.1,44.1
red,pink,Strong pink,#D70A52,215,10,83,339,91.1,44.1
red,pink,Strong pink,#D10047,209,0,71,340,100.0,41.0
red,pink,Strong pink,#C32350,195,35,80,343,69.6,45.1
red,medium dark pink-red,Strong dark red,#cc0033,204,0,51,345,100.0,40.0
red,medium dark pink-red,Strong dark red,#b60c26,182,12,38,350,87.6,38.0
red,medium dark pink-red,Strong dark red,#C90016,201,0,22,353,100.0,39.4
red,medium dark pink-red,Strong dark red,#ba0001,186,0,1,359,100.0,36.5
red,medium dark red,Strong dark red,#BA160C,186,22,12,3,87.9,38.8
pink,pink-red,Strong red,#cf142b,207,20,43,352,82.4,44.5
pink,pink-red,Strong red,#cd071e,205,7,30,353,93.4,41.6
pink,pink-red,Strong red,#ce1127,206,17,39,353,84.8,43.7
red,pink-red,Strong red,#C32148,195,33,72,346,71.1,44.7
red,pink-red,Strong red,#C3103A,195,16,58,346,84.8,41.4
red,pink-red,Strong red,#C53151,197,49,81,347,60.2,48.2
red,pink-red,Strong red,#cf0a2c,207,10,44,349,90.8,42.5
red,pink-red,Strong red,#C72C48,199,44,72,349,63.8,47.6
red,pink-red,Strong red,#c71232,199,18,50,349,83.4,42.5
red,pink-red,Strong red,#C41E3A,196,30,58,350,73.5,44.3
red,pink-red,Strong red,#d1001c,209,0,28,351,100.0,41.0
red,pink-red,Strong red,#c91f37,201,31,55,351,73.3,45.5
red,pink-red,Strong red,#C51D34,197,29,52,352,74.3,44.3
red,pink-red,Strong red,#b32134,179,33,52,352,68.9,41.6
red,pink-red,Strong red,#CE2029,206,22,41,354,73.1,46.7
red,pink-red,Strong red,#CF1020,207,16,32,355,85.7,43.7
red,pink-red,Strong red,#C80815,200,8,21,356,92.3,40.8
red,pink-red,Strong red,#D3212D,211,33,45,356,73.0,47.8
red,pink-red,Strong red,#cd040b,205,4,11,357,96.2,41.0
red,pink-red,Strong red,#C3272B,195,39,43,358,66.7,45.9
red,pink-red,Strong red,#CC3336,204,51,54,359,60.0,50.0
red,red,Strong red-brown,#B31B1B,179,27,27,0,73.8,40.4
red,red,Strong red-brown,#b62020,182,32,32,0,70.1,42.0
red,red,Strong red-brown,#CC3333,204,51,51,0,60.0,50.0
red,red,Strong red-brown,#D40000,212,0,0,0,100.0,41.6
red,red,Strong red-brown,#bc2d29,188,45,41,1,64.2,44.9
red,red,Strong red-brown,#C0362C,192,54,44,4,62.7,46.3
red,red,Strong red-brown,#cf3a24,207,58,36,7,70.4,47.6
red,red,Strong red-brown,#c23b22,194,59,34,9,70.2,44.7
brown,red-orange,Strong brown,#b64925,182,73,37,14,66.2,42.9
purple,blue-magenta,Strong violet,#7D26CD,125,38,205,271,68.7,47.6
purple,blue-magenta,Strong violet,#8806CE,136,6,206,279,94.3,41.6
purple,blue-magenta,Strong violet,#652DC1,101,45,93,309,62.2,46.7
purple,magenta,Strong violet,#9932CC,153,50,204,280,60.6,49.8
purple,magenta,Strong violet,#9400D3,148,0,211,282,100.0,41.4
purple,medium dark blue-magenta,Strong violet,#6600B7,102,0,187,273,100.0,35.9
purple,medium dark magenta,Strong violet,#8B00CC,139,0,204,281,100.0,40.0
brown,medium dark yellow,Strong dark yellow brown,#cc9900,204,153,0,45,100.0,40.0
yellow,medium dark yellow,Strong dark yellow brown,#C1A004,193,160,4,50,95.9,38.6
green,medium dark yellow-green,Strong dark yellow-green,#9DC209,157,194,9,72,91.1,39.8
green,medium dark yellow-green,Strong dark yellow-green,#8DB600,141,182,0,74,100.0,35.7
brown,yellow,Strong dark yellow brown,#bda928,189,169,40,51,65.1,44.9
yellow,yellow,Strong dark yellow brown,#bd9b16,189,155,22,47,79.1,41.4
green,yellow-green,Strong yellow-green,#B3C110,179,193,16,65,84.7,41.0
green,yellow-green,Strong yellow-green,#BFD833,191,216,51,69,67.9,52.4
green,yellow-green,Strong yellow-green,#A1C50A,161,197,10,72,90.3,40.6
green,yellow-green,Strong yellow-green,#A5CB0C,165,203,12,72,88.8,42.2
green,yellow-green,Strong yellow-green,#a6d608,166,214,8,73,92.8,43.5
green,yellow-green,Strong yellow-green,#A1C42C,161,196,44,74,63.3,47.1
yellow,yellow-green,Strong yellow-green,#CCCC33,204,204,51,60,60.0,50.0
yellow,yellow-green,Strong yellow-green,#B0BF1A,176,191,26,65,76.0,42.5
black,very dark cyan-blue,Black,#010203,1,2,3,210,50.0,0.8
black,very dark blue,Black,#181b26,24,27,38,227,22.6,12.2
black,very dark blue,Black,#17182b,23,24,43,237,30.3,12.9
black,very dark cyan-blue,Black,#1f262a,31,38,42,201,15.1,14.3
black,very dark cyan-blue,Black,#010B13,1,11,19,207,90.0,3.9
black,dark cyan,Black,#232B2B,35,43,43,180,10.3,15.3
black,very dark green-cyan,Black,#013220,1,50,32,158,96.1,10.0
black,very dark green-cyan,Black,#1A2421,26,36,33,162,16.1,12.2
black,dark green,Black,#2A2F23,42,47,35,85,14.6,16.1
black,very dark green,Black,#1A2118,26,33,24,107,15.8,11.2
black,very dark magenta,Black,#242124,36,33,36,300,4.3,13.5
black,very dark brown,Black,#100C08,16,12,8,30,33.3,4.7
black,very dark brown,Black,#252321,37,35,33,30,5.7,13.7
black,very dark orange,Black,#27221f,39,34,31,22,11.4,13.7
black,very dark orange,Black,#2c1608,44,22,8,23,69.2,10.2
black,very dark orange,Black,#171412,23,20,18,24,12.2,8.0
black,very dark red-orange,Black,#2e211b,46,33,27,18,26.0,14.3
black,very dark yellow,Black,#1B1811,27,24,17,42,22.7,8.6
black,very dark magenta,Black,#2b2028,43,32,40,316,14.7,14.7
black,very dark pink,Black,#23191e,35,25,30,330,16.7,11.8
black,very dark red,Black,#321414,50,20,20,0,42.9,13.7
black,very dark red,Black,#1a1110,26,17,16,5,23.8,8.2
black,very dark red-orange,Black,#290E05,41,14,5,15,78.3,9.0
black,very dark blue-magenta,Black,#0f031a,15,3,26,271,79.3,5.7
blue,dark cyan-blue,Very dark blue,#003366,0,51,102,210,100.0,20.0
black,dark blue,Very dark blue,#191F45,25,31,69,232,46.8,18.4
black,dark blue,Very dark blue,#02075d,2,7,93,236,95.8,18.6
blue,dark blue,Very dark blue,#082567,8,37,103,222,85.6,21.8
blue,dark blue,Very dark blue,#1B294B,27,41,75,222,47.1,20.0
blue,dark blue,Very dark blue,#1D2951,29,41,81,226,47.3,21.6
blue,dark blue,Very dark blue,#051657,9,22,87,230,89.1,18.0
blue,dark cyan-blue,Very dark blue,#00416A,0,65,106,203,100.0,20.8
blue,dark cyan-blue,Very dark blue,#003153,0,49,83,205,100.0,16.3
blue,dark cyan-blue,Very dark blue,#003b6f,0,59,111,208,100.0,21.8
blue,dark cyan-blue,Very dark blue,#003A6C,0,58,108,208,100.0,21.2
blue,dark cyan-blue,Very dark blue,#002E63,0,46,99,212,100.0,19.4
blue,dark cyan-blue,Very dark blue,#003171,0,49,113,214,100.0,22.2
blue,dark cyan-blue,Very dark blue,#002366,0,35,102,219,100.0,20.0
blue,medium dark blue,Very dark blue,#233067,35,48,103,229,49.3,27.1
blue,medium dark blue-magenta,Very dark blue,#191970,25,25,112,240,63.5,26.9
blue,medium dark cyan-blue,Very dark blue,#213C6E,33,60,110,219,53.8,28.0
black,very dark blue,Very dark blue,#001440,0,20,64,221,100.0,12.5
black,very dark cyan-blue,Very dark blue,#002147,0,33,71,212,100.0,13.9
green,dark cyan,Very dark cyan,#004953,0,73,83,187,100.0,16.3
green,dark cyan,Very dark cyan,#044f67,4,79,103,194,92.5,21.0
green,dark green-cyan,Very dark cyan,#18453B,24,69,59,167,48.4,18.2
green,dark green-cyan,Very dark cyan,#064E40,6,78,64,168,85.7,16.5
black,very dark cyan,Very dark cyan,#004242,0,66,66,180,100.0,12.9
black,very dark cyan,Very dark cyan,#004040,0,64,64,180,100.0,12.5
green,very dark cyan,Very dark cyan,#004B49,0,75,73,178,100.0,14.7
green,dark green-cyan,Very dark green,#006442,0,100,66,159,100.0,19.6
green,dark green,Very dark green,#1e4d2b,30,77,43,136,43.9,21.0
green,dark green-cyan,Very dark green,#00703C,0,112,60,152,100.0,22.0
green,dark green-cyan,Very dark green,#006B3C,0,107,60,154,100.0,21.0
green,dark green-cyan,Very dark green,#1B4D3E,27,77,62,162,48.1,20.4
green,dark green-cyan,Very dark green,#006A4E,0,106,78,164,100.0,20.8
green,dark green-cyan,Very dark green,#00563F,0,86,63,164,100.0,16.9
green,medium dark green-cyan,Very dark green,#177245,23,114,69,150,66.4,26.9
black,very dark green-cyan,Very dark green,#123524,18,53,36,151,49.3,13.9
black,very dark green-cyan,Very dark green,#004225,0,66,37,154,100.0,12.9
black,very dark green-cyan,Very dark green,#043927,4,57,39,160,86.9,12.0
black,very dark green-cyan,Very dark green,#02402C,2,64,44,161,93.9,12.9
green,very dark green-cyan,Very dark green,#014421,1,68,33,149,97.1,13.5
black,dark blue,Very dark grey blue,#192236,25,34,54,221,36.7,15.5
blue,dark blue,Very dark grey blue,#1C2841,28,40,65,221,39.8,18.2
grey,medium dark blue,Very dark grey blue,#485470,72,84,112,222,21.7,36.1
blue,medium dark blue-magenta,Very dark grey blue,#333366,51,51,102,240,33.3,30.0
grey,medium dark blue-magenta,Very dark grey blue,#3b3b6d,59,59,109,240,29.8,32.9
blue,medium dark cyan,Very dark grey blue,#344d56,52,77,86,195,24.6,27.1
blue,dark cyan,Very dark grey cyan,#264348,38,67,72,189,30.9,21.6
grey,dark cyan,Very dark grey cyan,#2F4F4F,47,79,79,180,25.4,24.7
grey,dark cyan,Very dark grey cyan,#203838,32,56,56,180,27.3,17.3
green,medium dark green-cyan,Very dark grey cyan,#3A6960,58,105,96,169,28.8,32.0
green,dark green-cyan,Very dark grey green,#224634,34,70,52,150,34.6,20.4
green,dark green-cyan,Very dark grey green,#1C352D,28,53,45,161,30.9,15.9
green,medium dark green-cyan,Very dark grey green,#35654d,53,101,77,150,31.2,30.2
grey,medium dark green,Very dark grey green,#2a603b,42,96,59,138,39.1,27.1
grey,dark yellow-green,Very dark grey green,#454d32,69,77,50,77,21.3,24.9
green,medium dark green,Very dark grey green,#556B2F,85,107,47,82,39.0,30.2
green,medium dark green,Very dark grey green,#355E3B,53,94,59,129,27.9,28.8
grey,medium dark green,Very dark grey green,#306030,48,96,48,120,33.3,28.2
purple,dark magenta,Very dark grey purple,#301934,48,25,52,291,35.1,15.1
purple,dark magenta,Very dark grey purple,#3a243b,58,36,59,297,24.2,18.6
purple,dark magenta,Very dark grey purple,#4F284B,79,40,75,306,32.8,23.3
grey,medium dark magenta,Very dark grey purple,#5D3954,93,57,84,315,24.0,29.4
purple,medium dark magenta,Very dark grey purple,#602F6B,96,47,107,289,39.0,30.2
purple,medium dark magenta,Very dark grey purple,#693B71,105,59,113,291,31.4,33.7
purple,medium dark magenta,Very dark grey purple,#56365C,86,54,92,291,26.0,28.6
purple,medium dark magenta,Very dark grey purple,#5B3256,91,50,86,307,29.1,27.6
grey,dark brown,Very dark brown,#413628,65,54,40,33,23.8,20.6
grey,dark brown,Very dark brown,#3c3024,60,48,36,30,25.0,18.8
black,dark orange,Very dark brown,#4c3d30,76,61,48,27,22.6,24.3
brown,dark orange,Very dark brown,#3D2B1F,61,43,31,24,32.6,18.0
brown,dark orange,Very dark brown,#4B3621,75,54,33,30,38.9,21.2
grey,dark yellow,Very dark brown,#473f2d,71,63,45,41,22.4,22.7
grey,dark yellow,Very dark brown,#3C341F,60,52,31,43,31.9,17.8
grey,dark yellow,Very dark brown,#3b331c,59,51,28,44,35.6,17.1
brown,medium dark brown,Medium dark brown,#5c4827,92,72,39,37,40.5,25.7
brown,medium dark orange,Medium dark brown,#6a432d,106,67,45,21,40.4,29.6
brown,medium dark orange,Medium dark brown,#593a27,89,58,39,22,39.1,25.1
brown,medium dark orange,Medium dark brown,#6F4E37,111,78,55,25,33.7,32.5
grey,medium dark orange,Medium dark brown,#70543e,112,84,62,26,28.7,34.1
brown,medium dark red-orange,Medium dark brown,#5C4033,96,64,51,19,28.7,28.0
grey,medium dark yellow,Medium dark brown,#534a32,83,74,50,43,24.8,26.1
purple,dark magenta,Very dark grey pink,#491e3c,73,30,60,318,41.7,20.2
purple,medium dark magenta-pink,Very dark grey pink,#663854,102,56,84,323,29.1,31.0
purple,medium dark magenta-pink,Very dark grey pink,#723157,114,49,87,325,39.9,32.0
brown,medium dark pink,Very dark grey pink,#5D3B4C,93,59,76,330,22.4,29.8
grey,medium dark pink,Very dark grey pink,#664051,97,64,81,329,22.9,32.5
grey,medium dark pink,Very dark grey pink,#66424d,102,66,77,342,21.4,32.9
purple,medium dark pink,Very dark grey pink,#673147,103,49,71,336,35.5,29.8
brown,dark pink-red,Very dark grey red,#43242a,67,36,42,348,30.1,20.2
brown,dark pink-red,Very dark grey red,#3c2126,60,33,38,348,29.0,18.2
brown,dark pink-red,Very dark grey red,#512c31,81,44,49,351,29.6,24.5
black,dark red,Very dark grey red,#4a2c2a,74,44,42,3,27.6,22.7
black,dark red,Very dark grey red,#351e1c,53,30,28,4,30.9,15.9
black,dark red-orange,Very dark grey red,#351f19,53,31,25,12,35.9,15.3
brown,dark red-orange,Very dark grey red,#542d24,84,45,36,11,40.0,23.5
grey,dark red-orange,Very dark grey red,#4c2f27,76,47,39,12,32.2,22.5
brown,medium dark pink-red,Very dark grey red,#703642,112,54,66,348,34.9,32.5
brown,medium dark pink-red,Very dark grey red,#63313A,99,49,58,349,33.8,29.0
brown,medium dark pink-red,Very dark grey red,#722F37,114,47,55,353,41.6,31.6
brown,medium dark pink-red,Very dark grey red,#713036,113,48,54,354,40.4,31.6
brown,medium dark pink-red,Very dark grey red,#59292c,89,41,44,356,36.9,25.5
grey,medium dark pink-red,Very dark grey red,#5A3839,90,56,57,358,23.3,28.6
brown,medium dark red,Very dark grey red,#704241,112,66,65,1,26.6,34.7
brown,medium dark red-orange,Very dark grey red,#523b35,82,59,53,12,21.5,26.5
grey,medium dark blue-magenta,Very dark grey violet,#54446C,84,68,108,264,22.7,34.5
purple,medium dark blue-magenta,Very dark grey violet,#3d325d,61,50,93,255,30.1,28.0
purple,medium dark magenta,Very dark grey violet,#5d3f6a,93,63,106,281,25.4,33.1
grey,dark yellow,Very dark grey yellow,#524b2a,82,75,42,49,32.3,24.3
grey,medium dark yellow-green,Very dark grey yellow,#6e6e30,110,110,48,60,39.2,31.0
grey,medium dark yellow-green,Very dark grey yellow,#545a2c,84,90,44,67,34.3,26.3
green,dark green,Very dark green,#296e01,41,110,1,97,98.2,21.8
green,medium dark green,Very dark green,#4c721d,76,114,29,86,59.4,28.0
green,medium dark yellow-green,Very dark green,#4A5D23,74,93,35,80,45.3,25.1
grey,dark grey,Very dark grey,#333333,51,51,51,0,0.0,20.0
grey,dark grey,Very dark grey,#343434,52,52,52,0,0.0,20.4
grey,grey,Very dark grey,#676767,103,103,103,0,0.0,40.4
grey,grey,Very dark grey,#696969,105,105,105,0,0.0,41.2
grey,medium dark grey,Very dark grey,#404040,64,64,64,0,0.0,25.1
grey,medium dark grey,Very dark grey,#555555,85,85,85,0,0.0,33.3
black,very dark grey,Black,#080808,8,8,8,0,0.0,3.1
black,very dark grey,Black,#1B1B1B,27,27,27,0,0.0,10.6
black,very dark grey,Black,#141414,20,20,20,0,0.0,7.8
black,dark cyan,Very dark greyish blue,#353839,53,56,57,195,3.6,21.6
grey,dark cyan-blue,Very dark greyish blue,#2a3439,42,52,57,200,15.2,19.4
grey,medium dark cyan,Very dark greyish blue,#536872,83,104,114,199,15.7,38.6
grey,medium dark blue,Very dark greyish blue,#4C516D,76,81,109,231,17.8,36.3
grey,medium dark blue-magenta,Very dark greyish blue,#41415D,65,65,93,240,17.7,31.0
grey,medium dark cyan,Very dark greyish blue,#3d4c51,61,76,81,195,14.1,27.8
grey,medium dark cyan,Very dark greyish blue,#4d646c,77,100,108,195,16.8,36.3
grey,medium dark cyan-blue,Very dark greyish blue,#36454F,54,69,79,204,18.8,26.1
grey,medium dark cyan-blue,Very dark greyish blue,#54626F,84,98,111,209,13.8,38.2
grey,dark cyan,Very dark greyish cyan,#2D383A,45,56,58,189,12.6,20.2
grey,dark cyan,Very dark greyish cyan,#2b3736,43,55,54,175,12.2,19.2
grey,dark cyan,Very dark greyish cyan,#364141,54,65,65,180,9.2,23.3
grey,medium dark cyan,Very dark greyish cyan,#354e4b,53,78,75,172,19.1,25.7
grey,medium dark cyan,Very dark greyish cyan,#455859,69,88,89,183,12.7,31.0
grey,medium dark cyan,Very dark greyish cyan,#4f666a,79,102,106,188,14.6,36.3
grey,medium dark cyan,Very dark greyish cyan,#414a4c,65,74,76,190,7.8,27.6
grey,medium dark cyan,Very dark greyish cyan,#4A646C,74,100,108,194,18.7,35.7
black,dark green,Very dark greyish lime,#253529,37,53,41,135,17.8,17.6
grey,dark green-cyan,Very dark greyish lime,#2d4436,45,68,54,143,20.4,22.2
grey,dark green-cyan,Very dark greyish lime,#2b3733,43,55,51,160,12.2,19.2
grey,medium dark green-cyan,Very dark greyish lime,#4D5D53,77,93,83,143,9.4,33.3
grey,dark green,Very dark greyish green,#374231,55,66,49,98,14.8,22.5
grey,dark green,Very dark greyish green,#354230,53,66,48,103,15.8,22.4
grey,dark yellow-green,Very dark greyish green,#3d4035,61,64,53,76,9.4,22.9
grey,medium dark green,Very dark greyish green,#444C38,68,76,56,84,15.2,25.9
grey,medium dark green,Very dark greyish green,#555D50,85,93,80,97,7.5,33.9
grey,medium dark yellow-green,Very dark greyish green,#5e644f,94,100,79,77,11.7,35.1
grey,dark green,Very dark greyish lime green,#2e372e,46,55,46,120,8.9,19.8
grey,dark green,Very dark greyish lime green,#3a403b,58,64,59,130,4.9,23.9
grey,medium dark green,Very dark greyish lime green,#5a6457,90,100,87,106,7.0,36.7
grey,medium dark green,Very dark greyish lime green,#465945,70,89,69,116,12.7,31.0
grey,medium dark green,Very dark greyish lime green,#3d5d42,61,93,66,129,20.8,30.2
grey,magenta,Very dark greyish magenta,#715F6D,113,92,86,13,8.7,40.8
grey,medium dark magenta,Very dark greyish magenta,#664D64,102,77,100,305,14.0,35.1
grey,medium dark magenta,Very dark greyish magenta,#6A5767,106,87,103,309,9.8,37.8
grey,medium dark magenta,Very dark greyish magenta,#50404d,80,64,77,311,11.1,28.2
grey,medium dark magenta,Very dark greyish magenta,#51484f,81,72,79,313,5.9,30.0
purple,medium dark magenta,Very dark greyish magenta,#563C5C,86,60,92,289,21.1,29.8
purple,medium dark magenta,Very dark greyish magenta,#513653,81,54,83,296,21.2,26.9
grey,dark brown,Very dark greyish orange,#3b3429,59,52,41,36,18.0,19.6
grey,dark brown,Very dark greyish orange,#463F32,70,63,50,39,16.7,23.5
black,dark orange,Very dark greyish orange,#483C32,72,60,50,27,18.0,23.9
black,dark red-orange,Very dark greyish orange,#393432,57,52,50,17,6.5,21.0
grey,medium dark brown,Very dark greyish orange,#5C5248,92,82,72,30,12.2,32.2
grey,medium dark brown,Very dark greyish orange,#5e5545,94,85,69,38,15.3,32.0
grey,medium dark orange,Very dark greyish orange,#6e5f57,110,95,87,20,11.7,38.6
grey,medium dark orange,Very dark greyish orange,#635147,99,81,71,21,16.5,33.3
grey,medium dark orange,Very dark greyish orange,#6A5445,106,84,69,24,21.1,34.3
grey,medium dark orange,Very dark greyish orange,#5c544e,92,84,78,25,8.2,33.3
grey,medium dark orange,Very dark greyish orange,#4f4944,79,73,68,27,7.5,28.8
grey,medium dark orange,Very dark greyish orange,#665343,102,83,67,27,20.7,33.1
grey,medium dark orange,Very dark greyish orange,#635a52,99,90,82,28,9.4,35.5
grey,yellow,Very dark greyish orange,#71706E,113,112,117,252,1.3,43.7
grey,dark magenta-pink,Very dark greyish pink,#3f313a,63,49,58,321,12.5,22.0
grey,medium dark magenta,Very dark greyish pink,#51354A,81,53,74,315,20.9,26.3
grey,medium dark magenta-pink,Very dark greyish pink,#614051,97,64,81,329,20.5,31.6
grey,medium dark pink,Very dark greyish pink,#534B4F,83,75,79,330,5.1,31.0
grey,medium dark pink,Very dark greyish pink,#6D4C5A,109,76,90,335,17.8,36.3
grey,medium dark pink,Very dark greyish pink,#704A59,112,74,89,336,20.4,36.5
grey,medium dark pink,Very dark greyish pink,#63424b,99,66,75,344,20.0,32.4
black,dark red,Very dark greyish red,#3B2F2F,59,47,47,0,11.3,20.8
black,dark red,Very dark greyish red,#43302E,67,31,26,7,18.6,22.2
black,dark red-orange,Very dark greyish red,#352925,53,41,37,15,17.8,17.6
grey,medium dark pink-red,Very dark greyish red,#4F3A3C,79,58,60,354,15.3,26.9
grey,medium dark pink-red,Very dark greyish red,#4d3b3c,77,59,60,356,13.2,26.7
brown,medium dark red,Very dark greyish red,#674846,103,76,71,9,19.1,33.9
brown,medium dark red,Very dark greyish red,#674C47,103,76,21,40,18.4,34.1
grey,medium dark red,Very dark greyish red,#6b4947,107,73,71,3,20.2,34.9
grey,medium dark red,Very dark greyish red,#645452,100,84,82,6,9.9,35.7
grey,medium dark red,Very dark greyish red,#4b3c39,75,60,57,9,13.6,25.9
grey,medium dark red,Very dark greyish red,#504040,80,64,77,311,11.1,28.2
grey,medium dark red-orange,Very dark greyish red,#543D37,84,61,55,12,20.9,27.3
grey,dark blue-magenta,Very dark greyish violet,#32293A,50,41,58,272,17.2,19.4
grey,medium dark blue-magenta,Very dark greyish violet,#614e6e,97,78,110,275,17.0,36.9
purple,medium dark blue-magenta,Very dark greyish violet,#503E5C,80,62,92,276,19.5,30.2
grey,dark yellow-green,Very dark greyish yellow,#3B3C36,59,60,54,70,5.3,22.4
grey,medium dark yellow,Very dark greyish yellow,#656255,101,98,85,48,8.6,36.5
grey,medium dark yellow,Very dark greyish yellow,#4d4b3a,77,75,58,53,14.1,26.5
grey,medium dark yellow,Very dark greyish yellow,#52503C,82,80,60,55,15.5,27.8
grey,medium dark yellow-green,Very dark greyish yellow,#52593b,82,89,59,73,20.3,29.0
grey,dark green,Very dark lime green,#006400,0,100,0,120,100.0,19.6
green,dark green,Very dark lime green,#195905,25,89,5,106,89.4,18.4
green,dark green,Very dark lime green,#136207,19,98,7,112,86.7,20.6
green,dark green,Very dark lime green,#046307,4,99,7,121,92.2,20.2
green,dark green,Very dark lime green,#056608,5,102,8,121,90.7,21.0
grey,dark green,Very dark lime green,#006600,0,102,0,120,100.0,20.0
purple,dark magenta,Very dark purple,#480656,72,6,86,290,87.0,18.0
purple,dark magenta,Very dark purple,#660066,102,0,102,300,100.0,20.0
purple,dark magenta,Very dark purple,#4E0041,78,0,65,310,100.0,15.3
purple,dark magenta,Very dark purple,#5A004A,90,0,74,311,100.0,17.6
purple,medium dark magenta,Very dark purple,#702670,112,38,112,300,49.3,29.4
purple,medium dark magenta,Very dark purple,#682860,104,40,96,308,44.4,28.2
purple,medium dark magenta,Very dark purple,#702963,112,41,99,311,46.4,30.0
black,very dark magenta,Very dark purple,#350036,53,0,54,299,100.0,10.6
black,very dark magenta,Very dark purple,#360029,54,0,41,314,100.0,10.6
brown,dark brown,Very dark brown,#663300,102,51,0,30,100.0,20.0
brown,dark brown,Very dark brown,#644117,100,65,23,33,62.6,24.1
brown,dark brown,Very dark brown,#674403,103,68,3,38,94.3,20.8
brown,dark brown,Very dark brown,#563c0d,86,60,13,38,73.7,19.4
brown,dark orange,Very dark brown,#59260B,89,38,11,0,78.0,19.6
brown,dark orange,Very dark brown,#5d3a1a,93,58,26,28,56.3,23.3
brown,dark orange,Very dark brown,#6e3a07,110,58,7,29,88.0,22.9
brown,medium dark brown,Very dark brown,#704214,112,66,20,30,69.7,25.9
brown,medium dark brown,Very dark brown,#654321,101,67,33,30,50.7,26.3
brown,medium dark orange,Very dark brown,#664228,102,66,40,25,43.7,27.8
brown,medium dark orange,Very dark brown,#6B4423,107,68,35,28,50.7,27.8
brown,medium dark yellow,Very dark brown,#6C541E,108,84,30,42,56.5,27.1
black,very dark orange,Very dark brown,#391802,57,24,2,24,93.2,11.6
purple,dark magenta,Very dark pink,#660045,102,0,69,319,100.0,20.0
purple,dark magenta,Very dark pink,#4D0135,77,1,53,319,97.4,15.3
purple,dark magenta-pink,Very dark pink,#66033c,102,3,60,325,94.3,20.6
purple,dark magenta-pink,Very dark pink,#66023C,102,2,60,325,96.2,20.4
black,dark pink,Very dark pink,#67032D,103,3,45,335,94.3,20.8
black,dark pink,Very dark pink,#3c1321,60,19,33,339,51.9,15.5
black,dark pink,Very dark pink,#3c1421,60,20,33,340,50.0,15.7
black,dark pink,Very dark pink,#560319,86,3,25,344,93.3,17.5
brown,dark pink,Very dark pink,#5f1933,95,25,51,337,58.3,23.5
purple,dark pink,Very dark pink,#551f2f,85,31,47,342,46.6,22.7
purple,medium dark magenta-pink,Very dark pink,#6d2b50,109,43,80,326,43.4,29.8
purple,medium dark pink,Very dark pink,#6E1C34,110,28,52,342,59.4,27.1
brown,dark red,Very dark red,#660000,102,0,0,0,100.0,20.0
brown,dark pink-red,Very dark red,#58111a,88,17,26,352,67.6,20.6
brown,dark pink-red,Very dark red,#65000B,101,0,11,353,100.0,19.8
brown,dark pink-red,Very dark red,#480607,72,6,7,359,84.6,15.3
purple,dark pink-red,Very dark red,#670F25,103,15,37,345,74.6,23.1
purple,dark pink-red,Very dark red,#660c21,102,12,33,346,78.9,22.4
black,dark red,Very dark red,#3C1414,60,20,20,0,50.0,15.7
brown,dark red,Very dark red,#630f0f,99,15,15,0,73.7,22.4
brown,dark red,Very dark red,#5d1916,93,25,22,2,61.7,22.5
brown,dark red,Very dark red,#651A14,101,26,20,4,66.9,23.7
brown,dark red,Very dark red,#592720,89,39,32,7,47.1,23.7
brown,dark red,Very dark red,#60281e,96,40,30,9,52.4,24.7
black,dark red-orange,Very dark red,#4E1609,78,22,9,11,79.3,17.1
brown,dark red-orange,Very dark red,#592b1f,89,43,31,12,48.3,23.5
brown,dark red-orange,Very dark red,#631800,99,24,0,15,100.0,19.4
brown,medium dark pink-red,Very dark red,#681C23,104,28,35,354,57.6,25.9
brown,medium dark red,Very dark red,#701C1C,112,28,28,0,60.0,27.5
brown,medium dark red,Very dark red,#672422,103,36,34,1,50.4,26.9
brown,medium dark red,Very dark red,#5e2824,94,40,36,4,44.6,25.5
brown,medium dark red,Very dark red,#6f3028,111,48,40,6,47.0,29.6
brown,medium dark red,Very dark red,#712F26,113,47,38,7,49.7,29.6
brown,medium dark red,Very dark red,#71291D,113,41,29,9,59.2,27.8
brown,medium dark red-orange,Very dark red,#6C2E1F,108,46,31,12,55.4,27.3
black,very dark pink-red,Very dark red,#3f000f,63,0,15,345,100.0,12.4
black,very dark pink-red,Very dark red,#490206,73,2,6,356,94.7,14.7
black,very dark red,Very dark red,#3D0C02,61,12,2,10,93.7,12.4
purple,dark blue-magenta,Very dark violet,#290C5E,41,12,94,261,77.4,20.8
purple,dark blue-magenta,Very dark violet,#32174D,50,23,77,270,54.0,19.6
purple,dark blue-magenta,Very dark violet,#310062,49,0,98,270,100.0,19.2
purple,dark blue-magenta,Very dark violet,#330066,51,0,102,270,100.0,20.0
purple,dark magenta,Very dark violet,#350E47,53,14,87,272,67.1,16.7
purple,dark magenta,Very dark violet,#431c53,67,28,83,282,49.5,21.8
brown,dark yellow,Very dark olive,#514100,81,65,0,48,100.0,15.9
grey,dark yellow-green,Very dark olive,#4B5320,75,83,32,69,44.3,22.5
grey,medium dark yellow,Very dark olive,#665D1E,102,93,30,53,54.5,25.9
grey,medium dark yellow,Very dark olive,#716E10,113,110,16,58,75.2,25.3
purple,light blue-magenta,Very light blue-purple,#9999FF,153,153,255,240,100.0,80.0
purple,light blue-magenta,Very light blue-purple,#8080FF,128,128,255,240,100.0,75.1
blue,medium light cyan-blue,Very light cyan-blue,#7eb6ff,126,182,255,213,100.0,74.7
cyan,medium light cyan,Very light cyan,#7DF9FF,125,249,255,183,100.0,74.5
cyan,medium light green-cyan,Very light cyan-green,#7FFFD4,127,255,212,160,100.0,74.9
green,medium light green,Very light green,#9FFF7F,159,255,127,105,100.0,74.9
grey,very light grey,Very light grey,#DCDCDC,220,220,220,0,0.0,86.3
grey,very light grey,Very light grey,#DADADA,218,218,218,0,0.0,85.5
white,very light grey,Greyish white,#f8f8f8,248,248,248,0,0.0,97.3
white,very light grey,Greyish white,#F5F5F5,245,245,245,0,0.0,96.1
green,light green,Very light lime green,#98FF98,152,255,152,120,100.0,79.8
pink,light magenta,Very light purple,#ff80ff,255,128,255,300,100.0,75.1
purple,light magenta,Very light purple,#E285FF,226,133,255,286,100.0,76.1
pink,medium light magenta,Very light purple,#FF6FFF,255,111,255,300,100.0,71.8
pink,medium light magenta,Very light purple,#FF77FF,255,119,255,300,100.0,73.3
purple,medium light magenta,Very light purple,#DF73FF,223,115,255,286,100.0,72.5
brown,light brown,Very light orange,#FFCC99,255,204,153,30,100.0,80.0
orange,light orange,Very light orange,#FFB280,255,178,128,24,100.0,75.1
pink,light red-orange,Very light orange,#FFAA8D,255,170,141,15,100.0,77.6
orange,light yellow,Very light orange,#FFBD88,255,189,136,27,100.0,76.7
brown,medium light brown,Very light orange,#ffc87c,255,200,124,34,100.0,74.3
orange,medium light orange,Very light orange,#ffa26b,255,162,107,22,100.0,71.0
orange,medium light orange,Very light orange,#ffb077,255,176,119,25,100.0,73.3
brown,medium light red-orange,Very light orange,#FFA07A,255,160,122,17,100.0,73.9
pink,light magenta-pink,Very light pink,#ff85cf,255,133,207,323,100.0,76.1
pink,light pink,Very light pink,#ff99cc,255,153,204,330,100.0,80.0
pink,light pink,Very light pink,#FF91AF,255,145,175,344,100.0,78.4
pink,medium light pink,Very light pink,#FF69B4,255,105,180,330,100.0,70.6
pink,light red,Very light red,#FF9999,255,153,153,0,100.0,80.0
pink,light pink-red,Very light red,#FF91A4,255,145,164,350,100.0,78.4
pink,light pink-red,Very light red,#ff878d,255,135,141,357,100.0,76.5
pink,light pink-red,Very light red,#ff9899,255,152,153,359,100.0,79.8
orange,light red-orange,Very light red,#FF9980,255,153,128,12,100.0,75.1
pink,light red-orange,Very light red,#FFA089,255,160,137,12,100.0,76.9
pink,medium light pink-red,Very light red,#FF7077,255,112,119,357,100.0,72.0
orange,medium light red-orange,Very light red,#FF8C69,255,140,105,14,100.0,70.6
purple,light blue-magenta,Very light violet,#CC99FF,204,153,255,270,100.0,80.0
yellow,light yellow,Very light yellow,#FFEC8B,255,236,139,50,100.0,77.3
yellow,light yellow-green,Very light yellow,#FFFF99,255,255,153,60,100.0,80.0
yellow,medium light yellow,Very light yellow,#ffe670,255,230,112,49,100.0,72.0
white,very light blue-magenta,Blueish white,#F8F8FF,248,248,255,240,100.0,98.6
white,very light cyan-blue,Blueish white,#F0F8FF,240,248,255,208,100.0,97.1
white,very light cyan,White,#F0FFFF,240,255,255,180,100.0,97.1
white,very light cyan,White,#F5FFFF,245,255,255,180,100.0,98.0
white,very light cyan,Cyan tint white,#E7FEFF,231,254,255,183,100.0,95.3
white,very light cyan,White,#EDFEFF,237,254,255,183,100.0,96.5
white,very light green-cyan,White,#F5FFFA,245,255,250,150,100.0,98.0
white,very light green,White,#F0FFF0,240,255,240,120,100.0,97.1
white,very light brown,White,#FFF9F0,255,249,240,36,100.0,97.1
white,very light brown,White,#FFF8ED,255,248,237,37,100.0,96.5
white,very light brown,White,#FFFAF0,255,250,240,40,100.0,97.1
white,very light orange,White,#FFF5EE,255,245,238,25,100.0,96.7
white,very light red-orange,White,#FFF1EB,255,241,235,18,100.0,96.1
white,very light yellow,White,#FFF8E7,255,248,231,43,100.0,95.3
white,very light magenta,Pinkish white,#FFF1FB,255,241,251,317,100.0,97.3
white,very light magenta-pink,Pinkish white,#FFF3FA,255,243,250,325,100.0,97.6
white,very light pink,Pinkish white,#FFF9FB,255,245,251,324,100.0,98.8
white,very light pink,Pinkish white,#FFF0F5,255,240,245,340,100.0,97.1
pink,very light red,Reddish white,#FFE6E6,255,230,230,0,100.0,95.1
white,very light red,White,#FFFAFA,255,250,250,0,100.0,99.0
white,very light red,White,#FFFBFB,255,251,251,0,100.0,99.2
white,very light red,Reddish white,#FFF0EE,255,240,238,7,100.0,96.7
white,very light red,Reddish white,#FFF6F5,255,246,243,15,100.0,98.0
white,very light blue-magenta,Purplish white,#f8f4ff,248,244,255,261,100.0,97.8
white,very light yellow-green,White,#FFFFF0,255,255,240,60,100.0,97.1
white,very light yellow-green,White,#fdfff5,253,255,245,71,100.0,98.0
purple,very light blue-magenta,Very light blue-purple,#CCCCFF,204,204,255,240,100.0,90.0
purple,very light blue-magenta,Very light blue-purple,#C7C1FF,199,193,255,246,100.0,87.8
cyan,very light cyan,Very pale cyan,#E0FFFF,224,255,255,180,100.0,93.9
green,very light green-cyan,Very pale cyan,#DBFFF8,219,255,248,168,100.0,92.9
cyan,very light green-cyan,Very light green-cyan,#C9FFE5,201,255,229,151,100.0,89.4
green,very light green,Very pale green,#E9FFD8,233,255,219,97,100.0,92.4
green,very light green,Very pale green,#E9FFDB,233,255,219,97,100.0,92.9
pink,very light magenta,Very pale purple,#FFCCFF,255,204,255,300,100.0,90.0
pink,very light magenta,Very pale purple,#FFD3F8,255,211,248,310,100.0,91.4
brown,very light orange,Very pale orange,#ffe4cd,255,228,205,27,100.0,90.2
brown,very light brown,Very pale orange,#ffe9d1,255,233,209,31,100.0,91.0
brown,very light brown,Very pale orange,#FFE4C4,255,228,196,33,100.0,88.4
brown,very light brown,Very pale orange,#FFF0DB,255,240,219,35,100.0,92.9
brown,very light brown,Very pale orange,#FFEBCD,255,235,205,36,100.0,90.2
brown,very light brown,Very pale orange,#FFEFD5,255,239,213,37,100.0,91.8
grey,very light brown,Very pale orange,#FFF0E0,255,240,224,31,100.0,93.9
pink,very light orange,Very pale orange,#FFDDCA,255,221,202,22,100.0,89.6
pink,very light red-orange,Very pale orange,#FFDDCF,255,221,207,18,100.0,90.6
pink,very light magenta,Very pale pink,#FFDDF4,255,221,207,18,100.0,93.3
pink,very light magenta,Very pale pink,#ffcff1,255,207,241,317,100.0,90.6
pink,very light magenta-pink,Very pale pink,#FFc1E8,255,193,232,322,100.0,87.8
pink,very light magenta-pink,Very pale pink,#FFE1F2,255,225,242,326,100.0,94.1
pink,very light pink,Very pale pink,#FFDAE9,255,218,233,336,100.0,92.7
pink,very light pink,Very pale pink,#FFCBDB,255,192,203,350,100.0,89.8
pink,very light pink-red,Very pale red,#FFE4E9,255,228,233,349,100.0,94.7
pink,very light pink-red,Very pale red,#ffc1cc,255,193,204,349,100.0,87.8
pink,very light pink-red,Very pale red,#FFC0CB,255,192,203,350,100.0,87.6
pink,very light red,Pale pink,#ffcccb,255,204,203,1,100.0,89.8
pink,very light red,Pale pink,#FFDCD6,255,220,214,9,100.0,92.0
white,very light red,Pale pink,#FFE4E1,255,228,225,6,100.0,94.1
purple,very light blue-magenta,Very pale violet,#DCD0FF,220,208,255,255,100.0,90.8
grey,very light yellow,Very pale yellow,#FFF8DC,255,248,220,48,100.0,93.1
white,very light yellow-green,Very pale yellow,#FFFFE0,255,255,224,60,100.0,93.9
yellow,very light yellow,Very pale yellow,#FFFACD,255,250,205,54,100.0,90.2
yellow,very light yellow,Very pale yellow,#FFFDD0,255,253,208,57,100.0,90.8
white,very light yellow-green,Very pale yellow,#ffffcc,255,255,204,60,100.0,90.0
white,very light yellow-green,Very pale yellow,#f9ffe3,249,255,227,72,100.0,94.5
blue,light blue,Very soft blue,#ACB8E8,172,184,232,228,56.6,79.2
blue,light blue,Very soft blue,#B3BCE2,179,188,226,229,44.8,79.4
purple,light blue-magenta,Very soft blue,#ACACE6,172,172,230,240,53.7,78.8
purple,light blue-magenta,Very soft blue,#C1BBEC,193,187,236,247,56.3,82.9
purple,light blue-magenta,Very soft blue,#A899E6,168,153,230,252,60.6,75.1
blue,light cyan-blue,Very soft blue,#A8D9F3,168,217,243,201,75.8,80.6
blue,light cyan-blue,Very soft blue,#B9D9EB,185,217,235,202,55.6,82.4
blue,light cyan-blue,Very soft blue,#AFDBF5,175,219,245,202,77.8,82.4
blue,light cyan-blue,Very soft blue,#A1CAF1,161,202,241,209,74.1,78.8
blue,light cyan-blue,Very soft blue,#abcdef,171,205,239,210,68.0,80.4
blue,light cyan-blue,Very soft blue,#B0C4DE,176,196,222,214,41.1,78.0
purple,medium light blue-magenta,Very soft blue,#8581D9,133,129,217,243,53.7,67.8
purple,medium light blue-magenta,Very soft blue,#9683EC,150,131,236,251,73.4,72.0
blue,medium light cyan,Very soft blue,#87CEEB,135,206,235,197,71.4,72.5
blue,medium light cyan,Very soft blue,#89CFF0,137,207,240,199,77.4,73.9
blue,medium light cyan-blue,Very soft blue,#93CCEA,147,204,234,201,67.4,74.7
blue,medium light cyan-blue,Very soft blue,#9BC4E2,155,196,226,205,55.0,74.7
blue,medium light cyan-blue,Very soft blue,#8AB9F1,138,185,241,213,78.6,74.3
blue,medium light cyan-blue,Very soft blue,#88ace0,136,172,224,215,58.7,70.6
blue,medium light cyan-blue,Very soft blue,#7c9ed9,124,158,217,218,55.0,66.9
blue,light cyan,Very soft cyan,#a7d8de,167,216,222,186,45.5,76.3
blue,light cyan,Very soft cyan,#B0E0E6,176,224,230,187,51.9,79.6
blue,light cyan,Very soft cyan,#ACE5EE,172,229,238,188,66.0,80.4
blue,light cyan,Very soft cyan,#A3E3ED,163,227,237,188,67.3,78.4
blue,light cyan,Very soft cyan,#A4DDED,164,221,237,193,67.0,78.6
blue,light cyan,Very soft cyan,#ADD8E6,173,216,230,195,53.3,79.0
cyan,light cyan,Very soft cyan,#AFE4DE,175,228,222,173,49.5,79.0
cyan,light cyan,Very soft cyan,#AFEEEE,175,238,238,180,64.9,81.0
cyan,light cyan,Very soft cyan,#a4f4f9,164,244,249,183,87.6,81.0
cyan,medium light cyan,Very soft cyan,#8DDCD3,141,220,211,173,53.0,70.8
cyan,medium light green-cyan,Very soft cyan,#96DED1,150,222,209,169,52.2,72.9
cyan,medium light green-cyan,Very soft cyan,#8DD9CC,141,217,204,170,50.0,70.2
cyan,light green-cyan,Very soft green-cyan,#AAF0D1,170,240,209,153,70.0,80.4
green,light green-cyan,Very soft green-cyan,#99e6b3,153,230,179,140,60.6,75.1
green,light green-cyan,Very soft green-cyan,#9FE2BF,159,226,191,149,53.6,75.5
green,light green,Very soft green,#c1f9a2,193,249,162,98,87.9,80.6
green,light green,Very soft green,#D0F0C0,208,240,192,100,61.5,84.7
green,medium light yellow-green,Very soft green,#C5E384,197,227,132,79,62.9,70.4
green,light green,Very soft lime green,#A8E4A0,168,228,160,113,55.7,76.1
green,light green,Very soft lime green,#ADDFAD,173,223,173,120,43.9,77.6
green,light green,Very soft lime green,#98FB98,152,251,152,120,92.5,79.0
green,light green,Very soft lime green,#ACE1AF,172,225,175,123,46.9,77.8
green,medium light green,Very soft lime green,#90EE90,144,238,144,120,73.4,74.9
green,medium light green,Very soft lime green,#85EA85,133,234,133,120,70.6,72.0
purple,light magenta,Very soft magenta,#D399E6,211,153,230,285,60.6,75.1
purple,light magenta,Very soft magenta,#D891EF,216,145,239,285,74.6,75.3
purple,light magenta,Very soft magenta,#DB91EF,219,145,239,287,74.6,75.3
purple,light magenta,Very soft magenta,#F1A7FE,241,167,254,291,97.8,82.5
purple,light magenta,Very soft magenta,#E6A8D7,230,168,215,315,55.4,78.0
pink,medium light magenta,Very soft magenta,#E68CD2,230,140,210,313,64.3,72.5
purple,medium light magenta,Very soft magenta,#DDA0DD,221,160,221,300,47.3,74.7
purple,medium light magenta,Very soft magenta,#E29CD2,226,156,210,314,54.7,74.9
pink,very light magenta,Very soft magenta,#F8C3F8,248,195,248,300,79.1,86.9
brown,light brown,Light brown,#e7c9a9,231,201,169,30,56.4,78.4
brown,light brown,Light brown,#FED8B1,254,216,177,30,97.5,84.5
brown,light brown,Light brown,#f7c58e,247,197,142,31,86.8,76.3
brown,light brown,Light brown,#FAD6A5,250,214,165,35,89.5,81.4
brown,light brown,Light brown,#e6d0ab,230,208,171,37,54.1,78.6
brown,light brown,Light brown,#FADFAD,250,223,173,39,88.5,82.9
brown,light brown,Light brown,#F5DEB3,245,222,179,39,76.7,83.1
brown,light orange,Light orange,#EFCDBB,239,205,187,21,61.9,83.5
brown,light orange,Light orange,#EFCDB8,239,205,184,23,63.2,82.9
brown,light orange,Light orange,#FBCEB1,251,206,177,24,90.2,83.9
brown,light orange,Light orange,#EDC9Af,237,201,175,25,63.3,80.8
brown,light orange,Light orange,#e2be9f,226,190,159,27,53.6,75.5
brown,light orange,Light orange,#FDD5B1,253,213,177,28,95.0,84.3
brown,light red-orange,Very soft orange,#EBC2AF,235,194,175,19,60.0,80.4
pink,light red-orange,Very soft orange,#F7CDB9,247,205,185,19,79.5,84.7
brown,light yellow,Very soft orange,#ECD9B0,236,217,176,41,61.2,80.8
brown,light yellow,Very soft orange,#FAE7B5,250,231,181,43,87.3,84.5
brown,light yellow,Very soft orange,#FBE7B2,251,231,128,50,90.1,84.1
grey,light yellow,Very soft orange,#EFDFBB,239,223,187,42,61.9,83.5
brown,medium light brown,Very soft brown,#DEB887,222,184,135,34,56.9,70.0
brown,medium light brown,Very soft brown,#EAC592,234,197,146,35,67.7,74.5
orange,medium light brown,Very soft brown,#E6BE8A,230,190,138,34,64.8,72.2
brown,medium light orange,Very soft brown,#DDAD95,221,173,149,20,51.4,72.5
brown,medium light orange,Very soft brown,#DEAA88,222,170,136,24,56.6,70.2
brown,very light orange,Very soft brown,#FDD9B5,253,217,181,30,94.7,85.1
pink,light magenta,Very soft pink,#FBA0E3,251,160,227,316,91.9,80.6
pink,light magenta-pink,Very soft pink,#E79EC5,231,94,197,315,60.3,76.3
pink,light magenta-pink,Very soft pink,#ebb0d7,235,176,215,320,59.6,80.6
pink,light magenta-pink,Very soft pink,#F1B2DC,248,170,221,321,69.2,82.2
pink,light magenta-pink,Very soft pink,#F8AADD,248,170,221,321,84.8,82.0
pink,light magenta-pink,Very soft pink,#e7accf,231,172,207,324,55.1,79.0
pink,light magenta-pink,Very soft pink,#E79FC4,231,159,196,329,60.0,76.5
pink,light pink,Very soft pink,#FBAED2,251,174,210,332,90.6,83.3
pink,light pink,Very soft pink,#f49ac2,244,154,194,333,80.4,78.0
pink,light pink,Very soft pink,#f8b9d4,248,185,212,334,81.8,84.9
pink,light pink,Very soft pink,#eda6c4,237,166,196,334,66.4,79.0
pink,light pink,Very soft pink,#F0B7CD,240,183,205,337,65.5,82.9
pink,light pink,Very soft pink,#EDBACD,237,186,205,338,58.6,82.9
pink,light pink,Very soft pink,#F19CBB,241,156,187,338,75.2,77.8
pink,light pink,Very soft pink,#EF9BB9,239,155,185,339,72.4,77.3
pink,light pink,Very soft pink,#F4BBCF,244,187,207,339,72.2,84.5
pink,light pink,Very soft pink,#F6ADC6,246,173,198,339,80.2,82.2
pink,light pink,Very soft pink,#EFBBCC,239,187,204,340,61.9,83.5
pink,light pink,Very soft pink,#f29cb7,242,156,183,341,76.8,78.0
pink,light pink,Very soft pink,#F2BDCD,242,189,205,342,67.1,84.5
pink,light pink,Very soft pink,#fc8eac,252,142,172,343,94.8,77.3
pink,light pink,Very soft pink,#F38FA9,243,143,169,344,80.6,75.7
pink,light pink,Very soft pink,#F091A9,240,145,169,345,76.0,75.5
pink,medium light magenta-pink,Medium light pink,#D987B9,217,135,185,323,51.9,69.0
pink,medium light magenta-pink,Medium light pink,#DF84B5,223,132,181,328,58.7,69.6
purple,medium light magenta-pink,Medium light pink,#D982B5,217,130,181,325,53.4,68.0
pink,medium light pink,Medium light pink,#E38FB7,227,143,183,331,60.0,72.5
pink,medium light pink,Medium light pink,#D98AA8,217,138,168,337,51.0,69.6
pink,medium light pink,Medium light pink,#DE98B2,222,152,178,338,51.5,73.3
pink,medium light pink,Medium light pink,#DC9DB3,220,157,179,339,47.4,73.9
pink,medium light pink,Medium light pink,#EA88A8,234,136,168,340,70.0,72.5
pink,medium light pink,Medium light pink,#E68FAC,230,143,172,340,63.5,73.1
pink,very light magenta-pink,Very soft pink,#F8C3DF,248,195,223,328,79.1,86.9
pink,very light pink,Very soft pink,#FBBEDA,251,190,218,332,88.4,86.5
brown,light pink-red,Very soft red,#ddadaf,221,173,175,357,41.4,77.3
pink,light pink-red,Very soft red,#f498ad,244,152,173,346,80.7,77.6
pink,light pink-red,Very soft red,#F78FA7,247,143,167,346,86.7,76.5
pink,light pink-red,Very soft red,#EF98AA,239,152,170,348,73.1,76.7
pink,light pink-red,Very soft red,#f29eab,242,158,171,350,76.4,78.4
pink,light pink-red,Very soft red,#ED999C,237,153,156,358,70.0,76.5
pink,light pink-red,Very soft red,#f08f90,240,143,144,359,76.4,75.1
brown,light red,Light red,#E7BCB4,231,188,180,9,51.5,80.6
pink,light red,Light red,#DEA5A4,222,165,164,1,46.8,75.7
pink,light red,Light red,#FEB4B1,254,180,177,2,97.5,84.5
pink,light red,Light red,#fdbcb4,253,188,180,6,94.8,84.9
pink,light red,Light red,#f6a494,246,164,148,9,84.5,77.3
pink,light red,Light red,#FEBAAD,254,186,173,10,97.6,83.7
red,light red,Light red,#f39998,243,153,152,0,79.1,77.5
orange,light red-orange,Light red-orange,#f6a08c,246,160,140,11,85.5,75.7
pink,medium light pink-red,Medium light red,#D98695,217,134,149,349,52.2,68.8
pink,medium light pink-red,Medium light red,#d998a0,217,152,160,352,46.1,72.4
pink,medium light pink-red,Medium light red,#e18e96,225,142,150,354,58.0,72.0
pink,medium light pink-red,Medium light red,#EA9399,234,147,153,356,67.4,74.7
brown,medium light red,Medium light red,#e7968b,231,150,139,7,65.7,72.5
brown,medium light red-orange,Medium light red,#E1AD9D,225,173,157,14,53.1,74.9
pink,very light pink-red,Very light red,#FBBBC4,251,197,196,1,88.9,85.9
pink,very light red,Very light red,#F4C2C2,222,194,194,0,69.4,85.9
pink,very light red,Very light red,#F7BFBE,247,191,190,1,78.1,85.7
pink,very light red,Very light red,#F5C5C2,245,197,194,4,71.8,86.1
pink,very light red,Very light red,#FDBFB7,253,191,183,7,94.6,85.5
pink,very light red-orange,Very light red,#fcc9b9,252,201,185,14,91.8,85.7
purple,light blue-magenta,Very soft violet,#CDB7F0,205,183,240,263,65.5,82.9
purple,light blue-magenta,Very soft violet,#CFBAEC,207,186,236,265,56.8,82.7
purple,light magenta,Very soft violet,#D19FE8,209,159,232,281,61.3,76.7
purple,light magenta,Very soft violet,#cda4de,205,164,222,282,46.8,75.7
purple,medium light blue-magenta,Very soft violet,#b19cd9,177,156,217,260,44.5,73.1
purple,medium light blue-magenta,Very soft violet,#B89BDD,184,155,221,266,49.3,73.7
purple,medium light blue-magenta,Very soft violet,#BA93DF,186,147,223,271,54.3,72.5
purple,medium light blue-magenta,Very soft violet,#BF94E4,191,148,228,272,59.7,73.7
purple,medium light blue-magenta,Very soft violet,#B57EDC,181,126,220,275,57.3,67.8
purple,medium light magenta,Very soft violet,#C9A0DC,201,160,220,281,46.2,74.5
purple,very light blue-magenta,Very soft violet,#D0BEF8,208,190,248,259,80.6,85.9
brown,light yellow,Very soft yellow,#eee0b1,238,224,177,46,64.2,81.4
yellow,light yellow,Very soft yellow,#F3E5AB,243,229,171,48,75.0,81.2
yellow,light yellow,Very soft yellow,#f7e98e,247,233,142,51,86.8,76.3
yellow,light yellow,Very soft yellow,#f0e891,240,232,145,55,76.0,75.5
yellow,light yellow,Very soft yellow,#EEE8AA,238,232,170,55,66.7,80.0
green,light yellow-green,Light yellow-green,#EFF7AA,239,247,170,66,82.8,81.8
green,light yellow-green,Light yellow-green,#E8F48C,232,244,140,67,82.5,75.3
grey,light yellow-green,Light yellow-green,#EAEDA6,234,237,166,63,66.4,79.0
yellow,light yellow-green,Light yellow-green,#fdfd96,253,253,150,60,96.3,79.0
yellow,light yellow-green,Light yellow-green,#F7FA97,247,250,151,62,90.8,78.6
grey,medium light yellow,Medium light yellow,#F0E68C,240,230,140,54,76.9,74.5
grey,medium light yellow,Medium light yellow,#E8E08E,232,224,142,55,66.2,73.3
yellow,medium light yellow,Medium light yellow,#F1E788,242,231,136,54,78.9,73.9
green,medium light yellow-green,Medium light yellow-green,#E2EE83,226,238,131,67,75.9,72.4
green,medium light yellow-green,Medium light yellow-green,#D4E29B,212,226,155,72,55.0,74.7
green,medium light yellow-green,Medium light yellow-green,#c9dc87,201,220,135,73,54.8,69.6
green,medium light yellow-green,Medium light yellow-green,#C9DC89,202,220,137,73,54.2,70.0
green,medium light yellow-green,Medium light yellow-green,#D1E189,200,225,137,77,59.5,71.0
brown,very light yellow,Very light yellow,#FAF0BE,250,240,190,50,85.7,86.3
grey,very light yellow,Very light yellow,#F6EABE,246,234,190,47,75.7,85.5
green,very light yellow-green,Very light yellow-green,#F3FDC6,243,253,198,71,93.2,88.4
blue,blue,Vivid blue,#0247FE,2,71,254,224,99.2,50.2
blue,blue-magenta,Vivid blue,#1c1cf0,28,28,240,240,87.6,52.5
blue,cyan,Vivid blue,#0FC0FC,15,192,252,195,97.5,52.4
blue,cyan-blue,Vivid blue,#0F9DEB,15,157,235,201,88.0,49.0
blue,cyan-blue,Vivid blue,#1f8eed,31,142,237,207,85.1,52.5
blue,cyan-blue,Vivid blue,#1E90FF,30,144,255,210,100.0,55.9
blue,cyan-blue,Vivid blue,#1F75FE,31,117,254,217,99.1,55.9
blue,cyan-blue,Vivid blue,#2C75FF,44,117,255,219,100.0,58.6
blue,medium light cyan-blue,Vivid blue,#3399ff,51,153,255,210,100.0,60.0
blue,cyan,Vivid cyan,#15F4EE,21,244,238,178,91.0,52.0
blue,cyan,Vivid cyan,#1ac1dd,26,193,221,188,78.9,48.4
blue,cyan,Vivid cyan,#0cbfe9,12,191,233,191,90.2,48.0
cyan,cyan,Vivid cyan,#08E8DE,8,232,222,177,93.3,47.1
cyan,cyan,Vivid cyan,#15f2fd,21,242,253,182,98.3,53.7
cyan,medium light green-cyan,Vivid cyan,#33FFCC,51,255,204,165,100.0,60.0
green,green-cyan,Vivid green-cyan,#0BDA51,11,218,81,140,90.4,44.9
green,green,Vivid green,#ADFF2F,173,255,47,84,100.0,59.2
green,green,Vivid green,#87FF2A,135,255,42,94,100.0,58.2
green,green,Vivid lime green,#39FF14,57,255,20,111,100.0,53.9
pink,magenta,Vivid purple,#EF1DE7,239,29,231,302,86.8,52.5
pink,magenta,Vivid purple,#ff1dce,255,29,206,313,100.0,55.7
purple,magenta,Vivid purple,#b80ce3,184,12,227,288,90.0,46.9
purple,magenta,Vivid purple,#C316E9,195,22,233,289,82.7,50.0
brown,brown,Vivid brown,#f28e1c,242,142,28,31,89.2,52.9
brown,brown,Vivid brown,#ED9121,237,145,33,33,85.0,52.9
brown,brown,Vivid brown,#e08a1e,224,138,30,33,76.4,49.8
brown,brown,Vivid brown,#EAA221,234,162,33,39,82.7,52.4
brown,brown,Vivid brown,#E49B0F,228,155,15,39,87.7,47.6
orange,brown,Vivid brown,#ffa631,255,166,49,34,100.0,59.6
orange,brown,Vivid brown,#fb9912,251,153,18,34,96.7,52.7
orange,brown,Vivid brown,#FF9505,255,149,5,36,100.0,51.0
orange,brown,Vivid brown,#fb9902,251,153,2,36,98.4,49.6
orange,brown,Vivid brown,#FFAA1D,255,170,29,37,100.0,55.7
orange,brown,Vivid brown,#FE9D04,254,157,4,37,99.2,50.6
orange,brown,Vivid brown,#ffa812,255,168,18,37,100.0,53.5
orange,brown,Vivid brown,#EF9B0F,239,155,15,38,88.2,49.8
orange,medium light brown,Medium light brown,#FF9933,255,153,51,30,100.0,60.0
orange,orange,Vivid orange,#FF6103,255,97,3,22,100.0,50.6
orange,orange,Vivid orange,#FF7518,255,117,24,24,100.0,54.7
orange,orange,Vivid orange,#da680f,218,104,15,26,87.1,45.7
orange,orange,Vivid orange,#FF7802,255,120,2,28,100.0,50.4
orange,red-orange,Vivid orange,#fb4f14,251,79,20,15,96.7,53.1
orange,red-orange,Vivid orange,#fe5a1d,254,90,29,16,99.1,55.5
orange,red-orange,Vivid orange,#FC5110,252,81,16,17,97.5,52.5
orange,red-orange,Vivid orange,#ff631c,255,99,28,18,100.0,55.5
orange,red-orange,Vivid orange,#eb6123,235,97,35,18,83.3,52.9
orange,red-orange,Vivid orange,#FF681F,255,104,31,20,100.0,56.1
brown,yellow,Yellow,#DAA520,218,165,32,43,74.4,49.0
brown,yellow,Yellow,#e1ad21,225,173,33,43,76.2,50.6
orange,yellow,Yellow,#ffb61e,255,182,30,40,100.0,55.9
yellow,yellow,Yellow,#f6b511,246,181,17,42,92.7,51.6
yellow,yellow,Yellow,#ffc324,255,195,36,43,100.0,57.1
yellow,yellow,Yellow,#F5BD1F,245,189,31,44,91.5,54.1
yellow,yellow,Yellow,#FDBE02,253,190,2,46,98.4,50.0
pink,magenta,Vivid pink,#FC0FC0,252,15,192,315,97.5,52.4
pink,magenta,Vivid pink,#E010A8,224,16,168,316,86.7,47.1
pink,magenta,Vivid pink,#F00BA4,240,11,164,320,91.2,49.2
pink,magenta-pink,Vivid pink,#FF1CB1,255,28,177,321,100.0,55.5
pink,magenta-pink,Vivid pink,#e0218a,224,33,138,327,75.5,50.4
pink,magenta-pink,Vivid pink,#DA1884,218,24,132,327,80.2,47.5
pink,magenta-pink,Vivid pink,#DA1D81,218,29,129,328,76.5,48.4
pink,magenta-pink,Vivid pink,#FF1493,255,20,147,328,100.0,53.9
pink,magenta-pink,Vivid pink,#fa1a8e,250,26,142,328,95.7,54.1
pink,medium light magenta,Vivid pink,#FF33CC,255,51,204,315,100.0,60.0
pink,medium light pink,Vivid pink,#FF3399,255,51,153,330,100.0,60.0
pink,pink,Vivid pink,#f7238a,247,35,138,330,93.0,55.3
pink,pink,Vivid pink,#F8227F,248,34,127,334,93.9,55.3
pink,pink,Vivid pink,#E0115F,224,17,95,337,85.9,47.3
pink,pink,Vivid pink,#E30B5D,227,11,93,337,90.8,46.7
red,pink,Vivid pink,#E30B5C,227,11,92,338,90.8,46.7
pink,pink-red,Vivid red,#E51A4C,229,26,76,345,79.6,50.0
pink,pink-red,Vivid red,#FF2052,255,32,82,347,100.0,56.3
pink,pink-red,Vivid red,#EE204D,238,32,77,347,85.8,52.9
pink,pink-red,Vivid red,#FD0E35,253,14,53,350,98.4,52.4
pink,pink-red,Vivid red,#E8192F,232,25,47,354,81.8,50.4
pink,pink-red,Vivid red,#ec2131,236,33,49,355,84.2,52.7
red,pink-red,Vivid red,#FF033E,255,3,62,346,100.0,50.6
red,pink-red,Vivid red,#DC143C,220,20,60,348,83.3,47.1
red,pink-red,Vivid red,#E2062C,226,6,44,350,94.8,45.5
red,pink-red,Vivid red,#ff1b2d,255,27,45,355,100.0,55.3
red,pink-red,Vivid red,#f70d1a,247,13,26,356,93.6,51.0
red,pink-red,Vivid red,#ec1c24,236,28,36,357,84.6,51.8
red,pink-red,Vivid red,#ED1C24,237,28,36,358,85.3,52.0
red,red,Vivid red,#E62020,230,32,32,0,79.8,51.4
red,red,Vivid red,#FE2712,254,39,18,5,99.2,53.3
red,red,Vivid red,#D9381E,217,56,30,8,75.7,48.4
orange,red-orange,Vivid red,#ff4e20,255,78,32,12,100.0,56.3
orange,red-orange,Vivid red,#f04e1f,240,78,31,13,87.4,53.1
red,red-orange,Vivid red,#ff3503,255,53,3,11,100.0,50.6
purple,blue-magenta,Vivid violet,#5218FA,82,24,250,255,95.8,53.7
purple,blue-magenta,Vivid violet,#791CF8,121,28,248,265,94.0,54.1
purple,blue-magenta,Vivid violet,#A020F0,160,92,240,268,87.4,53.3
purple,magenta,Vivid violet,#BC13FE,188,19,254,283,99.2,53.5
yellow,medium light yellow,Vivid yellow,#FFCC33,255,204,51,45,100.0,60.0
yellow,medium light yellow-green,Vivid yellow,#FFFF33,255,255,51,60,100.0,60.0
yellow,yellow,Vivid yellow,#ffc922,255,201,34,45,100.0,56.7
yellow,yellow,Vivid yellow,#FFC40C,255,196,12,45,100.0,52.4
yellow,yellow,Vivid yellow,#e1ad01,225,173,1,46,99.1,44.3
yellow,yellow,Vivid yellow,#FFD230,255,210,48,47,100.0,59.4
yellow,yellow,Vivid yellow,#fdcc0d,253,204,13,47,98.4,52.2
yellow,yellow,Vivid yellow,#F5C71A,245,199,26,47,91.6,53.1
yellow,yellow,Vivid yellow,#FFC901,255,201,1,47,100.0,50.2
yellow,yellow,Vivid yellow,#d9b611,217,182,17,49,85.5,45.9
yellow,yellow,Vivid yellow,#F4CA16,244,202,22,49,91.0,52.2
yellow,yellow,Vivid yellow,#ffdd05,255,221,5,51,100.0,51.0
yellow,yellow,Vivid yellow,#FCD917,252,217,23,51,97.4,53.9
yellow,yellow,Vivid yellow,#EED202,238,210,2,53,98.3,47.1
yellow,yellow,Vivid yellow,#FFE302,255,227,2,53,100.0,50.4
yellow,yellow,Vivid yellow,#E4D00A,228,208,10,54,91.6,46.7
yellow,yellow,Vivid yellow,#FFE816,255,232,28,54,100.0,54.3
yellow,yellow,Vivid yellow,#FDE910,253,233,16,55,98.3,52.7
yellow,yellow,Vivid yellow,#EEED09,238,237,9,60,92.7,48.4
green,yellow-green,Vivid yellow-green,#CAE00D,202,224,13,66,89.0,46.5
green,yellow-green,Vivid yellow-green,#C6E610,193,230,16,70,87.0,48.2
green,yellow-green,Vivid yellow-green,#D0FF14,208,255,20,72,100.0,53.9
yellow,yellow-green,Vivid yellow,#FEFE22,254,254,34,60,99.1,56.5
yellow,yellow-green,Vivid yellow,#FDFD02,255,253,2,60,98.4,50.0
yellow,yellow-green,Vivid yellow,#FFFF31,255,255,49,60,100.0,59.6
yellow,yellow-green,Vivid yellow,#fdfe03,253,254,3,60,99.2,50.4
yellow,yellow-green,Vivid yellow,#eeff1b,238,255,27,64,100.0,55.3
white,very light grey,White,#FFFFFF,255,255,255,0,0.0,100.0
yellow,yellow,Yellow,#F4C430,244,196,48,45,89.9,57.3
yellow,yellow,Yellow,#e1bd27,225,189,39,48,75.6,51.8
yellow,yellow,Yellow,#f2d930,242,217,48,52,88.2,56.9
yellow,yellow,Yellow,#ECD540,236,213,64,52,81.9,58.8
yellow,yellow,Yellow,#E4D430,228,212,48,55,76.9,54.1
yellow,yellow,Yellow,#f0e130,240,225,48,55,86.5,56.5
yellow,yellow,Yellow,#E5DE43,229,222,67,57,75.7,58.0
green,yellow-green,Yellow-green,#D1E231,209,226,49,66,75.3,53.9
green,yellow-green,Yellow-green,#D2E543,210,229,67,67,75.7,58.0"""

# %%
# Name0,Desc1,Desc2,HEX,R,G,B,Hue,Sat,Lum
striped = []
for line in csv_desc.split('\n'):
    # Get desc2
    tmp = line.split(',')
# ['blue', 'blue', 'Bright blue', '#3C69E7', '60', '105', '231', '224', '78.1', '57.1']
    new_line = []
    new_line.append('"'+tmp[2]+'"')
    # get rgb
    r = int(tmp[4])
    g = int(tmp[5])
    b = int(tmp[6])
    # get hsl
    h = float(tmp[7])
    sl = float(tmp[8])/100
    l = float(tmp[9])/100
    # Get HSV
    _, sv, v = colorsys.rgb_to_hsv(r/255, g/255, b/255)
    # reconstruct
    new_line.append("0x{:02x}".format(r))
    new_line.append("0x{:02x}".format(g))
    new_line.append("0x{:02x}".format(b))
    new_line.append("{:.1f}F".format(h))
    new_line.append("{:.3f}F".format(sl))
    new_line.append("{:.3f}F".format(l))
    new_line.append("{:.3f}F".format(sv))
    new_line.append("{:.3f}F".format(v))
    striped.append(new_line)
# Format back to code
formatted = ''
for line in striped:
    formatted += new_pre
    for item in line:
        if line.index(item) == 0:
            formatted += item
        else: 
            formatted += ','
            formatted += item
    formatted += post
    formatted += '\n'
print(formatted)
# Out:
#         colourList.add(ColorName("Black",0x00,0x00,0x00,0.0F,0.000F,0.000F,0.000F,0.000F))
#         colourList.add(ColorName("Bright blue",0x3c,0x69,0xe7,224.0F,0.781F,0.571F,0.740F,0.906F))
#         colourList.add(ColorName("Bright blue",0x41,0x69,0xe1,225.0F,0.727F,0.569F,0.711F,0.882F))
#         colourList.add(ColorName("Bright blue",0x27,0x3b,0xe2,233.0F,0.763F,0.520F,0.827F,0.886F))
#         colourList.add(ColorName("Bright blue",0x26,0xa7,0xde,197.0F,0.736F,0.510F,0.829F,0.871F))
#         colourList.add(ColorName("Bright blue",0x42,0xad,0xde,199.0F,0.703F,0.565F,0.703F,0.871F))
#         colourList.add(ColorName("Bright blue",0x45,0xb1,0xe8,200.0F,0.780F,0.590F,0.703F,0.910F))
#         colourList.add(ColorName("Bright blue",0x24,0xa0,0xed,202.0F,0.848F,0.535F,0.848F,0.929F))
#         colourList.add(ColorName("Bright blue",0x3e,0x8e,0xde,210.0F,0.708F,0.557F,0.721F,0.871F))
# ...

# %%
# Short Desc to code
csv_desc = """0,black,Black,Black,#000000,0,0,0,0.0,0.0,0.0
2,blue,blue,Bright blue,#4169E1,65,105,225,225.0,72.7,56.9
6,blue,cyan-blue,Bright blue,#45B1E8,69,177,232,200.0,78.0,59.0
8,blue,cyan-blue,Bright blue,#3E8EDE,62,142,222,210.0,70.8,55.7
10,blue,medium light blue,Bright blue,#4166F5,65,102,245,228.0,90.0,60.8
11,blue,cyan,Bright cyan,#3ECAE8,62,202,232,191.0,78.7,57.6
12,cyan,cyan,Bright cyan,#40E0D0,64,224,208,174.0,72.1,56.5
13,green,green,Bright green,#A7F432,167,244,50,84.0,89.8,57.6
16,green,yellow-green,Bright green,#C2F732,194,247,50,76.0,92.5,58.2
23,brown,orange,Bright orange,#E18731,225,135,49,29.0,74.6,53.7
40,pink,medium light pink,Bright pink,#FD3F92,253,63,146,334.0,97.9,62.0
49,purple,magenta,Bright purple,#DF33EA,211,56,234,292.0,81.3,55.9
50,purple,magenta,Bright purple,#ED3CCA,237,60,202,312.0,83.1,58.2
51,red,pink-red,Bright red,#EF3038,239,48,36,4.0,85.7,56.3
53,red,pink-red,Bright red,#E44165,228,65,101,347.0,75.1,57.5
61,red,red,Bright red,#d9463e,217,70,62,3.0,67.1,54.7
68,purple,blue-magenta,Bright violet,#9842E3,152,66,227,272.0,74.2,57.5
71,yellow,yellow-green,Bright yellow,#FAFA37,250,250,55,60.0,95.1,59.8
72,brown,brown,Brown,#e69b3a,230,155,58,33.0,77.5,56.5
73,blue,blue,Dark blue,#324AB2,50,74,178,229.0,56.1,44.7
74,blue,cyan-blue,Dark blue,#3176AF,49,118,173,207.0,56.3,43.9
80,blue,medium dark blue,Dark blue,#0033AA,0,51,170,222.0,100.0,33.3
92,blue,medium dark blue,Dark blue,#0a1195,10,17,149,237.0,87.4,31.2
107,blue,medium dark cyan-blue,Dark blue,#035096,3,80,150,209.0,96.1,30.0
122,brown,red-orange,Dark brown,#AF593E,175,89,67,12.0,47.7,46.5
126,green,dark green-cyan,Dark cyan,#00755E,0,117,94,168.0,100.0,22.9
134,cyan,medium dark cyan,Dark cyan,#009698,0,150,152,181.0,100.0,29.8
141,green,green,Dark green,#66B032,102,176,50,95.0,55.8,44.3
144,green,medium dark yellow-green,Dark green,#6B8E23,107,142,35,80.0,60.5,34.7
146,grey,grey,Dark grey,#808080,128,128,128,0.0,0.0,50.2
149,grey,blue,Dark greyish blue,#838996,131,150,156,194.0,8.3,55.1
151,grey,blue-magenta,Dark greyish blue,#777696,119,118,150,242.0,13.2,52.5
154,grey,cyan-blue,Dark greyish blue,#778899,119,136,153,210.0,14.3,53.3
156,grey,medium light blue,Dark greyish blue,#8C92AC,140,146,172,229.0,16.2,61.2
158,grey,medium light blue-magenta,Dark greyish blue,#AAA9AD,170,169,173,255.0,2.4,67.1
159,grey,medium light cyan-blue,Dark greyish blue,#91A3B0,145,163,176,205.0,16.4,62.9
160,grey,brown,Dark greyish brown,#8B8680,139,134,128,33.0,4.5,52.4
163,grey,cyan,Dark greyish cyan,#86aba5,134,171,165,170.0,18.0,59.8
164,grey,cyan,Dark greyish cyan,#718080,113,128,128,180.0,6.2,47.3
166,grey,green-cyan,Dark greyish cyan,#6a7f7a,106,127,122,165.0,9.0,45.7
167,grey,green,Dark greyish green,#8c9c76,140,156,118,85.0,16.1,53.7
168,grey,green,Dark greyish green,#78866B,120,134,107,91.0,11.2,47.3
169,grey,green,Dark greyish green,#63775b,99,119,91,102.0,13.3,41.2
170,grey,yellow-green,Dark greyish green,#8F9779,143,151,121,76.0,12.6,53.3
171,grey,green,Dark greyish green-cyan,#738678,115,134,120,136.0,7.6,48.8
172,grey,green-cyan,Dark greyish green-cyan,#819c8b,129,156,139,142.0,12.0,55.9
173,grey,green-cyan,Dark greyish green-cyan,#8DA399,141,163,153,153.0,10.7,59.6
174,grey,green,Dark greyish lime green,#757d75,117,125,117,120.0,3.3,47.5
176,grey,green,Dark greyish lime green,#828e84,130,142,132,130.0,5.0,53.3
178,grey,orange,Dark greyish orange,#97867c,151,134,124,22.0,11.5,53.9
180,grey,magenta-pink,Dark greyish pink,#8B8589,139,133,137,320.0,2.5,53.3
182,grey,pink,Dark greyish pink,#9C7687,156,118,135,333.0,16.1,53.7
184,grey,magenta,Dark greyish purple,#8A7F8D,138,127,141,287.0,5.8,52.5
186,grey,magenta,Dark greyish purple,#A17E9A,161,126,154,312.0,15.7,56.3
187,grey,medium light magenta,Dark greyish purple,#AA98A9,170,152,169,303.0,9.6,63.1
190,grey,pink-red,Dark greyish red,#98777B,152,119,123,353.0,13.8,53.1
192,brown,red,Dark greyish red,#AD8884,173,160,132,41.0,20.0,59.8
194,grey,red,Dark greyish red,#A3807B,163,128,123,8.0,17.9,56.1
196,grey,blue-magenta,Dark greyish violet,#766980,118,105,128,273.0,9.9,45.7
198,grey,magenta,Dark greyish violet,#716675,113,102,117,284.0,6.8,42.9
200,grey,yellow,Dark greyish yellow,#878681,135,134,129,50.0,2.4,51.8
202,grey,yellow-green,Dark greyish yellow,#898a74,137,138,116,62.0,8.7,49.8
206,green,green,Dark lime green,#27A640,39,166,76,137.0,62.0,40.2
212,green,medium dark green,Dark lime green,#18880d,24,136,13,114.0,82.6,29.2
224,green,medium dark green-cyan,Dark lime green,#009150,0,145,80,153.0,100.0,28.4
234,brown,medium dark pink-red,Dark medium red,#7e2639,126,38,57,347.0,53.7,32.2
236,blue,blue,Dark moderate blue,#39569c,57,86,156,222.0,46.5,41.8
237,blue,blue,Dark moderate blue,#545AA7,84,90,167,236.0,33.1,49.2
238,blue,cyan,Dark moderate blue,#44798e,68,121,142,197.0,35.2,41.2
242,blue,cyan-blue,Dark moderate blue,#44719B,68,113,155,209.0,39.0,43.7
247,blue,medium dark blue,Dark moderate blue,#333C87,51,60,135,234.0,45.2,36.5
249,blue,medium dark blue-magenta,Dark moderate blue,#2E2D88,46,45,136,241.0,50.3,35.5
254,blue,medium dark cyan-blue,Dark moderate blue,#2E5090,46,80,144,219.0,51.6,37.3
255,purple,medium dark blue-magenta,Dark moderate blue-purple,#4B308D,75,48,141,257.0,49.2,37.1
256,brown,brown,Dark moderate brown,#b08d57,176,141,87,36.0,36.0,51.6
258,brown,red-orange,Dark moderate brown,#985538,152,85,56,18.0,46.2,40.8
262,green,green-cyan,Dark moderate cyan,#39A78E,57,167,142,166.0,49.1,43.9
264,blue,medium dark cyan,Dark moderate cyan,#317589,49,117,137,193.0,47.3,36.5
266,cyan,medium dark cyan,Dark moderate cyan,#2F847C,47,132,124,174.0,47.5,35.1
268,green,medium dark cyan,Dark moderate cyan,#36747D,54,116,125,188.0,39.7,35.1
270,green,green,Dark moderate green,#6f9940,111,153,64,88.0,41.0,42.5
272,green,green,Dark moderate lime green,#4C9141,76,145,65,112.0,38.1,41.2
274,green,medium dark green,Dark moderate lime green,#4F7942,79,121,66,106.0,29.4,36.7
276,green,medium dark green,Dark moderate lime green,#2e963d,46,150,61,128.0,53.1,38.4
278,pink,pink,Dark moderate pink,#AA4069,170,64,105,337.0,45.3,45.9
282,purple,pink,Dark moderate pink,#A8516E,168,81,110,340.0,34.9,48.8
284,brown,pink-red,Dark moderate pink-red,#AB5C6D,171,92,109,347.0,32.0,51.6
286,purple,blue-magenta,Dark moderate purple,#5946B2,89,70,178,251.0,43.5,48.6
288,purple,magenta,Dark moderate purple,#8F509D,143,80,157,289.0,32.5,46.5
289,purple,magenta,Dark moderate purple,#A757AB,167,87,171,297.0,33.3,50.6
292,purple,magenta,Dark moderate purple,#98508E,152,80,142,308.0,31.0,45.5
299,purple,magenta-pink,Dark moderate purple,#A85387,168,83,135,323.0,33.9,49.2
308,purple,medium dark blue-magenta,Dark moderate purple,#3E2F84,62,47,132,251.0,47.5,35.1
312,brown,pink-red,Dark moderate red,#AB4E52,171,78,82,357.0,37.3,48.8
322,brown,red,Dark moderate red,#B0665C,176,102,92,7.0,34.7,52.5
327,purple,blue-magenta,Dark moderate violet,#6B3FA0,107,63,160,267.0,43.5,43.7
333,purple,magenta,Dark moderate violet,#7f3e98,127,62,152,283.0,42.1,42.0
334,brown,yellow,Dark moderate yellow,#9c8a4d,156,138,77,46.0,33.9,45.7
335,green,yellow-green,Dark moderate yellow-green,#96a53c,150,165,60,68.0,46.7,44.1
336,brown,dark brown,Dark brown,#7B3F00,123,63,0,31.0,100.0,24.1
339,brown,medium dark brown,Medium dark brown,#804000,128,64,0,30.0,100.0,25.1
349,brown,medium dark orange,Dark brown,#933709,147,55,9,20.0,88.5,30.6
361,brown,medium dark yellow,Medium dark yellow-brown,#a17917,161,121,23,43.0,75.0,36.1
363,brown,orange,Brown,#a96232,169,98,50,24.0,54.3,42.9
364,brown,red-orange,Brown,#A0522D,160,82,45,19.0,56.1,40.2
375,pink,medium dark pink,Dark pink,#B11355,177,19,85,335.0,80.6,38.4
388,purple,medium dark magenta,Dark purple,#731E8F,115,30,143,285.0,65.3,33.9
391,purple,medium dark magenta,Dark purple,#7D2181,125,33,129,298.0,59.3,31.8
400,brown,dark red,Dark brown,#7C0A02,124,10,2,4.0,96.8,24.7
402,red,medium dark red,Dark red,#a40000,164,0,0,0.0,100.0,32.2
406,purple,medium dark pink-red,Dark brown,#800020,128,0,32,345.0,100.0,25.1
409,red,medium dark pink-red,Dark red,#990024,97,64,81,329.0,100.0,30.0
420,red,medium dark pink-red,Dark red,#b2071d,178,7,29,352.0,92.4,36.3
432,brown,medium dark red,Dark brown,#9d2b22,157,43,34,4.0,64.4,37.5
449,red,medium dark red,Medium dark red,#A81C07,168,28,7,8.0,92.0,34.3
452,brown,medium dark red-orange,Moderate dark brown,#7C1C05,124,28,5,12.0,92.2,25.3
456,red,pink-red,Dark red,#AE2029,174,22,42,352.0,68.9,40.4
457,red,pink-red,Dark red,#B21B1C,178,27,28,360.0,73.7,40.2
459,brown,red,Dark red,#A83731,168,55,49,3.0,54.8,42.5
463,brown,red-orange,Brown,#b14a30,177,74,48,12.0,57.3,44.1
467,purple,medium dark blue-magenta,Dark violet,#512888,81,40,136,266.0,54.5,34.5
475,grey,dark yellow,Dark olive,#737000,115,112,0,58.0,100.0,22.5
483,brown,yellow,Dark yellow brown,#aa8736,170,135,54,41.0,51.8,43.9
487,grey,medium light grey,Grey,#ACACAC,172,172,172,0.0,0.0,67.5
490,grey,light blue-magenta,Greyish blue,#C4C3D0,196,195,221,242.0,12.1,79.0
492,grey,light cyan-blue,Greyish blue,#BFC1C2,191,193,194,200.0,2.4,75.5
494,grey,medium light cyan-blue,Greyish blue,#A9B2C3,169,178,195,219.0,17.8,71.4
495,blue,medium light blue,Greyish blue,#A2ADD0,162,173,208,226.0,32.9,72.5
496,grey,medium light blue-magenta,Greyish blue,#A2A2D0,162,162,208,240.0,32.9,72.5
498,grey,medium light cyan-blue,Greyish blue,#8BA8B7,139,168,183,200.0,23.4,63.1
499,brown,medium light brown,Greyish brown,#ABA092,71,100,146,217.0,13.0,62.2
500,brown,medium light brown,Greyish brown,#AF9E89,175,158,137,33.0,19.2,61.2
502,green,light cyan,Greyish cyan,#B4CFD3,180,207,211,188.0,26.1,76.7
503,cyan,light green-cyan,Greyish cyan,#AFD0CA,175,208,202,169.0,26.0,75.1
504,grey,medium light cyan,Grey,#B8C2C2,184,194,194,180.0,7.6,74.1
505,grey,light green-cyan,Greyish cyan,#bbd0c9,187,208,201,160.0,18.3,77.5
506,grey,medium light green,Grey,#B2BEB5,178,190,181,135.0,8.5,72.2
507,grey,medium light green-cyan,Greyish green-cyan,#A3C1AD,163,193,173,140.0,19.5,69.8
508,grey,medium light green-cyan,Greyish green-cyan,#A8C3BC,168,195,188,164.0,18.4,71.2
509,grey,medium light green,Grey-green,#afb1ae,175,177,174,99.0,1.9,68.8
510,grey,medium light green,Greyish green,#a5ba93,165,186,147,92.0,22.0,65.3
512,grey,medium light green,Greyish green,#AEBEA6,142,190,166,150.0,15.6,69.8
513,grey,medium light yellow-green,Greyish green,#ACB78E,172,183,142,76.0,22.2,63.7
514,grey,medium light green-cyan,Greyish green-cyan,#96ABA5,134,171,165,170.0,11.1,62.9
515,green,medium light green,Greyish lime green,#8FBC8F,143,188,143,120.0,25.1,64.9
516,green,medium light green,Greyish lime green,#96C8A2,150,200,162,134.0,31.3,68.6
517,grey,light magenta,Greyish purple,#D8BFD8,216,191,216,300.0,24.3,79.8
518,purple,light magenta,Greyish purple,#D8B2D1,219,178,209,315.0,32.8,77.3
519,grey,medium light magenta,Greyish purple,#b39eb5,179,158,181,294.0,13.5,66.5
520,purple,medium light magenta,Greyish purple,#AB92B3,171,146,179,285.0,17.8,63.7
522,purple,medium light magenta,Greyish purple,#CAABD0,202,171,208,290.0,28.2,74.3
524,purple,medium light magenta,Greyish purple,#CBA2C8,200,162,200,300.0,28.3,71.6
526,purple,medium light magenta,Greyish purple,#C79FC4,231,159,196,329.0,26.3,70.2
527,grey,light orange,Greyish brown,#C9C0BB,201,192,187,21.0,11.5,76.1
528,brown,medium light brown,Greyish orange,#d1bea8,209,190,168,32.0,30.8,73.9
530,grey,medium light orange,Greyish orange,#bea493,190,164,147,23.0,24.9,66.1
532,grey,medium light yellow,Greyish brown,#c6c2b6,198,194,182,44.0,12.3,74.5
533,purple,medium light magenta,Greyish pink,#C49FBA,196,159,186,316.0,23.9,69.6
534,grey,medium light magenta-pink,Greyish pink,#AA8A9E,170,138,158,323.0,15.8,60.4
535,grey,medium light pink,Greyish pink,#B89CA9,184,156,169,332.0,16.5,66.7
536,grey,medium light pink,Greyish pink,#C3A6B1,195,166,177,337.0,19.5,70.8
539,grey,medium light pink-red,Greyish red,#AD9194,173,145,148,354.0,14.6,62.4
540,grey,medium light pink-red,Greyish red,#BFAFB2,191,175,178,349.0,11.1,71.8
541,grey,medium light pink-red,Greyish red,#C09396,217,166,169,356.0,26.3,66.5
543,brown,medium light red,Greyish red,#C09999,192,153,153,0.0,23.6,67.6
545,grey,medium light red,Greyish red,#C4AEAD,196,174,173,3.0,16.3,72.4
546,grey,medium light red-orange,Greyish red,#C1B6B3,193,182,179,13.0,10.1,72.9
548,purple,medium light blue-magenta,Greyish violet,#B2A4D4,178,164,202,262.0,35.8,73.7
549,grey,medium light magenta,Greyish violet,#BAA8C1,186,168,193,283.0,16.8,70.8
550,grey,light yellow-green,Greyish yellow,#cfcfc4,207,207,196,60.0,10.3,79.0
552,grey,medium light yellow,Greyish yellow,#A79E8B,167,158,139,41.0,13.7,60.0
553,blue,medium light blue,Medium light blue,#4666FF,70,102,255,230.0,100.0,63.7
554,blue,medium light blue-magenta,Medium light blue,#6666ff,102,102,255,240.0,100.0,70.0
558,grey,light grey,Light grey,#cfcfcf,207,207,207,0.0,0.0,81.2
562,blue,light blue,Light greyish blue,#C5D0E6,197,208,230,220.0,39.8,83.7
563,blue,light blue,Light greyish blue,#C5CBE1,197,203,225,228.0,31.8,82.7
564,blue,light blue,Light greyish blue,#bfc0ee,191,192,238,238.0,58.0,84.1
565,purple,light blue-magenta,Light greyish purple,#C5C2EF,197,194,239,244.0,58.4,84.9
566,blue,light cyan-blue,Light greyish blue,#c4d8e2,196,216,226,199.0,34.1,82.7
567,blue,light cyan-blue,Light greyish blue,#BCD4E6,188,212,230,206.0,45.7,82.0
568,grey,very light blue,Very light greyish blue,#e9edf6,233,237,246,221.0,41.9,93.9
569,grey,very light blue,Very light greyish blue,#ebecf0,235,236,240,227.0,14.3,93.1
570,grey,very light blue-magenta,Very light greyish purple,#F5F5FD,245,245,253,240.0,66.7,97.6
571,grey,very light blue-magenta,Light greyish purple,#D9D8EA,217,216,234,243.0,30.0,88.2
573,purple,very light blue-magenta,Light greyish purple,#CEC8EF,206,200,239,249.0,54.9,86.1
574,purple,very light blue-magenta,Light greyish purple,#D8D0F5,216,208,245,253.0,64.9,88.8
575,purple,very light blue-magenta,Very light greyish purple,#F0EEFD,249,238,253,284.0,78.9,96.3
576,white,very light blue-magenta,Very light greyish purple,#F9F8FE,249,248,254,250.0,75.0,98.4
577,blue,very light cyan-blue,Light greyish purple,#dbe9f4,219,233,244,206.0,53.2,90.8
578,grey,very light cyan-blue,Very light grey,#f2f3f4,242,243,244,210.0,8.3,95.3
580,blue,very light cyan,Light greyish cyan,#d4f1f9,212,241,249,192.0,75.5,90.4
582,grey,very light cyan,Light greyish cyan,#DEEBEC,222,235,236,184.0,26.9,89.8
583,green,light green-cyan,Light greyish green-cyan,#CBE3D7,200,227,215,153.0,30.0,84.3
584,green,light green-cyan,Light greyish green-cyan,#BFDCD4,191,220,212,163.0,29.3,80.6
585,green,very light green-cyan,Very light greyish cyan,#e9f6ef,233,246,239,147.0,41.9,93.9
586,green,very light green-cyan,Very light greyish cyan,#E6F8F3,230,248,243,163.0,56.3,93.7
587,grey,light green,Light greyish green,#DDECC0,221,236,192,80.0,53.7,83.9
588,grey,light yellow-green,Light greyish green,#d8e4bc,216,228,188,78.0,42.6,81.6
589,grey,very light green,Light grey,#e2e5de,226,229,222,85.0,11.9,88.4
590,grey,light magenta,Light greyish purple,#DFD2DF,223,210,222,305.0,16.9,84.9
592,purple,very light magenta,Very light purple,#FAE6FA,250,230,250,300.0,66.7,94.1
593,grey,light brown,Light greyish brown,#DBD7D2,219,215,210,33.0,11.1,84.1
594,grey,light brown,Light greyish brown,#E3DAC9,227,218,201,39.0,31.7,83.9
595,brown,light orange,Light brown,#ECD5C5,236,213,197,25.0,50.6,84.9
596,grey,light orange,Light greyish brown,#DCD7D4,220,215,212,22.0,10.3,84.7
597,grey,very light brown,Very light brown,#FAF0E6,250,240,230,30.0,66.7,94.1
598,grey,very light brown,Very light brown,#e6e0d4,230,224,212,39.0,26.5,86.7
599,grey,very light orange,Very light brown,#F1DDCF,241,221,207,25.0,54.8,87.8
605,grey,very light brown,Light greyish brown,#F2E8D7,242,232,215,38.0,50.9,89.6
615,pink,very light magenta-pink,Very light greyish purple,#F9EAF3,249,234,243,324.0,55.6,94.7
620,grey,very light pink,Light greyish pink,#E8CCD7,232,204,215,336.0,37.8,85.5
621,grey,very light pink,Light greyish pink,#EBCBD6,237,203,214,341.0,44.4,85.9
622,pink,very light pink,Light greyish pink,#FDE3F0,253,227,240,330.0,86.7,94.1
623,pink,very light pink,Light greyish pink,#F6C6D8,246,198,216,338.0,72.7,87.1
624,pink,very light pink,Light greyish pink,#FDDDE6,253,221,230,343.0,88.9,92.9
625,grey,light pink-red,Light greyish red,#DDBEC3,221,190,195,350.0,31.3,80.6
626,brown,light red,Light greyish red,#E2CACA,226,202,202,0.0,29.3,83.9
628,grey,light red,Light greyish red,#E1C7C3,225,199,195,8.0,33.3,82.4
630,pink,very light pink-red,Very light pink-red,#FADADD,250,218,221,354.0,76.2,91.8
632,brown,very light red,Light greyish red,#EBDBDB,235,219,219,0.0,28.6,89.0
634,grey,very light red,Light greyish red,#E4D3D2,228,211,210,3.0,25.0,85.9
636,grey,very light red,Light greyish red,#EBE1DF,235,225,223,10.0,23.1,89.8
637,pink,very light red,Very light pink-red,#FACCCA,249,204,202,3.0,82.8,88.6
638,purple,light blue-magenta,Light greyish violet,#D0C0E5,208,192,229,266.0,41.6,82.5
640,purple,light blue-magenta,Light greyish violet,#CFB8DE,207,184,222,276.0,36.5,79.6
642,purple,light blue-magenta,Light greyish violet,#D4BEEB,228,190,235,291.0,52.9,83.3
643,grey,very light blue-magenta,Very light grey,#E7E4EF,231,228,255,247.0,25.6,91.6
644,purple,very light blue-magenta,Light greyish violet,#EBE3FC,235,227,252,259.0,80.6,93.9
645,purple,very light blue-magenta,Light greyish violet,#EBE4F4,235,228,244,266.0,42.1,92.5
646,grey,light yellow,Light greyish yellow,#ECEBBD,236,235,189,59.0,55.3,83.3
648,grey,very light yellow,Very light greyish yellow,#EDEAE0,237,234,224,50.0,26.5,90.4
649,brown,very light yellow,White,#fefdfa,254,253,250,45.0,66.7,98.8
651,grey,very light yellow,Very light greyish yellow,#F4EED7,244,238,215,48.0,56.9,90.0
654,white,very light yellow-green,White,#FEFEFA,254,254,250,60.0,66.7,98.8
656,green,medium light green,Light lime green,#66FF66,102,255,102,120.0,100.0,70.0
657,green,medium light green,Light lime green,#7FFF55,127,255,85,105.0,100.0,66.7
658,green,medium light green,Light lime green,#5cff67,92,255,103,124.0,100.0,68.0
659,purple,medium light magenta,Light magenta,#FF66FF,255,102,255,300.0,100.0,70.0
660,orange,medium light brown,Light orange,#FFAE42,255,174,66,34.0,100.0,62.9
661,orange,medium light red-orange,Light orange,#FF9966,255,153,102,20.0,100.0,70.0
662,yellow,medium light yellow,Medium light yellow,#ffce44,255,206,68,44.0,100.0,63.3
664,brown,medium light brown,Light orange,#ffb95a,255,185,90,34.0,100.0,67.6
667,orange,medium light brown,Light orange,#ffc34d,255,195,77,39.0,100.0,65.1
668,orange,medium light orange,Light orange,#FF8243,255,130,67,20.0,100.0,63.1
670,orange,medium light orange,Light orange,#ff8936,255,137,54,24.0,100.0,60.6
672,orange,medium light red-orange,Light orange,#FF7F50,255,127,80,16.0,100.0,65.7
675,pink,medium light magenta-pink,Light pink,#FF66CC,255,102,204,320.0,100.0,70.0
678,pink,medium light pink,Light pink,#FF55A3,255,85,163,332.0,100.0,66.7
685,pink,medium light pink-red,Light red,#FF5470,255,84,112,350.0,100.0,66.5
689,red,medium light pink-red,Light red,#ff404c,255,64,76,356.0,100.0,62.5
690,orange,medium light red,Light red,#FF5349,255,83,73,3.0,100.0,64.3
692,orange,medium light red,Light red,#FF5A36,255,90,54,11.0,100.0,60.6
694,red,medium light red,Light red,#FF3F34,255,63,52,3.0,100.0,60.2
697,orange,medium light red-orange,Light red,#FF6E4A,255,110,74,12.0,100.0,64.5
699,purple,medium light blue-magenta,Light violet,#9966FF,153,102,255,260.0,100.0,70.0
700,yellow,medium light yellow-green,Light yellow,#FFFF66,255,255,102,60.0,100.0,70.0
702,yellow,medium light yellow,Medium light yellow,#ffdf46,255,223,70,49.0,100.0,63.7
704,yellow,medium light yellow,Light yellow,#FFF44F,255,244,79,56.0,100.0,65.5
706,purple,medium dark blue-magenta,Medium dark blue-purple,#58427C,88,66,124,263.0,30.5,37.3
710,brown,medium dark brown,Medium dark brown,#826644,130,102,68,33.0,31.3,38.8
711,brown,medium dark brown,Medium dark brown,#896c39,137,108,57,38.0,41.2,38.0
713,brown,medium dark orange,Medium dark brown,#84563c,132,86,60,21.0,37.5,37.6
716,brown,medium dark orange,Medium dark brown,#7f5d3b,127,93,59,29.0,36.6,36.5
717,brown,medium dark red-orange,medium dark brown,#824b35,130,75,53,17.0,42.1,35.9
718,brown,medium dark red-orange,Medium dark brown,#8c4736,140,71,54,11.0,44.3,38.0
719,green,green,Medium dark green,#4D8C57,77,140,87,130.0,29.0,42.5
720,green,medium dark green,Medium dark green,#2f7532,47,117,50,122.0,42.7,32.2
721,green,medium dark green,Medium dark green,#407a52,64,122,82,138.0,31.2,36.5
722,green,medium dark green,Medium dark green,#5b8930,91,137,48,91.0,48.1,36.3
724,green,medium dark green,Medium dark green,#3C8043,60,128,67,126.0,36.2,36.9
728,green,medium dark green-cyan,Medium dark green,#14A989,20,169,137,167.0,78.8,37.1
734,green,medium dark green-cyan,Medium dark green-cyan,#3B7A57,59,122,87,147.0,34.8,35.5
735,green,medium dark green-cyan,Medium dark green-cyan,#3B7861,59,120,97,157.0,34.1,35.1
736,green,medium dark green-cyan,Medium dark green-cyan,#40826D,64,130,109,161.0,34.0,38.0
740,purple,medium dark pink,Medium dark pink,#892D52,137,45,82,336.0,50.5,35.7
743,purple,medium dark blue-magenta,Medium dark purple,#663399,102,51,153,270.0,50.0,40.0
744,purple,medium dark magenta,Medium dark purple,#733380,115,51,128,290.0,43.0,35.1
746,purple,medium dark magenta,Medium dark purple,#763568,118,53,104,312.0,38.0,33.5
748,purple,medium dark magenta,Medium dark purple,#6C3082,108,48,130,284.0,46.1,34.9
749,purple,medium dark magenta-pink,Medium dark pink,#873260,135,50,96,328.0,45.9,36.3
754,brown,medium dark red,Medium dark brown,#7B3636,123,54,54,0.0,39.0,34.7
758,brown,medium dark red,Medium dark brown,#934337,147,67,55,7.0,45.5,39.6
762,grey,medium dark yellow,Medium dark yellow,#807532,128,117,50,52.0,43.8,34.9
764,green,medium dark yellow-green,Medium dark yellow-green,#7a942e,122,148,46,75.0,52.6,38.0
765,grey,medium dark yellow-green,Medium dark yellow-green,#7C7C40,124,124,64,60.0,31.9,36.9
766,brown,medium light brown,Medium light brown,#faa945,250,169,69,33.0,94.8,62.5
767,pink,medium light pink-red,Medium light pink-red,#fe4164,254,65,100,348.0,99.0,62.5
768,pink,medium light pink-red,Medium light pink-red,#FD3A4A,253,58,74,355.0,98.0,61.0
770,orange,medium light red,Medium light red,#fd5240,253,82,64,5.0,97.9,62.2
771,orange,medium light red,Medium light red,#FA5B3D,250,91,61,10.0,95.0,61.0
773,blue,blue,Moderate blue,#446CCF,68,108,207,223.0,59.1,53.9
777,purple,blue-magenta,Moderate blue-purple,#4F42B5,79,66,181,247.0,46.6,48.4
784,blue,cyan-blue,Moderate cyan-blue,#458AC6,69,138,198,208.0,53.1,52.4
789,brown,brown,Moderate brown,#b07939,176,121,57,32.0,51.1,45.7
793,brown,orange,Moderate brown,#A67B5B,166,123,91,26.0,29.6,50.4
799,blue,cyan,Moderate cyan,#3AA1C1,58,161,193,194.0,53.8,49.2
803,cyan,cyan,Moderate cyan,#43B3AE,67,179,174,177.0,45.5,48.2
807,cyan,cyan,Moderate cyan,#3aa8c1,58,168,193,191.0,53.8,49.2
808,green,green-cyan,Moderate cyan,#4cb7a5,76,183,165,169.0,42.6,50.8
810,green,green-cyan,Moderate green-cyan,#50C878,80,200,120,140.0,52.2,54.9
812,green,green-cyan,Moderate green-cyan,#3CB371,60,179,113,147.0,49.8,46.9
815,green,green-cyan,Moderate green-cyan,#44d7a8,68,215,168,160.0,64.8,55.5
818,green,green,Moderate green,#7dc242,125,194,66,92.0,51.2,51.0
820,green,green,Moderate green,#66b447,102,180,71,102.0,43.4,49.2
821,green,green,Moderate lime green,#34b334,52,179,52,120.0,55.0,45.3
822,purple,magenta,Moderate purple,#BA55D3,186,85,211,288.0,58.9,58.0
824,purple,magenta,Moderate purple,#C154C1,193,84,193,300.0,46.8,54.3
826,brown,brown,Moderate brown,#bb8141,187,129,65,31.0,48.4,49.4
828,brown,brown,Moderate brown,#C39953,195,153,83,38.0,48.3,54.5
829,brown,medium light orange,Moderate brown,#cc9966,204,153,102,29.0,50.0,60.0
830,brown,medium light brown,Medium light brown,#D2A560,210,165,96,36.0,55.9,60.0
831,brown,orange,Brown,#C08D5E,192,58,21,13.0,43.8,56.1
834,brown,orange,Brown,#be7f51,190,127,81,25.0,45.6,53.1
838,brown,yellow,Yellow brown,#CBA135,203,161,53,43.0,59.1,50.2
845,pink,magenta-pink,Purple-pink,#D74894,215,72,148,328.0,64.1,56.3
859,pink,pink,Moderate pink,#D65282,214,82,130,338.0,61.7,58.0
867,brown,medium light red,Medium light red,#CC6666,204,102,102,0.0,50.0,60.0
872,pink,pink-red,Moderate red,#cc4e5c,204,78,92,353.0,55.3,55.3
873,red,pink-red,Moderate red,#c93756,201,55,86,347.0,57.5,50.2
883,brown,red,Moderate red,#CD5B45,205,91,69,10.0,57.6,53.7
885,brown,red,Moderate red,#CC4E3C,204,78,92,353.0,58.5,51.8
892,purple,magenta,Moderate violet,#9955BB,153,85,187,280.0,42.9,53.3
894,purple,medium light blue-magenta,Moderate violet,#9966CC,153,102,204,270.0,50.0,60.0
896,green,medium light yellow-green,Medium light yellow-green,#CBD862,205,216,98,66.0,60.2,61.6
897,brown,yellow,Moderate yellow,#C9AE5D,201,174,93,45.0,50.0,57.6
898,grey,yellow,Moderate yellow,#b5a642,181,166,66,52.0,46.6,48.4
900,grey,yellow,Moderate yellow,#B8B654,184,182,84,59.0,41.3,52.5
902,yellow,yellow,Moderate yellow,#D4AF37,212,175,55,46.0,64.6,52.4
906,green,yellow-green,Moderate yellow-green,#b0c24a,176,194,74,69.0,49.6,52.5
909,blue,blue,Greyish dark blue,#536895,83,104,149,220.0,28.4,45.5
912,purple,blue-magenta,Greyish dark blue-purple,#7573A6,117,115,166,242.0,22.3,55.1
915,grey,cyan-blue,Greyish dark cyan-blue,#778BA5,119,139,165,214.0,20.4,55.7
916,grey,medium dark cyan-blue,Dark bluish grey,#536878,83,104,120,206.0,18.2,39.8
917,blue,cyan,Greyish dark cyan,#68a0b0,104,160,176,193.0,31.3,54.9
919,cyan,cyan,Greyish dark cyan,#5F9EA0,95,158,160,182.0,25.5,50.0
922,green,green-cyan,Greyish dark cyan,#6EAEA1,119,174,161,166.0,28.3,55.7
926,green,green-cyan,Greyish dark green-cyan,#5FA777,95,167,119,140.0,29.0,51.4
928,green,green-cyan,Greyish dark green-cyan,#749f8d,116,159,141,154.0,18.3,53.9
930,green,medium dark green-cyan,Dark greyish green-cyan,#49796B,73,121,107,163.0,24.7,38.0
931,green,green,Greyish dark green,#87A96B,135,169,107,93.0,26.5,54.1
932,green,yellow-green,Greyish dark yellow-green,#8A9A5B,138,154,191,222.0,25.7,48.0
933,grey,yellow-green,Greyish dark yellow-green,#8c9e5e,140,158,94,76.0,25.4,49.4
934,green,green,Greyish dark lime green,#6b9362,107,147,98,108.0,20.0,48.0
935,green,green,Greyish dark lime green,#679267,103,146,103,120.0,17.3,48.8
938,purple,magenta,Greyish dark purple,#976e9a,151,110,154,295.0,17.9,51.8
941,purple,magenta,Greyish dark purple,#8D4E85,141,78,133,308.0,28.8,42.9
942,purple,magenta,Greyish dark purple,#a87ca0,168,124,160,310.0,20.2,57.3
946,brown,brown,Grey brown,#8C7853,140,120,83,39.0,25.6,43.7
950,brown,medium dark orange,Medium dark greyish brown,#785e49,120,94,73,26.0,24.4,37.8
956,brown,orange,Greyish dark brown,#b0927a,176,146,122,26.0,25.5,58.4
962,brown,red-orange,Greyish brown,#8b5f4d,139,95,77,17.0,28.7,42.4
965,grey,yellow,Grey yellow,#85754E,133,117,78,43.0,26.1,41.4
966,purple,magenta,Greyish purple,#915C83,145,92,131,316.0,22.4,46.5
968,grey,pink,Greyish dark pink,#976F7B,151,111,123,342.0,16.1,51.4
970,purple,pink,Greyish dark pink,#A65E7E,166,94,126,333.0,28.8,51.0
972,grey,medium dark pink-red,Greyish dark purple,#755258,117,77,82,353.0,17.6,39.0
973,brown,medium dark red,Greyish dark red,#7C4848,124,72,72,0.0,26.5,38.4
974,brown,pink-red,Greyish dark pink-red,#8E616A,142,97,106,348.0,18.8,46.9
975,grey,pink-red,Greyish dark pink-red,#7E5E60,126,94,96,356.0,14.5,43.1
978,brown,red,Dark greyish brown,#996666,149,102,102,0.0,20.0,50.0
983,brown,red,Dark greyish brown,#986960,152,105,96,10.0,22.6,48.6
988,purple,blue-magenta,Greyish dark violet,#89729e,137,114,158,271.0,18.5,53.3
989,purple,blue-magenta,Greyish dark violet,#926EAE,146,110,174,274.0,28.3,55.7
991,grey,medium dark blue-magenta,Dark greyish blue-purple,#5a4f74,90,79,116,257.0,19.0,38.2
995,brown,yellow,Orange yellow,#e3b130,227,177,48,43.0,76.2,53.9
1000,blue,light cyan,Pale blue,#a6e7ff,166,231,255,196.0,100.0,82.5
1002,cyan,light cyan,Pale cyan,#B2FFFF,178,255,255,180.0,100.0,84.9
1003,blue,very light cyan,Pale cyan,#b9f2ff,185,242,255,191.0,100.0,86.3
1004,purple,very light magenta,Pale magenta,#F4BBFF,249,192,255,294.0,100.0,86.7
1009,brown,light red-orange,Pale orange,#FFB79B,255,185,123,28.0,100.0,80.4
1016,pink,light pink,Pale pink,#FFAFC8,255,175,200,341.0,100.0,84.3
1020,pink,very light pink-red,Pale red,#FFB7C5,255,183,197,348.0,100.0,85.9
1022,pink,light red,Pale red-pink,#ffb3a7,255,179,167,8.0,100.0,82.7
1023,purple,light blue-magenta,Pale violet,#E0B0FF,224,176,255,276.0,100.0,84.5
1025,yellow,light yellow-green,Pale yellow,#FCFFA4,252,255,164,62.0,100.0,82.2
1030,pink,pink-red,Pink-red,#DA2C43,218,44,67,352.0,70.2,51.4
1034,blue,blue-magenta,Blue-violet,#3F00FF,63,0,255,255.0,100.0,50.0
1037,blue,cyan,Blue,#00aaee,0,170,238,197.0,100.0,46.7
1041,blue,cyan-blue,Blue,#0070FF,0,112,255,214.0,100.0,50.0
1047,cyan,cyan,Cyan,#00FFFF,0,255,255,180.0,100.0,50.0
1052,green,green,Lime-green,#00FF40,0,255,64,135.0,100.0,50.0
1054,green,green-cyan,Green-cyan,#00FF7F,0,255,127,150.0,100.0,50.0
1060,green,green,Green,#7CFC00,124,252,0,90.0,100.0,49.4
1065,green,yellow-green,Green,#BFFF00,191,255,0,75.0,100.0,50.0
1067,green,green,Lime-green,#00FF00,0,255,0,120.0,100.0,50.0
1069,pink,magenta,Purple,#FF00FF,255,0,255,300.0,100.0,50.0
1070,pink,magenta,Purple,#FF00CC,255,0,204,312.0,100.0,50.0
1073,purple,magenta,Purple,#CB00F5,203,0,245,290.0,100.0,48.0
1076,brown,brown,Brown,#E48400,228,132,0,35.0,100.0,44.7
1084,orange,brown,Orange,#ff9900,255,153,0,36.0,100.0,50.0
1098,orange,orange,Orange,#FF6700,255,103,0,24.0,100.0,50.0
1108,red,red-orange,Red-orange,#ff4200,255,66,0,15.0,100.0,50.0
1113,orange,yellow,Yellow,#fdb900,253,185,0,43.0,100.0,49.6
1125,pink,pink,Pink-red,#FF007F,255,0,127,330.0,100.0,50.0
1137,red,pink-red,Red,#FF0038,255,0,56,347.0,100.0,50.0
1144,red,red,Red,#FF0000,255,0,0,0.0,100.0,50.0
1146,red,red,Red,#FF2400,255,36,0,8.0,100.0,50.0
1149,red,red-orange,Red-orange,#FF3F00,255,63,0,15.0,100.0,50.0
1157,purple,blue-magenta,Purple,#8F00FF,143,0,255,274.0,100.0,50.0
1170,yellow,yellow,Yellow,#FFDF00,255,223,0,52.0,100.0,50.0
1183,green,yellow-green,Yellow-green,#CCFF00,204,255,0,72.0,100.0,50.0
1186,yellow,yellow-green,Bright yellow,#FFFF00,255,255,0,60.0,100.0,50.0
1188,brown,red-orange,Red-orange,#e35c38,227,92,56,12.0,75.3,55.5
1190,blue,blue,Greyish blue,#6576B4,101,118,180,227.0,34.5,55.1
1192,purple,blue-magenta,Greyish blue,#7366BD,115,102,189,249.0,39.7,57.1
1194,blue,cyan-blue,Greyish blue,#6D9BC3,109,155,195,208.0,41.7,59.6
1195,blue,cyan-blue,Greyish blue,#6082B6,96,130,182,216.0,37.1,54.5
1196,blue,medium light blue,Medium greyish blue,#8A9CC4,138,156,196,221.0,33.0,65.5
1198,blue,medium light blue,Medium greyish blue,#7A83BF,122,131,191,232.0,35.0,61.4
1199,purple,medium light blue-magenta,Medium greyish purple,#766EC8,118,110,200,246.0,45.0,60.8
1202,purple,medium light blue-magenta,Medium greyish purple,#9F91CF,159,145,207,254.0,39.2,69.0
1203,purple,medium light blue-magenta,Medium greyish purple,#8C82B6,140,52,182,281.0,26.3,61.2
1208,blue,medium light cyan-blue,Medium greyish cyan,#70A3CC,112,163,204,207.0,47.4,62.0
1213,cyan,medium light cyan,Greyish cyan,#81D8D0,129,216,208,174.0,52.7,67.6
1214,green,green-cyan,Greyish green-cyan,#66c992,102,201,146,146.0,47.8,59.4
1216,green,medium light green-cyan,Medium greyish green-cyan,#A0D6B4,160,214,180,142.0,39.7,73.3
1217,green,medium light green-cyan,Medium greyish green-cyan,#88d8c0,136,216,192,162.0,50.6,69.0
1218,green,green,Greyish green,#9AB973,154,185,115,87.0,33.3,58.8
1222,green,medium light green,Greyish green,#93C572,147,197,146,119.0,41.7,61.0
1224,green,green,Greyish lime green,#71bc78,113,188,120,125.0,35.9,59.0
1227,purple,medium light magenta,Greyish purple,#C693C7,198,147,199,299.0,31.7,67.8
1230,purple,medium light magenta,Greyish purple,#D498CB,212,152,203,309.0,41.1,71.4
1236,brown,medium light brown,Greyish brown,#d3b17d,211,177,125,36.0,49.4,65.9
1242,brown,medium light orange,Greyish brown,#BC987E,188,152,26,47.0,31.6,61.6
1244,brown,orange,Greyish brown,#C48E69,196,142,105,24.0,43.5,59.0
1246,brown,red-orange,Brown,#B4745E,180,116,194,289.0,36.4,53.7
1247,brown,yellow,Greyish yellow brown,#bba46d,187,164,109,42.0,36.4,58.0
1253,pink,medium light magenta-pink,Greyish purple,#CA82AF,202,130,175,323.0,40.4,65.1
1262,pink,medium light pink,Greyish pink,#D47494,212,116,148,340.0,52.7,64.3
1269,purple,medium light pink-red,Greyish pink-red,#CC8899,204,136,153,345.0,40.0,66.7
1273,brown,medium light red,Greyish brown,#C08181,192,128,125,3.0,33.3,62.9
1276,grey,pink-red,Greyish pink-red,#B57281,181,114,129,347.0,31.2,57.8
1279,brown,red,Greyish brown,#b56c60,181,108,96,8.0,36.5,54.3
1283,purple,blue-magenta,Greyish violet,#9678B6,150,120,182,269.0,29.8,59.2
1289,purple,medium light blue-magenta,Medium greyish purple,#ba93d8,186,147,216,273.0,46.9,71.2
1296,grey,medium light yellow,Greyish yellow,#D6CE7B,214,206,123,55.0,52.6,66.1
1305,purple,blue-magenta,Soft blue-purple,#6050DC,96,80,220,247.0,66.7,58.8
1308,blue,light cyan-blue,Soft blue,#87CEFA,135,206,250,203.0,92.0,75.5
1310,purple,medium light blue-magenta,Soft blue-purple,#7B68EE,123,104,238,249.0,79.8,67.1
1316,blue,medium light cyan-blue,Medium soft blue,#74ACDF,116,172,223,209.0,62.6,66.5
1323,blue,medium light cyan,Soft cyan,#71D9E2,113,217,226,185.0,66.1,66.5
1326,green,medium light green,Soft lime green,#64e986,100,233,134,135.0,75.1,65.3
1328,green,medium light green,Soft green,#B2EC5D,178,236,53,79.0,79.0,64.5
1330,green,medium light green,Soft lime green,#77DD77,119,221,119,120.0,60.0,66.7
1334,purple,medium light magenta,Soft purple,#DF63E6,223,99,230,297.0,72.4,64.5
1341,brown,medium light brown,Soft brown,#E1A95F,225,169,95,34.0,68.4,62.7
1349,brown,medium light orange,Soft orange,#D99A6C,217,154,108,34.0,58.9,63.7
1358,brown,medium light red-orange,Soft brown,#DA8A67,218,138,103,18.0,60.8,62.9
1364,yellow,medium light yellow,Soft yellow,#F2C649,242,198,73,44.0,86.7,61.8
1366,brown,orange,Soft brown,#D99058,217,144,88,26.0,62.9,59.8
1368,pink,light pink,Soft pink,#FC89AC,252,137,172,342.0,95.0,76.3
1369,pink,medium light magenta,Soft pink-purple,#EB6FCB,235,111,203,315.0,75.6,67.8
1371,pink,medium light magenta-pink,Soft pink,#F653A6,246,83,166,329.0,90.1,64.5
1373,pink,medium light pink,Soft pink,#DE6FA1,222,111,61,19.0,62.7,65.3
1383,pink,medium light pink,Soft pink,#EC5486,236,84,134,340.0,80.0,62.7
1396,pink,light pink-red,Soft red,#FE828C,254,130,140,355.0,98.4,75.3
1397,pink,medium light pink-red,Soft red,#F05B78,253,91,153,337.0,83.2,64.9
1402,pink,medium light pink-red,Soft red,#F57584,245,117,132,353.0,86.5,71.0
1413,pink,medium light red,Soft red,#fd7c6e,253,124,110,5.0,97.3,71.2
1421,brown,medium light red-orange,Soft brown,#f9906f,249,144,111,14.0,92.0,70.6
1423,orange,medium light red-orange,Soft brown,#F99379,248,131,121,5.0,91.4,72.5
1424,orange,medium light red-orange,Soft brown,#f07f5e,240,127,94,13.0,83.0,65.5
1427,brown,red,Soft red-brown,#da614e,218,97,78,8.0,65.4,58.0
1428,red,red,Soft red-brown,#dc5349,220,83,73,4.0,67.7,57.5
1430,purple,medium light blue-magenta,Soft violet,#9457EB,148,87,235,265.0,78.7,63.1
1431,purple,medium light blue-magenta,Soft violet,#C77DF3,199,125,243,278.0,83.1,72.2
1432,purple,medium light magenta,Soft violet,#D46FF9,212,111,249,284.0,92.0,70.6
1433,yellow,light yellow,Soft yellow,#FCE883,252,232,131,50.0,95.3,75.1
1434,green,light yellow-green,Soft yellow,#E3F988,227,249,136,72.0,90.4,75.5
1443,yellow,medium light yellow,Soft yellow,#E9D66B,233,214,107,51.0,74.1,66.7
1457,grey,medium light yellow-green,Soft yellow-green,#E8F24E,232,242,78,64.0,86.3,62.7
1464,blue,blue,Strong blue,#2243B6,34,67,182,227.0,68.5,42.4
1466,blue,Blue-magenta,Strong blue-purple,#0000CD,0,0,205,240.0,100.0,40.2
1467,blue,blue-magenta,Strong blue-purple,#360CCC,54,12,204,253.0,88.9,42.4
1470,blue,cyan,Strong cyan,#188bc2,24,139,194,199.0,78.0,42.7
1476,blue,cyan-blue,Strong cyan-blue,#1974D2,25,116,210,210.0,78.7,46.1
1482,blue,medium dark cyan,Medium dark cyan,#007BB8,0,123,184,200.0,100.0,36.1
1483,blue,medium dark cyan-blue,Medium dark cyan-blue,#0066CC,0,102,204,210.0,100.0,40.0
1484,purple,medium dark blue-magenta,Medium dark blue-purple,#1C05B3,28,5,179,248.0,94.6,36.1
1487,blue,medium dark cyan-blue,Medium dark cyan-blue,#006DBA,0,109,176,203.0,100.0,36.5
1491,blue,medium dark cyan-blue,Strong dark blue,#0048BA,0,72,186,217.0,100.0,36.5
1493,blue,cyan,Strong cyan,#18A7B5,24,167,181,185.0,76.6,40.2
1496,blue,cyan,Strong cyan,#21ABCD,33,171,205,192.0,72.3,46.7
1500,cyan,cyan,Strong cyan,#30D5C8,48,213,200,175.0,66.3,51.2
1502,cyan,cyan,Strong cyan,#00c5cd,0,197,205,182.0,100.0,40.2
1503,blue,medium dark cyan,Strong dark cyan,#0095B6,0,149,182,191.0,100.0,35.7
1504,cyan,medium dark cyan,Strong dark cyan,#00CCCC,0,204,204,180.0,100.0,40.0
1505,green,medium dark green-cyan,Strong dark cyan,#00CC99,0,204,153,165.0,100.0,40.0
1507,blue,medium dark cyan,Strong dark cyan,#00AFCA,0,175,202,188.0,100.0,39.6
1509,cyan,medium dark cyan,Strong dark cyan,#0ABAB5,10,186,181,178.0,89.8,38.4
1510,green,green-cyan,Strong green-cyan,#1AB385,26,179,33,123.0,74.6,40.2
1512,green,medium dark green,Strong green-cyan,#03C03C,3,192,60,138.0,96.9,38.2
1513,green,green,Strong green,#6BBE23,107,142,35,80.0,68.9,44.1
1514,green,green,Strong green,#76BD17,118,189,23,86.0,78.3,41.6
1516,green,green,Strong green,#4CBB17,76,187,23,101.0,78.1,41.2
1518,green,medium dark green,Strong green,#50B708,80,183,8,95.0,91.6,37.5
1519,green,medium dark green,Strong green,#33CC00,51,204,0,105.0,100.0,40.0
1522,green,yellow-green,Strong yellow-green,#9ACD32,154,205,50,80.0,60.8,50.0
1524,green,green,Strong lime green,#32CD32,50,205,50,120.0,60.8,50.0
1525,pink,magenta,Strong purple,#D500B6,213,0,182,309.0,100.0,41.8
1527,purple,magenta,Strong purple,#CC33CC,204,51,204,300.0,60.0,50.0
1530,purple,medium dark magenta,Strong dark purple,#aa00bb,170,0,187,294.0,100.0,36.7
1535,brown,brown,Strong brown,#ca7309,202,115,9,32.0,91.5,41.4
1539,brown,medium dark brown,Medium dark brown,#c86500,200,101,0,30.0,100.0,39.2
1540,brown,medium dark orange,Medium dark red-orange,#C04000,192,64,0,20.0,100.0,37.6
1541,brown,medium dark orange,Medium dark brown,#CC5500,204,85,0,25.0,100.0,40.0
1542,brown,medium dark red-orange,Medium dark red-orange,#B7410E,183,65,14,18.0,85.8,38.6
1544,brown,medium dark yellow,Medium dark yellow-brown,#B8860B,184,134,11,43.0,88.7,38.2
1550,brown,orange,Medium brown,#D2691E,210,105,30,25.0,75.0,47.1
1557,red,red-orange,Strong red-orange,#CB410B,203,65,11,17.0,89.7,42.0
1559,brown,yellow,Yellowish brown,#B78727,183,135,39,40.0,64.9,43.5
1566,pink,magenta-pink,Strong dark pink,#D40D7D,212,13,125,326.0,88.4,44.1
1571,red,medium dark pink,Strong dark red,#B80049,184,0,73,336.0,100.0,36.1
1572,red,medium dark pink,Strong dark red,#BE0032,190,0,50,344.0,100.0,37.3
1581,pink,pink,Strong pink,#BC2350,188,35,80,342.0,68.6,43.7
1590,red,medium dark pink-red,Strong dark red,#b60c26,182,12,38,350.0,87.6,38.0
1593,red,medium dark red,Strong dark red,#BA160C,186,22,12,3.0,87.9,38.8
1603,red,pink-red,Strong red,#C41E3A,196,30,58,350.0,73.5,44.3
1619,red,red,Strong red-brown,#bc2d29,188,45,41,1.0,64.2,44.9
1623,brown,red-orange,Strong brown,#b64925,182,73,37,14.0,66.2,42.9
1628,purple,magenta,Strong violet,#9400D3,148,0,211,282.0,100.0,41.4
1632,yellow,medium dark yellow,Strong dark yellow brown,#C1A004,193,160,4,50.0,95.9,38.6
1634,green,medium dark yellow-green,Strong dark yellow-green,#8DB600,141,182,0,74.0,100.0,35.7
1636,yellow,yellow,Strong dark yellow brown,#bd9b16,189,155,22,47.0,79.1,41.4
1637,green,yellow-green,Strong yellow-green,#B3C110,179,193,16,65.0,84.7,41.0
1638,green,yellow-green,Strong yellow-green,#BFD833,191,216,51,69.0,67.9,52.4
1640,green,yellow-green,Strong yellow-green,#A5CB0C,165,203,12,72.0,88.8,42.2
1643,yellow,yellow-green,Strong yellow-green,#CCCC33,204,204,51,60.0,60.0,50.0
1645,black,very dark cyan-blue,Black,#010203,1,2,3,210.0,50.0,0.8
1646,black,very dark blue,Black,#181b26,24,27,38,227.0,22.6,12.2
1647,black,very dark blue,Black,#17182b,23,24,43,237.0,30.3,12.9
1648,black,very dark cyan-blue,Black,#1f262a,31,38,42,201.0,15.1,14.3
1649,black,very dark cyan-blue,Black,#010B13,1,11,19,207.0,90.0,3.9
1650,black,dark cyan,Black,#232B2B,35,43,43,180.0,10.3,15.3
1651,black,very dark green-cyan,Black,#013220,1,50,32,158.0,96.1,10.0
1652,black,very dark green-cyan,Black,#1A2421,26,36,33,162.0,16.1,12.2
1653,black,dark green,Black,#2A2F23,42,47,35,85.0,14.6,16.1
1654,black,very dark green,Black,#1A2118,26,33,24,107.0,15.8,11.2
1655,black,very dark magenta,Black,#242124,36,33,36,300.0,4.3,13.5
1656,black,very dark brown,Black,#100C08,16,12,8,30.0,33.3,4.7
1659,black,very dark orange,Black,#2c1608,44,22,8,23.0,69.2,10.2
1661,black,very dark red-orange,Black,#2e211b,46,33,27,18.0,26.0,14.3
1662,black,very dark yellow,Black,#1B1811,27,24,17,42.0,22.7,8.6
1663,black,very dark magenta,Black,#2b2028,43,32,40,316.0,14.7,14.7
1664,black,very dark pink,Black,#23191e,35,25,30,330.0,16.7,11.8
1665,black,very dark red,Black,#321414,50,20,20,0.0,42.9,13.7
1666,black,very dark red,Black,#1a1110,26,17,16,5.0,23.8,8.2
1667,black,very dark red-orange,Black,#290E05,41,14,5,15.0,78.3,9.0
1668,black,very dark blue-magenta,Black,#0f031a,15,3,26,271.0,79.3,5.7
1669,blue,dark cyan-blue,Very dark blue,#003366,0,51,102,210.0,100.0,20.0
1670,black,dark blue,Very dark blue,#191F45,25,31,69,232.0,46.8,18.4
1673,blue,dark blue,Very dark blue,#1B294B,27,41,75,222.0,47.1,20.0
1679,blue,dark cyan-blue,Very dark blue,#003A6C,0,58,108,208.0,100.0,21.2
1683,blue,medium dark blue,Very dark blue,#233067,35,48,103,229.0,49.3,27.1
1684,blue,medium dark blue-magenta,Very dark blue,#191970,25,25,112,240.0,63.5,26.9
1686,black,very dark blue,Very dark blue,#001440,0,20,64,221.0,100.0,12.5
1687,black,very dark cyan-blue,Very dark blue,#002147,0,33,71,212.0,100.0,13.9
1688,green,dark cyan,Very dark cyan,#004953,0,73,83,187.0,100.0,16.3
1689,green,dark cyan,Very dark cyan,#044f67,4,79,103,194.0,92.5,21.0
1690,green,dark green-cyan,Very dark cyan,#18453B,24,69,59,167.0,48.4,18.2
1693,black,very dark cyan,Very dark cyan,#004040,0,64,64,180.0,100.0,12.5
1695,green,dark green-cyan,Very dark green,#006442,0,100,66,159.0,100.0,19.6
1696,green,dark green,Very dark green,#1e4d2b,30,77,43,136.0,43.9,21.0
1698,green,dark green-cyan,Very dark green,#006B3C,0,107,60,154.0,100.0,21.0
1700,green,dark green-cyan,Very dark green,#006A4E,0,106,78,164.0,100.0,20.8
1703,black,very dark green-cyan,Very dark green,#123524,18,53,36,151.0,49.3,13.9
1706,black,very dark green-cyan,Very dark green,#02402C,2,64,44,161.0,93.9,12.9
1707,green,very dark green-cyan,Very dark green,#014421,1,68,33,149.0,97.1,13.5
1709,blue,dark blue,Very dark grey blue,#1C2841,28,40,65,221.0,39.8,18.2
1712,grey,medium dark blue-magenta,Very dark grey blue,#3b3b6d,59,59,109,240.0,29.8,32.9
1713,blue,medium dark cyan,Very dark grey blue,#344d56,52,77,86,195.0,24.6,27.1
1714,blue,dark cyan,Very dark grey cyan,#264348,38,67,72,189.0,30.9,21.6
1716,grey,dark cyan,Very dark grey cyan,#203838,32,56,56,180.0,27.3,17.3
1718,green,dark green-cyan,Very dark grey green,#224634,34,70,52,150.0,34.6,20.4
1720,green,medium dark green-cyan,Very dark grey green,#35654d,53,101,77,150.0,31.2,30.2
1721,grey,medium dark green,Very dark grey green,#2a603b,42,96,59,138.0,39.1,27.1
1722,grey,dark yellow-green,Very dark grey green,#454d32,69,77,50,77.0,21.3,24.9
1724,green,medium dark green,Very dark grey green,#355E3B,53,94,59,129.0,27.9,28.8
1725,grey,medium dark green,Very dark grey green,#306030,48,96,48,120.0,33.3,28.2
1726,purple,dark magenta,Very dark grey purple,#301934,48,25,52,291.0,35.1,15.1
1727,purple,dark magenta,Very dark grey purple,#3a243b,58,36,59,297.0,24.2,18.6
1728,purple,dark magenta,Very dark grey purple,#4F284B,79,40,75,306.0,32.8,23.3
1729,grey,medium dark magenta,Very dark grey purple,#5D3954,93,57,84,315.0,24.0,29.4
1730,purple,medium dark magenta,Very dark grey purple,#602F6B,96,47,107,289.0,39.0,30.2
1732,purple,medium dark magenta,Very dark grey purple,#56365C,86,54,92,291.0,26.0,28.6
1733,purple,medium dark magenta,Very dark grey purple,#5B3256,91,50,86,307.0,29.1,27.6
1736,black,dark orange,Very dark brown,#4c3d30,76,61,48,27.0,22.6,24.3
1748,grey,medium dark yellow,Medium dark brown,#534a32,83,74,50,43.0,24.8,26.1
1751,purple,medium dark magenta-pink,Very dark grey pink,#723157,114,49,87,325.0,39.9,32.0
1754,grey,medium dark pink,Very dark grey pink,#66424d,102,66,77,342.0,21.4,32.9
1755,purple,medium dark pink,Very dark grey pink,#673147,103,49,71,336.0,35.5,29.8
1757,brown,dark pink-red,Very dark grey red,#3c2126,60,33,38,348.0,29.0,18.2
1760,black,dark red,Very dark grey red,#351e1c,53,30,28,4.0,30.9,15.9
1762,brown,dark red-orange,Very dark grey red,#542d24,84,45,36,11.0,40.0,23.5
1766,brown,medium dark pink-red,Very dark grey red,#722F37,114,47,55,353.0,41.6,31.6
1770,brown,medium dark red,Very dark grey red,#704241,112,66,65,1.0,26.6,34.7
1771,brown,medium dark red-orange,Very dark grey red,#523b35,82,59,53,12.0,21.5,26.5
1772,grey,medium dark blue-magenta,Very dark grey violet,#54446C,84,68,108,264.0,22.7,34.5
1773,purple,medium dark blue-magenta,Very dark grey violet,#3d325d,61,50,93,255.0,30.1,28.0
1774,purple,medium dark magenta,Very dark grey violet,#5d3f6a,93,63,106,281.0,25.4,33.1
1775,grey,dark yellow,Very dark grey yellow,#524b2a,82,75,42,49.0,32.3,24.3
1776,grey,medium dark yellow-green,Very dark grey yellow,#6e6e30,110,110,48,60.0,39.2,31.0
1777,grey,medium dark yellow-green,Very dark grey yellow,#545a2c,84,90,44,67.0,34.3,26.3
1778,green,dark green,Very dark green,#296e01,41,110,1,97.0,98.2,21.8
1779,green,medium dark green,Very dark green,#4c721d,76,114,29,86.0,59.4,28.0
1780,green,medium dark yellow-green,Very dark green,#4A5D23,74,93,35,80.0,45.3,25.1
1783,grey,grey,Very dark grey,#676767,103,103,103,0.0,0.0,40.4
1788,black,very dark grey,Black,#1B1B1B,27,27,27,0.0,0.0,10.6
1791,grey,dark cyan-blue,Very dark greyish blue,#2a3439,42,52,57,200.0,15.2,19.4
1793,grey,medium dark blue,Very dark greyish blue,#4C516D,76,81,109,231.0,17.8,36.3
1794,grey,medium dark blue-magenta,Very dark greyish blue,#41415D,65,65,93,240.0,17.7,31.0
1796,grey,medium dark cyan,Very dark greyish blue,#4d646c,77,100,108,195.0,16.8,36.3
1797,grey,medium dark cyan-blue,Very dark greyish blue,#36454F,54,69,79,204.0,18.8,26.1
1798,grey,medium dark cyan-blue,Very dark greyish blue,#54626F,84,98,111,209.0,13.8,38.2
1799,grey,dark cyan,Very dark greyish cyan,#2D383A,45,56,58,189.0,12.6,20.2
1800,grey,dark cyan,Very dark greyish cyan,#2b3736,43,55,54,175.0,12.2,19.2
1801,grey,dark cyan,Very dark greyish cyan,#364141,54,65,65,180.0,9.2,23.3
1805,grey,medium dark cyan,Very dark greyish cyan,#414a4c,65,74,76,190.0,7.8,27.6
1808,grey,dark green-cyan,Very dark greyish lime,#2d4436,45,68,54,143.0,20.4,22.2
1812,grey,dark green,Very dark greyish green,#354230,53,66,48,103.0,15.8,22.4
1813,grey,dark yellow-green,Very dark greyish green,#3d4035,61,64,53,76.0,9.4,22.9
1814,grey,medium dark green,Very dark greyish green,#444C38,68,76,56,84.0,15.2,25.9
1815,grey,medium dark green,Very dark greyish green,#555D50,85,93,80,97.0,7.5,33.9
1816,grey,medium dark yellow-green,Very dark greyish green,#5e644f,94,100,79,77.0,11.7,35.1
1817,grey,dark green,Very dark greyish lime green,#2e372e,46,55,46,120.0,8.9,19.8
1818,grey,dark green,Very dark greyish lime green,#3a403b,58,64,59,130.0,4.9,23.9
1819,grey,medium dark green,Very dark greyish lime green,#5a6457,90,100,87,106.0,7.0,36.7
1820,grey,medium dark green,Very dark greyish lime green,#465945,70,89,69,116.0,12.7,31.0
1821,grey,medium dark green,Very dark greyish lime green,#3d5d42,61,93,66,129.0,20.8,30.2
1822,grey,magenta,Very dark greyish magenta,#715F6D,113,92,86,13.0,8.7,40.8
1824,grey,medium dark magenta,Very dark greyish magenta,#6A5767,106,87,103,309.0,9.8,37.8
1827,purple,medium dark magenta,Very dark greyish magenta,#563C5C,86,60,92,289.0,21.1,29.8
1828,purple,medium dark magenta,Very dark greyish magenta,#513653,81,54,83,296.0,21.2,26.9
1830,grey,dark brown,Very dark greyish orange,#463F32,70,63,50,39.0,16.7,23.5
1831,black,dark orange,Very dark greyish orange,#483C32,72,60,50,27.0,18.0,23.9
1832,black,dark red-orange,Very dark greyish orange,#393432,57,52,50,17.0,6.5,21.0
1833,grey,medium dark brown,Very dark greyish orange,#5C5248,92,82,72,30.0,12.2,32.2
1834,grey,medium dark brown,Very dark greyish orange,#5e5545,94,85,69,38.0,15.3,32.0
1838,grey,medium dark orange,Very dark greyish orange,#5c544e,92,84,78,25.0,8.2,33.3
1842,grey,yellow,Very dark greyish orange,#71706E,113,112,117,252.0,1.3,43.7
1843,grey,dark magenta-pink,Very dark greyish pink,#3f313a,63,49,58,321.0,12.5,22.0
1844,grey,medium dark magenta,Very dark greyish pink,#51354A,81,53,74,315.0,20.9,26.3
1846,grey,medium dark pink,Very dark greyish pink,#534B4F,83,75,79,330.0,5.1,31.0
1849,grey,medium dark pink,Very dark greyish pink,#63424b,99,66,75,344.0,20.0,32.4
1850,black,dark red,Very dark greyish red,#3B2F2F,59,47,47,0.0,11.3,20.8
1851,black,dark red,Very dark greyish red,#43302E,67,31,26,7.0,18.6,22.2
1852,black,dark red-orange,Very dark greyish red,#352925,53,41,37,15.0,17.8,17.6
1854,grey,medium dark pink-red,Very dark greyish red,#4d3b3c,77,59,60,356.0,13.2,26.7
1855,brown,medium dark red,Very dark greyish red,#674846,103,76,71,9.0,19.1,33.9
1856,brown,medium dark red,Very dark greyish red,#674C47,103,76,21,40.0,18.4,34.1
1858,grey,medium dark red,Very dark greyish red,#645452,100,84,82,6.0,9.9,35.7
1860,grey,medium dark red,Very dark greyish red,#504040,80,64,77,311.0,11.1,28.2
1861,grey,medium dark red-orange,Very dark greyish red,#543D37,84,61,55,12.0,20.9,27.3
1863,grey,medium dark blue-magenta,Very dark greyish violet,#614e6e,97,78,110,275.0,17.0,36.9
1865,grey,dark yellow-green,Very dark greyish yellow,#3B3C36,59,60,54,70.0,5.3,22.4
1867,grey,medium dark yellow,Very dark greyish yellow,#4d4b3a,77,75,58,53.0,14.1,26.5
1869,grey,medium dark yellow-green,Very dark greyish yellow,#52593b,82,89,59,73.0,20.3,29.0
1870,grey,dark green,Very dark lime green,#006400,0,100,0,120.0,100.0,19.6
1871,green,dark green,Very dark lime green,#195905,25,89,5,106.0,89.4,18.4
1872,green,dark green,Very dark lime green,#136207,19,98,7,112.0,86.7,20.6
1874,green,dark green,Very dark lime green,#056608,5,102,8,121.0,90.7,21.0
1875,grey,dark green,Very dark lime green,#006600,0,102,0,120.0,100.0,20.0
1876,purple,dark magenta,Very dark purple,#480656,72,6,86,290.0,87.0,18.0
1877,purple,dark magenta,Very dark purple,#660066,102,0,102,300.0,100.0,20.0
1878,purple,dark magenta,Very dark purple,#4E0041,78,0,65,310.0,100.0,15.3
1880,purple,medium dark magenta,Very dark purple,#702670,112,38,112,300.0,49.3,29.4
1882,purple,medium dark magenta,Very dark purple,#702963,112,41,99,311.0,46.4,30.0
1884,black,very dark magenta,Very dark purple,#360029,54,0,41,314.0,100.0,10.6
1885,brown,dark brown,Very dark brown,#663300,102,51,0,30.0,100.0,20.0
1886,brown,dark brown,Very dark brown,#644117,100,65,23,33.0,62.6,24.1
1888,brown,dark brown,Very dark brown,#563c0d,86,60,13,38.0,73.7,19.4
1889,brown,dark orange,Very dark brown,#59260B,89,38,11,0.0,78.0,19.6
1892,brown,medium dark brown,Very dark brown,#704214,112,66,20,30.0,69.7,25.9
1894,brown,medium dark orange,Very dark brown,#664228,102,66,40,25.0,43.7,27.8
1896,brown,medium dark yellow,Very dark brown,#6C541E,108,84,30,42.0,56.5,27.1
1897,black,very dark orange,Very dark brown,#391802,57,24,2,24.0,93.2,11.6
1898,purple,dark magenta,Very dark pink,#660045,102,0,69,319.0,100.0,20.0
1900,purple,dark magenta-pink,Very dark pink,#66033c,102,3,60,325.0,94.3,20.6
1901,purple,dark magenta-pink,Very dark pink,#66023C,102,2,60,325.0,96.2,20.4
1904,black,dark pink,Very dark pink,#3c1421,60,20,33,340.0,50.0,15.7
1908,purple,medium dark magenta-pink,Very dark pink,#6d2b50,109,43,80,326.0,43.4,29.8
1909,purple,medium dark pink,Very dark pink,#6E1C34,110,28,52,342.0,59.4,27.1
1910,brown,dark red,Very dark red,#660000,102,0,0,0.0,100.0,20.0
1912,brown,dark pink-red,Very dark red,#65000B,101,0,11,353.0,100.0,19.8
1913,brown,dark pink-red,Very dark red,#480607,72,6,7,359.0,84.6,15.3
1914,purple,dark pink-red,Very dark red,#670F25,103,15,37,345.0,74.6,23.1
1920,brown,dark red,Very dark red,#592720,89,39,32,7.0,47.1,23.7
1925,brown,medium dark pink-red,Very dark red,#681C23,104,28,35,354.0,57.6,25.9
1929,brown,medium dark red,Very dark red,#6f3028,111,48,40,6.0,47.0,29.6
1933,black,very dark pink-red,Very dark red,#3f000f,63,0,15,345.0,100.0,12.4
1934,black,very dark pink-red,Very dark red,#490206,73,2,6,356.0,94.7,14.7
1935,black,very dark red,Very dark red,#3D0C02,61,12,2,10.0,93.7,12.4
1936,purple,dark blue-magenta,Very dark violet,#290C5E,41,12,94,261.0,77.4,20.8
1939,purple,dark blue-magenta,Very dark violet,#330066,51,0,102,270.0,100.0,20.0
1941,purple,dark magenta,Very dark violet,#431c53,67,28,83,282.0,49.5,21.8
1942,brown,dark yellow,Very dark olive,#514100,81,65,0,48.0,100.0,15.9
1943,grey,dark yellow-green,Very dark olive,#4B5320,75,83,32,69.0,44.3,22.5
1944,grey,medium dark yellow,Very dark olive,#665D1E,102,93,30,53.0,54.5,25.9
1945,grey,medium dark yellow,Very dark olive,#716E10,113,110,16,58.0,75.2,25.3
1946,purple,light blue-magenta,Very light blue-purple,#9999FF,153,153,255,240.0,100.0,80.0
1947,purple,light blue-magenta,Very light blue-purple,#8080FF,128,128,255,240.0,100.0,75.1
1948,blue,medium light cyan-blue,Very light cyan-blue,#7eb6ff,126,182,255,213.0,100.0,74.7
1950,cyan,medium light green-cyan,Very light cyan-green,#7FFFD4,127,255,212,160.0,100.0,74.9
1951,green,medium light green,Very light green,#9FFF7F,159,255,127,105.0,100.0,74.9
1953,grey,very light grey,Very light grey,#DADADA,218,218,218,0.0,0.0,85.5
1955,white,very light grey,Greyish white,#F5F5F5,245,245,245,0.0,0.0,96.1
1956,green,light green,Very light lime green,#98FF98,152,255,152,120.0,100.0,79.8
1958,purple,light magenta,Very light purple,#E285FF,226,133,255,286.0,100.0,76.1
1960,pink,medium light magenta,Very light purple,#FF77FF,255,119,255,300.0,100.0,73.3
1962,brown,light brown,Very light orange,#FFCC99,255,204,153,30.0,100.0,80.0
1963,orange,light orange,Very light orange,#FFB280,255,178,128,24.0,100.0,75.1
1964,pink,light red-orange,Very light orange,#FFAA8D,255,170,141,15.0,100.0,77.6
1965,orange,light yellow,Very light orange,#FFBD88,255,189,136,27.0,100.0,76.7
1966,brown,medium light brown,Very light orange,#ffc87c,255,200,124,34.0,100.0,74.3
1968,orange,medium light orange,Very light orange,#ffb077,255,176,119,25.0,100.0,73.3
1969,brown,medium light red-orange,Very light orange,#FFA07A,255,160,122,17.0,100.0,73.9
1970,pink,light magenta-pink,Very light pink,#ff85cf,255,133,207,323.0,100.0,76.1
1971,pink,light pink,Very light pink,#ff99cc,255,153,204,330.0,100.0,80.0
1972,pink,light pink,Very light pink,#FF91AF,255,145,175,344.0,100.0,78.4
1974,pink,light red,Very light red,#FF9999,255,153,153,0.0,100.0,80.0
1975,pink,light pink-red,Very light red,#FF91A4,255,145,164,350.0,100.0,78.4
1977,pink,light pink-red,Very light red,#ff9899,255,152,153,359.0,100.0,79.8
1978,orange,light red-orange,Very light red,#FF9980,255,153,128,12.0,100.0,75.1
1980,pink,medium light pink-red,Very light red,#FF7077,255,112,119,357.0,100.0,72.0
1981,orange,medium light red-orange,Very light red,#FF8C69,255,140,105,14.0,100.0,70.6
1982,purple,light blue-magenta,Very light violet,#CC99FF,204,153,255,270.0,100.0,80.0
1983,yellow,light yellow,Very light yellow,#FFEC8B,255,236,139,50.0,100.0,77.3
1984,yellow,light yellow-green,Very light yellow,#FFFF99,255,255,153,60.0,100.0,80.0
1985,yellow,medium light yellow,Very light yellow,#ffe670,255,230,112,49.0,100.0,72.0
1986,white,very light blue-magenta,Blueish white,#F8F8FF,248,248,255,240.0,100.0,98.6
1987,white,very light cyan-blue,Blueish white,#F0F8FF,240,248,255,208.0,100.0,97.1
1989,white,very light cyan,White,#F5FFFF,245,255,255,180.0,100.0,98.0
1990,white,very light cyan,Cyan tint white,#E7FEFF,231,254,255,183.0,100.0,95.3
1992,white,very light green-cyan,White,#F5FFFA,245,255,250,150.0,100.0,98.0
1993,white,very light green,White,#F0FFF0,240,255,240,120.0,100.0,97.1
1994,white,very light brown,White,#FFF9F0,255,249,240,36.0,100.0,97.1
1995,white,very light brown,White,#FFF8ED,255,248,237,37.0,100.0,96.5
1996,white,very light brown,White,#FFFAF0,255,250,240,40.0,100.0,97.1
1997,white,very light orange,White,#FFF5EE,255,245,238,25.0,100.0,96.7
1998,white,very light red-orange,White,#FFF1EB,255,241,235,18.0,100.0,96.1
1999,white,very light yellow,White,#FFF8E7,255,248,231,43.0,100.0,95.3
2000,white,very light magenta,Pinkish white,#FFF1FB,255,241,251,317.0,100.0,97.3
2002,white,very light pink,Pinkish white,#FFF9FB,255,245,251,324.0,100.0,98.8
2003,white,very light pink,Pinkish white,#FFF0F5,255,240,245,340.0,100.0,97.1
2005,white,very light red,White,#FFFAFA,255,250,250,0.0,100.0,99.0
2007,white,very light red,Reddish white,#FFF0EE,255,240,238,7.0,100.0,96.7
2008,white,very light red,Reddish white,#FFF6F5,255,246,243,15.0,100.0,98.0
2009,white,very light blue-magenta,Purplish white,#f8f4ff,248,244,255,261.0,100.0,97.8
2010,white,very light yellow-green,White,#FFFFF0,255,255,240,60.0,100.0,97.1
2011,white,very light yellow-green,White,#fdfff5,253,255,245,71.0,100.0,98.0
2012,purple,very light blue-magenta,Very light blue-purple,#CCCCFF,204,204,255,240.0,100.0,90.0
2013,purple,very light blue-magenta,Very light blue-purple,#C7C1FF,199,193,255,246.0,100.0,87.8
2014,cyan,very light cyan,Very pale cyan,#E0FFFF,224,255,255,180.0,100.0,93.9
2015,green,very light green-cyan,Very pale cyan,#DBFFF8,219,255,248,168.0,100.0,92.9
2016,cyan,very light green-cyan,Very light green-cyan,#C9FFE5,201,255,229,151.0,100.0,89.4
2018,green,very light green,Very pale green,#E9FFDB,233,255,219,97.0,100.0,92.9
2019,pink,very light magenta,Very pale purple,#FFCCFF,255,204,255,300.0,100.0,90.0
2020,pink,very light magenta,Very pale purple,#FFD3F8,255,211,248,310.0,100.0,91.4
2021,brown,very light orange,Very pale orange,#ffe4cd,255,228,205,27.0,100.0,90.2
2024,brown,very light brown,Very pale orange,#FFF0DB,255,240,219,35.0,100.0,92.9
2027,grey,very light brown,Very pale orange,#FFF0E0,255,240,224,31.0,100.0,93.9
2028,pink,very light orange,Very pale orange,#FFDDCA,255,221,202,22.0,100.0,89.6
2030,pink,very light magenta,Very pale pink,#FFDDF4,255,221,207,18.0,100.0,93.3
2031,pink,very light magenta,Very pale pink,#ffcff1,255,207,241,317.0,100.0,90.6
2032,pink,very light magenta-pink,Very pale pink,#FFc1E8,255,193,232,322.0,100.0,87.8
2034,pink,very light pink,Very pale pink,#FFDAE9,255,218,233,336.0,100.0,92.7
2036,pink,very light pink-red,Very pale red,#FFE4E9,255,228,233,349.0,100.0,94.7
2038,pink,very light pink-red,Very pale red,#FFC0CB,255,192,203,350.0,100.0,87.6
2041,white,very light red,Pale pink,#FFE4E1,255,228,225,6.0,100.0,94.1
2042,purple,very light blue-magenta,Very pale violet,#DCD0FF,220,208,255,255.0,100.0,90.8
2043,grey,very light yellow,Very pale yellow,#FFF8DC,255,248,220,48.0,100.0,93.1
2044,white,very light yellow-green,Very pale yellow,#FFFFE0,255,255,224,60.0,100.0,93.9
2046,yellow,very light yellow,Very pale yellow,#FFFDD0,255,253,208,57.0,100.0,90.8
2048,white,very light yellow-green,Very pale yellow,#f9ffe3,249,255,227,72.0,100.0,94.5
2050,blue,light blue,Very soft blue,#B3BCE2,179,188,226,229.0,44.8,79.4
2051,purple,light blue-magenta,Very soft blue,#ACACE6,172,172,230,240.0,53.7,78.8
2052,purple,light blue-magenta,Very soft blue,#C1BBEC,193,187,236,247.0,56.3,82.9
2053,purple,light blue-magenta,Very soft blue,#A899E6,168,153,230,252.0,60.6,75.1
2055,blue,light cyan-blue,Very soft blue,#B9D9EB,185,217,235,202.0,55.6,82.4
2057,blue,light cyan-blue,Very soft blue,#A1CAF1,161,202,241,209.0,74.1,78.8
2058,blue,light cyan-blue,Very soft blue,#abcdef,171,205,239,210.0,68.0,80.4
2060,purple,medium light blue-magenta,Very soft blue,#8581D9,133,129,217,243.0,53.7,67.8
2061,purple,medium light blue-magenta,Very soft blue,#9683EC,150,131,236,251.0,73.4,72.0
2063,blue,medium light cyan,Very soft blue,#89CFF0,137,207,240,199.0,77.4,73.9
2067,blue,medium light cyan-blue,Very soft blue,#88ace0,136,172,224,215.0,58.7,70.6
2071,blue,light cyan,Very soft cyan,#ACE5EE,172,229,238,188.0,66.0,80.4
2076,cyan,light cyan,Very soft cyan,#AFEEEE,175,238,238,180.0,64.9,81.0
2080,cyan,medium light green-cyan,Very soft cyan,#8DD9CC,141,217,204,170.0,50.0,70.2
2083,green,light green-cyan,Very soft green-cyan,#9FE2BF,159,226,191,149.0,53.6,75.5
2085,green,light green,Very soft green,#D0F0C0,208,240,192,100.0,61.5,84.7
2086,green,medium light yellow-green,Very soft green,#C5E384,197,227,132,79.0,62.9,70.4
2087,green,light green,Very soft lime green,#A8E4A0,168,228,160,113.0,55.7,76.1
2090,green,light green,Very soft lime green,#ACE1AF,172,225,175,123.0,46.9,77.8
2094,purple,light magenta,Very soft magenta,#D891EF,216,145,239,285.0,74.6,75.3
2099,purple,medium light magenta,Very soft magenta,#DDA0DD,221,160,221,300.0,47.3,74.7
2100,purple,medium light magenta,Very soft magenta,#E29CD2,226,156,210,314.0,54.7,74.9
2102,brown,light brown,Light brown,#e7c9a9,231,201,169,30.0,56.4,78.4
2106,brown,light brown,Light brown,#e6d0ab,230,208,171,37.0,54.1,78.6
2112,brown,light orange,Light orange,#EDC9Af,237,201,175,25.0,63.3,80.8
2115,brown,light red-orange,Very soft orange,#EBC2AF,235,194,175,19.0,60.0,80.4
2117,brown,light yellow,Very soft orange,#ECD9B0,236,217,176,41.0,61.2,80.8
2119,brown,light yellow,Very soft orange,#FBE7B2,251,231,128,50.0,90.1,84.1
2122,brown,medium light brown,Very soft brown,#EAC592,234,197,146,35.0,67.7,74.5
2124,brown,medium light orange,Very soft brown,#DDAD95,221,173,149,20.0,51.4,72.5
2126,brown,very light orange,Very soft brown,#FDD9B5,253,217,181,30.0,94.7,85.1
2128,pink,light magenta-pink,Very soft pink,#E79EC5,231,94,197,315.0,60.3,76.3
2139,pink,light pink,Very soft pink,#EDBACD,237,186,205,338.0,58.6,82.9
2152,purple,medium light magenta-pink,Medium light pink,#D982B5,217,130,181,325.0,53.4,68.0
2153,pink,medium light pink,Medium light pink,#E38FB7,227,143,183,331.0,60.0,72.5
2156,pink,medium light pink,Medium light pink,#DC9DB3,220,157,179,339.0,47.4,73.9
2160,pink,very light pink,Very soft pink,#FBBEDA,251,190,218,332.0,88.4,86.5
2161,brown,light pink-red,Very soft red,#ddadaf,221,173,175,357.0,41.4,77.3
2163,pink,light pink-red,Very soft red,#F78FA7,247,143,167,346.0,86.7,76.5
2166,pink,light pink-red,Very soft red,#ED999C,237,153,156,358.0,70.0,76.5
2171,pink,light red,Light red,#fdbcb4,253,188,180,6.0,94.8,84.9
2175,orange,light red-orange,Light red-orange,#f6a08c,246,160,140,11.0,85.5,75.7
2177,pink,medium light pink-red,Medium light red,#d998a0,217,152,160,352.0,46.1,72.4
2180,brown,medium light red,Medium light red,#e7968b,231,150,139,7.0,65.7,72.5
2181,brown,medium light red-orange,Medium light red,#E1AD9D,225,173,157,14.0,53.1,74.9
2184,pink,very light red,Very light red,#F7BFBE,247,191,190,1.0,78.1,85.7
2187,pink,very light red-orange,Very light red,#fcc9b9,252,201,185,14.0,91.8,85.7
2194,purple,medium light blue-magenta,Very soft violet,#BA93DF,186,147,223,271.0,54.3,72.5
2201,yellow,light yellow,Very soft yellow,#f7e98e,247,233,142,51.0,86.8,76.3
2206,grey,light yellow-green,Light yellow-green,#EAEDA6,234,237,166,63.0,66.4,79.0
2210,grey,medium light yellow,Medium light yellow,#E8E08E,232,224,142,55.0,66.2,73.3
2214,green,medium light yellow-green,Medium light yellow-green,#c9dc87,201,220,135,73.0,54.8,69.6
2218,grey,very light yellow,Very light yellow,#F6EABE,246,234,190,47.0,75.7,85.5
2219,green,very light yellow-green,Very light yellow-green,#F3FDC6,243,253,198,71.0,93.2,88.4
2220,blue,blue,Vivid blue,#0247FE,2,71,254,224.0,99.2,50.2
2221,blue,blue-magenta,Vivid blue,#1c1cf0,28,28,240,240.0,87.6,52.5
2225,blue,cyan-blue,Vivid blue,#1E90FF,30,144,255,210.0,100.0,55.9
2233,cyan,cyan,Vivid cyan,#15f2fd,21,242,253,182.0,98.3,53.7
2234,cyan,medium light green-cyan,Vivid cyan,#33FFCC,51,255,204,165.0,100.0,60.0
2235,green,green-cyan,Vivid green-cyan,#0BDA51,11,218,81,140.0,90.4,44.9
2236,green,green,Vivid green,#ADFF2F,173,255,47,84.0,100.0,59.2
2237,green,green,Vivid green,#87FF2A,135,255,42,94.0,100.0,58.2
2238,green,green,Vivid lime green,#39FF14,57,255,20,111.0,100.0,53.9
2239,pink,magenta,Vivid purple,#EF1DE7,239,29,231,302.0,86.8,52.5
2240,pink,magenta,Vivid purple,#ff1dce,255,29,206,313.0,100.0,55.7
2242,purple,magenta,Vivid purple,#C316E9,195,22,233,289.0,82.7,50.0
2249,orange,brown,Vivid brown,#fb9912,251,153,18,34.0,96.7,52.7
2256,orange,medium light brown,Medium light brown,#FF9933,255,153,51,30.0,100.0,60.0
2258,orange,orange,Vivid orange,#FF7518,255,117,24,24.0,100.0,54.7
2263,orange,red-orange,Vivid orange,#FC5110,252,81,16,17.0,97.5,52.5
2270,yellow,yellow,Yellow,#f6b511,246,181,17,42.0,92.7,51.6
2278,pink,magenta-pink,Vivid pink,#e0218a,224,33,138,327.0,75.5,50.4
2283,pink,medium light magenta,Vivid pink,#FF33CC,255,51,204,315.0,100.0,60.0
2286,pink,pink,Vivid pink,#F8227F,248,34,127,334.0,93.9,55.3
2296,red,pink-red,Vivid red,#FF033E,255,3,62,346.0,100.0,50.6
2305,red,red,Vivid red,#D9381E,217,56,30,8.0,75.7,48.4
2309,purple,blue-magenta,Vivid violet,#5218FA,82,24,250,255.0,95.8,53.7
2310,purple,blue-magenta,Vivid violet,#791CF8,121,28,248,265.0,94.0,54.1
2312,purple,magenta,Vivid violet,#BC13FE,188,19,254,283.0,99.2,53.5
2313,yellow,medium light yellow,Vivid yellow,#FFCC33,255,204,51,45.0,100.0,60.0
2314,yellow,medium light yellow-green,Vivid yellow,#FFFF33,255,255,51,60.0,100.0,60.0
2333,green,yellow-green,Vivid yellow-green,#C6E610,193,230,16,70.0,87.0,48.2
2340,white,very light grey,White,#FFFFFF,255,255,255,0.0,0.0,100.0
2344,yellow,yellow,Yellow,#ECD540,236,213,64,52.0,81.9,58.8
2348,green,yellow-green,Yellow-green,#D1E231,209,226,49,66.0,75.3,53.9"""

# %%
# index,Name0,Desc1,Desc2,HEX,R,G,B,Hue,Sat,Lum
striped = []
for line in csv_desc.split('\n'):
    # Get desc2
    tmp = line.split(',')
# ['3', 'blue', 'blue', 'Bright blue', '#3C69E7', '60', '105', '231', '224', '78.1', '57.1']
    new_line = []
    new_line.append('"'+tmp[3]+'"')
    # get rgb
    r = int(tmp[5])
    g = int(tmp[6])
    b = int(tmp[7])
    # get hsl
    h = float(tmp[8])
    sl = float(tmp[9])/100
    l = float(tmp[10])/100
    # Get HSV
    _, sv, v = colorsys.rgb_to_hsv(r/255, g/255, b/255)
    # reconstruct
    new_line.append("0x{:02x}".format(r))
    new_line.append("0x{:02x}".format(g))
    new_line.append("0x{:02x}".format(b))
    new_line.append("{:.1f}F".format(h))
    new_line.append("{:.3f}F".format(sl))
    new_line.append("{:.3f}F".format(l))
    new_line.append("{:.3f}F".format(sv))
    new_line.append("{:.3f}F".format(v))
    striped.append(new_line)
# Format back to code
formatted = ''
for line in striped:
    formatted += new_pre
    for item in line:
        if line.index(item) == 0:
            formatted += item
        else: 
            formatted += ','
            formatted += item
    formatted += post
    formatted += '\n'
print(formatted)
# Out:
#         colourList.add(ColorName("Black",0x00,0x00,0x00,0.0F,0.000F,0.000F,0.000F,0.000F))
#         colourList.add(ColorName("Bright blue",0x41,0x69,0xe1,225.0F,0.727F,0.569F,0.711F,0.882F))
#         colourList.add(ColorName("Bright blue",0x45,0xb1,0xe8,200.0F,0.780F,0.590F,0.703F,0.910F))
#         colourList.add(ColorName("Bright blue",0x3e,0x8e,0xde,210.0F,0.708F,0.557F,0.721F,0.871F))
#         colourList.add(ColorName("Bright blue",0x41,0x66,0xf5,228.0F,0.900F,0.608F,0.735F,0.961F))
#         colourList.add(ColorName("Bright cyan",0x3e,0xca,0xe8,191.0F,0.787F,0.576F,0.733F,0.910F))
#         colourList.add(ColorName("Bright cyan",0x40,0xe0,0xd0,174.0F,0.721F,0.565F,0.714F,0.878F))
#         colourList.add(ColorName("Bright green",0xa7,0xf4,0x32,84.0F,0.898F,0.576F,0.795F,0.957F))
#         colourList.add(ColorName("Bright green",0xc2,0xf7,0x32,76.0F,0.925F,0.582F,0.798F,0.969F))
# ...

# %% [markdown]
# # From hsl only

# %%
# Adjusted colour desc
code = """        colorList.add(ColorName("Black",0.0f,0.0f,0.0f))
        colorList.add(ColorName("Black",50.0f,0.0f,0.0f))
        colorList.add(ColorName("Black",25.7f,2.3f,6.3f))
        colorList.add(ColorName("Black",75.0f,2.5f,8.3f))
        colorList.add(ColorName("Black",100.0f,0.0f,0.0f))
        colorList.add(ColorName("Grey",0.0f,9.0f,20.0f))
        colorList.add(ColorName("Grey",50.0f,9.0f,20.0f))
        colorList.add(ColorName("Grey",25.7f,5.3f,20.3f))
        colorList.add(ColorName("Grey",75.0f,11.5f,20.3f))
        colorList.add(ColorName("Grey",100.0f,9.0f,20.0f))
        colorList.add(ColorName("Blue",56.5f,100.0f,48.2f))
        colorList.add(ColorName("Blue-purple",75.4f,100.0f,50.0f))
        colorList.add(ColorName("Blue-violet",68.8f,100.0f,50.0f))
        colorList.add(ColorName("Blueish white",62.2f,100.0f,97.9f))
        colorList.add(ColorName("Blueish white",64.4f,100.0f,98.2f))
        colorList.add(ColorName("Bright blue",59.1f,77.4f,55.7f))
        colorList.add(ColorName("Bright blue",61.6f,80.3f,56.1f))
        colorList.add(ColorName("Bright cyan",50.7f,75.4f,57.1f))
        colorList.add(ColorName("Bright green",23.6f,89.1f,58.4f))
        colorList.add(ColorName("Bright orange",6.6f,83.2f,55.9f))
        colorList.add(ColorName("Bright pink",92.7f,84.6f,57.2f))
        colorList.add(ColorName("Bright purple",83.9f,82.2f,57.1f))
        colorList.add(ColorName("Bright red",1.1f,79.0f,55.2f))
        colorList.add(ColorName("Bright red",97.2f,75.3f,53.3f))
        colorList.add(ColorName("Bright violet",75.4f,75.1f,55.1f))
        colorList.add(ColorName("Bright yellow",16.8f,96.2f,56.1f))
        colorList.add(ColorName("Brown",7.2f,62.3f,48.4f))
        colorList.add(ColorName("Brown",80.3f,36.4f,53.7f))
        colorList.add(ColorName("Cyan",50.9f,100.0f,46.7f))
        colorList.add(ColorName("Cyan tint white",50.8f,100.0f,95.3f))
        colorList.add(ColorName("Dark blue",60.9f,88.6f,31.7f))
        colorList.add(ColorName("Dark blue",63.3f,87.8f,31.5f))
        colorList.add(ColorName("Dark bluish grey",57.2f,18.2f,39.8f))
        colorList.add(ColorName("Dark brown",4.6f,72.7f,32.9f))
        colorList.add(ColorName("Dark brown",97.2f,69.9f,33.9f))
        colorList.add(ColorName("Dark cyan",49.8f,93.8f,28.6f))
        colorList.add(ColorName("Dark green",24.9f,82.4f,31.0f))
        colorList.add(ColorName("Dark grey",0.0f,0.0f,52.7f))
        colorList.add(ColorName("Dark greyish blue",62.9f,11.4f,58.5f))
        colorList.add(ColorName("Dark greyish blue",64.9f,11.6f,58.8f))
        colorList.add(ColorName("Dark greyish blue-purple",71.4f,19.0f,38.2f))
        colorList.add(ColorName("Dark greyish brown",3.3f,20.3f,52.2f))
        colorList.add(ColorName("Dark greyish cyan",48.5f,10.2f,49.9f))
        colorList.add(ColorName("Dark greyish green",24.6f,13.3f,48.9f))
        colorList.add(ColorName("Dark greyish green-cyan",41.3f,13.8f,50.6f))
        colorList.add(ColorName("Dark greyish lime green",34.9f,3.8f,48.5f))
        colorList.add(ColorName("Dark greyish orange",6.9f,12.0f,50.7f))
        colorList.add(ColorName("Dark greyish pink",90.8f,12.4f,54.4f))
        colorList.add(ColorName("Dark greyish purple",84.3f,10.1f,56.0f))
        colorList.add(ColorName("Dark greyish red",4.5f,15.7f,52.7f))
        colorList.add(ColorName("Dark greyish red",98.1f,9.6f,51.2f))
        colorList.add(ColorName("Dark greyish violet",77.6f,9.7f,49.3f))
        colorList.add(ColorName("Dark greyish yellow",14.6f,5.2f,49.9f))
        colorList.add(ColorName("Dark greyish yellow",15.9f,4.0f,51.0f))
        colorList.add(ColorName("Dark lime green",38.7f,86.8f,32.8f))
        colorList.add(ColorName("Dark medium red",97.1f,47.9f,35.0f))
        colorList.add(ColorName("Dark moderate blue",60.6f,42.8f,41.8f))
        colorList.add(ColorName("Dark moderate blue",63.6f,43.1f,41.0f))
        colorList.add(ColorName("Dark moderate blue-purple",71.4f,49.2f,37.1f))
        colorList.add(ColorName("Dark moderate brown",6.3f,43.8f,43.8f))
        colorList.add(ColorName("Dark moderate cyan",50.6f,45.5f,38.1f))
        colorList.add(ColorName("Dark moderate green",24.2f,42.3f,43.7f))
        colorList.add(ColorName("Dark moderate lime green",32.3f,38.7f,39.5f))
        colorList.add(ColorName("Dark moderate pink",94.3f,43.9f,45.0f))
        colorList.add(ColorName("Dark moderate pink-red",96.9f,31.5f,51.4f))
        colorList.add(ColorName("Dark moderate purple",69.7f,45.5f,41.9f))
        colorList.add(ColorName("Dark moderate purple",78.0f,41.9f,43.3f))
        colorList.add(ColorName("Dark moderate red",1.3f,39.3f,47.3f))
        colorList.add(ColorName("Dark moderate red",99.2f,40.7f,43.0f))
        colorList.add(ColorName("Dark moderate violet",71.9f,29.9f,49.2f))
        colorList.add(ColorName("Dark moderate violet",73.4f,33.8f,47.6f))
        colorList.add(ColorName("Dark moderate yellow",12.8f,33.9f,45.7f))
        colorList.add(ColorName("Dark moderate yellow-green",18.9f,46.7f,44.1f))
        colorList.add(ColorName("Dark olive",16.1f,100.0f,22.5f))
        colorList.add(ColorName("Dark pink",91.8f,74.6f,37.6f))
        colorList.add(ColorName("Dark pink-red",94.0f,87.5f,34.4f))
        colorList.add(ColorName("Dark purple",82.6f,92.0f,30.3f))
        colorList.add(ColorName("Dark red",0.5f,66.2f,39.7f))
        colorList.add(ColorName("Dark red",97.7f,81.5f,34.4f))
        colorList.add(ColorName("Dark violet",71.7f,74.3f,27.5f))
        colorList.add(ColorName("Dark violet",73.5f,76.1f,29.7f))
        colorList.add(ColorName("Dark yellow brown",11.1f,47.4f,42.0f))
        colorList.add(ColorName("Dark yellow-green",17.4f,84.5f,32.2f))
        colorList.add(ColorName("Dark yellow-olive",13.6f,95.2f,33.3f))
        colorList.add(ColorName("Green",25.3f,100.0f,49.3f))
        colorList.add(ColorName("Green-cyan",43.9f,100.0f,46.8f))
        colorList.add(ColorName("Grey",21.9f,4.0f,70.9f))
        colorList.add(ColorName("Grey",43.8f,8.1f,73.2f))
        colorList.add(ColorName("Grey brown",10.4f,25.6f,45.1f))
        colorList.add(ColorName("Grey yellow",11.9f,26.1f,41.4f))
        colorList.add(ColorName("Grey-green",27.5f,1.9f,68.8f))
        colorList.add(ColorName("Greyish blue",63.1f,28.3f,67.0f))
        colorList.add(ColorName("Greyish blue",65.5f,29.2f,67.6f))
        colorList.add(ColorName("Greyish brown",21.7f,28.2f,61.7f))
        colorList.add(ColorName("Greyish brown",36.7f,22.3f,61.9f))
        colorList.add(ColorName("Greyish cyan",48.0f,30.8f,74.2f))
        colorList.add(ColorName("Greyish dark blue",63.3f,26.4f,43.0f))
        colorList.add(ColorName("Greyish dark blue",64.4f,25.3f,41.7f))
        colorList.add(ColorName("Greyish dark blue-purple",66.9f,21.2f,52.6f))
        colorList.add(ColorName("Greyish dark brown",6.9f,23.2f,47.1f))
        colorList.add(ColorName("Greyish dark cyan",48.7f,24.5f,50.0f))
        colorList.add(ColorName("Greyish dark cyan-blue",57.6f,24.1f,54.9f))
        colorList.add(ColorName("Greyish dark green",31.8f,22.4f,52.9f))
        colorList.add(ColorName("Greyish dark green-cyan",41.5f,25.3f,53.9f))
        colorList.add(ColorName("Greyish dark lime green",31.7f,18.7f,48.4f))
        colorList.add(ColorName("Greyish dark pink",94.2f,22.5f,49.7f))
        colorList.add(ColorName("Greyish dark pink-red",97.8f,16.7f,45.0f))
        colorList.add(ColorName("Greyish dark purple",85.0f,21.9f,48.0f))
        colorList.add(ColorName("Greyish dark red",0.0f,26.5f,38.4f))
        colorList.add(ColorName("Greyish dark violet",76.4f,23.5f,52.6f))
        colorList.add(ColorName("Greyish dark yellow",13.1f,23.6f,43.1f))
        colorList.add(ColorName("Greyish dark yellow",13.3f,22.0f,42.7f))
        colorList.add(ColorName("Greyish dark yellow-green",41.4f,25.6f,48.7f))
        colorList.add(ColorName("Greyish green",27.9f,30.2f,62.2f))
        colorList.add(ColorName("Greyish green-cyan",43.1f,24.2f,65.8f))
        colorList.add(ColorName("Greyish lime green",34.0f,34.1f,62.6f))
        colorList.add(ColorName("Greyish orange",7.1f,25.7f,68.4f))
        colorList.add(ColorName("Greyish pink",92.7f,34.9f,65.4f))
        colorList.add(ColorName("Greyish pink-red",97.3f,38.7f,62.6f))
        colorList.add(ColorName("Greyish purple",85.8f,33.6f,66.3f))
        colorList.add(ColorName("Greyish red",0.9f,21.2f,70.1f))
        colorList.add(ColorName("Greyish red",97.8f,17.8f,67.8f))
        colorList.add(ColorName("Greyish violet",74.6f,28.2f,63.1f))
        colorList.add(ColorName("Greyish white",0.0f,0.0f,96.7f))
        colorList.add(ColorName("Greyish yellow",14.7f,31.1f,62.5f))
        colorList.add(ColorName("Greyish yellow",15.6f,33.0f,63.0f))
        colorList.add(ColorName("Greyish yellow brown",11.7f,36.4f,58.0f))
        colorList.add(ColorName("Greyish yellow-green",17.9f,42.8f,60.6f))
        colorList.add(ColorName("Light brown",9.3f,75.0f,81.3f))
        colorList.add(ColorName("Light grey",12.6f,6.3f,85.4f))
        colorList.add(ColorName("Light grey",23.6f,11.9f,88.4f))
        colorList.add(ColorName("Light greyish blue",60.8f,41.8f,83.1f))
        colorList.add(ColorName("Light greyish blue",63.5f,49.9f,83.6f))
        colorList.add(ColorName("Light greyish brown",9.8f,44.2f,86.9f))
        colorList.add(ColorName("Light greyish cyan",52.7f,37.8f,88.1f))
        colorList.add(ColorName("Light greyish green",21.9f,48.2f,82.8f))
        colorList.add(ColorName("Light greyish green-cyan",43.9f,29.7f,82.5f))
        colorList.add(ColorName("Light greyish pink",93.8f,66.1f,89.1f))
        colorList.add(ColorName("Light greyish purple",66.4f,54.7f,88.8f))
        colorList.add(ColorName("Light greyish purple",70.1f,50.9f,88.0f))
        colorList.add(ColorName("Light greyish red",1.3f,34.0f,87.5f))
        colorList.add(ColorName("Light greyish red",97.2f,31.3f,80.6f))
        colorList.add(ColorName("Light greyish violet",75.4f,42.0f,85.5f))
        colorList.add(ColorName("Light greyish yellow",14.9f,44.1f,84.5f))
        colorList.add(ColorName("Light greyish yellow",15.4f,47.8f,84.1f))
        colorList.add(ColorName("Light lime green",32.3f,100.0f,68.2f))
        colorList.add(ColorName("Light magenta",83.3f,100.0f,70.0f))
        colorList.add(ColorName("Light orange",7.2f,90.9f,70.0f))
        colorList.add(ColorName("Light pink",91.1f,100.0f,66.0f))
        colorList.add(ColorName("Light red",1.8f,90.7f,71.0f))
        colorList.add(ColorName("Light red",97.3f,100.0f,63.8f))
        colorList.add(ColorName("Light red-orange",3.1f,85.5f,75.7f))
        colorList.add(ColorName("Light violet",72.2f,100.0f,70.0f))
        colorList.add(ColorName("Light yellow",16.1f,100.0f,67.8f))
        colorList.add(ColorName("Light yellow-green",17.7f,83.8f,78.7f))
        colorList.add(ColorName("Lime-green",34.4f,100.0f,50.0f))
        colorList.add(ColorName("Medium brown",7.4f,71.3f,45.0f))
        colorList.add(ColorName("Medium dark blue-purple",68.9f,94.6f,36.1f))
        colorList.add(ColorName("Medium dark blue-purple",70.6f,74.6f,36.0f))
        colorList.add(ColorName("medium dark brown",4.7f,42.1f,35.9f))
        colorList.add(ColorName("Medium dark brown",6.3f,53.8f,33.8f))
        colorList.add(ColorName("Medium dark cyan",55.1f,100.0f,36.6f))
        colorList.add(ColorName("Medium dark cyan-blue",56.9f,97.1f,37.5f))
        colorList.add(ColorName("Medium dark green",40.5f,67.6f,33.2f))
        colorList.add(ColorName("Medium dark green-cyan",43.1f,40.5f,36.6f))
        colorList.add(ColorName("Medium dark greyish brown",7.2f,24.4f,37.8f))
        colorList.add(ColorName("Medium dark pink",92.0f,59.6f,34.2f))
        colorList.add(ColorName("Medium dark purple",82.5f,44.3f,36.3f))
        colorList.add(ColorName("Medium dark red",0.5f,89.9f,30.8f))
        colorList.add(ColorName("Medium dark red-orange",4.9f,95.3f,37.8f))
        colorList.add(ColorName("Medium dark yellow",14.4f,42.5f,36.8f))
        colorList.add(ColorName("Medium dark yellow-brown",11.7f,87.4f,33.4f))
        colorList.add(ColorName("Medium dark yellow-green",18.8f,42.3f,37.5f))
        colorList.add(ColorName("Medium greyish blue",62.8f,35.6f,65.4f))
        colorList.add(ColorName("Medium greyish blue",63.6f,35.3f,63.4f))
        colorList.add(ColorName("Medium greyish cyan",57.0f,44.1f,64.8f))
        colorList.add(ColorName("Medium greyish green-cyan",41.2f,41.6f,68.4f))
        colorList.add(ColorName("Medium greyish purple",69.4f,43.5f,64.0f))
        colorList.add(ColorName("Medium greyish purple",71.2f,43.7f,64.5f))
        colorList.add(ColorName("Medium light blue",65.3f,100.0f,66.9f))
        colorList.add(ColorName("Medium light brown",9.2f,83.6f,60.8f))
        colorList.add(ColorName("Medium light cyan-blue",58.3f,50.0f,60.0f))
        colorList.add(ColorName("Medium light green-cyan",44.4f,50.7f,60.2f))
        colorList.add(ColorName("Medium light greyish brown",6.9f,23.0f,60.8f))
        colorList.add(ColorName("Medium light pink",92.6f,56.4f,71.3f))
        colorList.add(ColorName("Medium light pink-red",0.6f,95.8f,62.9f))
        colorList.add(ColorName("Medium light pink-red",97.6f,98.5f,61.8f))
        colorList.add(ColorName("Medium light red",2.0f,72.3f,66.1f))
        colorList.add(ColorName("Medium light red",98.0f,55.9f,72.0f))
        colorList.add(ColorName("Medium light yellow",14.2f,87.9f,68.5f))
        colorList.add(ColorName("Medium light yellow",14.4f,87.0f,68.9f))
        colorList.add(ColorName("Medium light yellow-green",19.8f,59.9f,69.9f))
        colorList.add(ColorName("Medium soft blue",58.3f,80.2f,67.4f))
        colorList.add(ColorName("Moderate blue",62.2f,51.9f,55.5f))
        colorList.add(ColorName("Moderate blue-purple",68.5f,52.4f,54.1f))
        colorList.add(ColorName("Moderate brown",7.9f,45.0f,48.4f))
        colorList.add(ColorName("Moderate cyan",50.7f,53.2f,51.9f))
        colorList.add(ColorName("Moderate cyan-blue",57.7f,50.0f,52.0f))
        colorList.add(ColorName("Moderate dark brown",3.4f,75.8f,32.8f))
        colorList.add(ColorName("Moderate green",27.2f,50.2f,48.8f))
        colorList.add(ColorName("Moderate green-cyan",41.8f,54.7f,50.8f))
        colorList.add(ColorName("Moderate lime green",33.3f,55.0f,45.3f))
        colorList.add(ColorName("Moderate pink",93.8f,55.3f,51.1f))
        colorList.add(ColorName("Moderate purple",83.1f,54.9f,51.6f))
        colorList.add(ColorName("Moderate red",1.6f,50.7f,53.9f))
        colorList.add(ColorName("Moderate red",98.3f,54.9f,52.4f))
        colorList.add(ColorName("Moderate violet",77.7f,47.1f,56.5f))
        colorList.add(ColorName("Moderate yellow",13.8f,55.2f,52.5f))
        colorList.add(ColorName("Moderate yellow",14.1f,54.6f,52.1f))
        colorList.add(ColorName("Moderate yellow-green",19.4f,54.0f,52.2f))
        colorList.add(ColorName("Orange",8.2f,100.0f,49.5f))
        colorList.add(ColorName("Orange brown",6.7f,60.4f,59.4f))
        colorList.add(ColorName("Orange yellow",11.9f,80.6f,56.3f))
        colorList.add(ColorName("Pale blue",54.7f,100.0f,81.4f))
        colorList.add(ColorName("Pale cyan",51.5f,100.0f,85.6f))
        colorList.add(ColorName("Pale magenta",81.7f,100.0f,86.7f))
        colorList.add(ColorName("Pale orange",8.9f,100.0f,84.0f))
        colorList.add(ColorName("Pale pink",1.5f,100.0f,92.0f))
        colorList.add(ColorName("Pale pink",92.3f,100.0f,84.3f))
        colorList.add(ColorName("Pale red",97.1f,100.0f,85.8f))
        colorList.add(ColorName("Pale red-pink",2.2f,100.0f,82.7f))
        colorList.add(ColorName("Pale violet",76.7f,100.0f,84.5f))
        colorList.add(ColorName("Pale yellow",16.9f,100.0f,81.7f))
        colorList.add(ColorName("Pink",90.2f,100.0f,48.3f))
        colorList.add(ColorName("Pink-red",95.4f,91.7f,51.3f))
        colorList.add(ColorName("Pinkish white",90.7f,100.0f,97.7f))
        colorList.add(ColorName("Purple",80.0f,100.0f,49.8f))
        colorList.add(ColorName("Purple-pink",90.2f,52.4f,52.1f))
        colorList.add(ColorName("Purplish white",72.5f,100.0f,97.8f))
        colorList.add(ColorName("Red",0.9f,100.0f,48.2f))
        colorList.add(ColorName("Red",97.2f,100.0f,47.2f))
        colorList.add(ColorName("Red-orange",4.1f,79.0f,51.3f))
        colorList.add(ColorName("Reddish white",2.0f,100.0f,96.6f))
        colorList.add(ColorName("Soft blue",57.0f,92.3f,72.8f))
        colorList.add(ColorName("Soft blue-purple",69.3f,77.7f,64.6f))
        colorList.add(ColorName("Soft brown",6.1f,74.6f,65.4f))
        colorList.add(ColorName("Soft cyan",52.4f,70.0f,69.1f))
        colorList.add(ColorName("Soft green",21.8f,74.0f,63.9f))
        colorList.add(ColorName("Soft lime green",38.4f,66.2f,65.1f))
        colorList.add(ColorName("Soft orange",7.3f,82.7f,67.8f))
        colorList.add(ColorName("Soft pink",5.3f,62.7f,65.3f))
        colorList.add(ColorName("Soft pink",93.7f,80.5f,64.9f))
        colorList.add(ColorName("Soft pink-purple",87.5f,75.6f,67.8f))
        colorList.add(ColorName("Soft purple",84.6f,83.6f,69.8f))
        colorList.add(ColorName("Soft red",1.5f,87.6f,67.7f))
        colorList.add(ColorName("Soft red",97.6f,84.2f,68.4f))
        colorList.add(ColorName("Soft red-brown",1.5f,67.6f,57.6f))
        colorList.add(ColorName("Soft red-orange",5.0f,82.1f,64.6f))
        colorList.add(ColorName("Soft violet",75.5f,78.4f,67.7f))
        colorList.add(ColorName("Soft yellow",14.1f,87.9f,68.3f))
        colorList.add(ColorName("Soft yellow",14.7f,88.5f,68.9f))
        colorList.add(ColorName("Soft yellow-green",18.1f,75.4f,62.7f))
        colorList.add(ColorName("Strong blue",62.7f,69.4f,43.9f))
        colorList.add(ColorName("Strong blue",63.2f,71.7f,43.0f))
        colorList.add(ColorName("Strong blue-purple",68.5f,94.5f,41.3f))
        colorList.add(ColorName("Strong brown",8.3f,73.9f,44.9f))
        colorList.add(ColorName("Strong cyan",52.7f,82.2f,43.9f))
        colorList.add(ColorName("Strong cyan-blue",58.3f,81.3f,44.5f))
        colorList.add(ColorName("Strong dark blue",60.5f,95.0f,37.7f))
        colorList.add(ColorName("Strong dark cyan",50.8f,96.7f,38.9f))
        colorList.add(ColorName("Strong dark pink",89.9f,75.5f,44.8f))
        colorList.add(ColorName("Strong dark purple",81.7f,100.0f,38.4f))
        colorList.add(ColorName("Strong dark red",0.8f,87.9f,38.8f))
        colorList.add(ColorName("Strong dark red",96.5f,97.9f,38.0f))
        colorList.add(ColorName("Strong dark yellow brown",13.6f,82.5f,41.4f))
        colorList.add(ColorName("Strong dark yellow brown",13.7f,80.0f,41.6f))
        colorList.add(ColorName("Strong dark yellow-green",20.3f,95.6f,37.8f))
        colorList.add(ColorName("Strong green",25.9f,87.0f,40.8f))
        colorList.add(ColorName("Strong green-cyan",36.7f,90.5f,39.5f))
        colorList.add(ColorName("Strong lime green",33.3f,60.8f,50.0f))
        colorList.add(ColorName("Strong pink",94.2f,84.9f,44.0f))
        colorList.add(ColorName("Strong purple",84.8f,82.9f,44.0f))
        colorList.add(ColorName("Strong red",97.8f,78.7f,44.3f))
        colorList.add(ColorName("Strong red-brown",0.7f,71.4f,44.7f))
        colorList.add(ColorName("Strong red-orange",4.7f,89.7f,42.0f))
        colorList.add(ColorName("Strong violet",78.4f,83.7f,43.3f))
        colorList.add(ColorName("Strong yellow-green",19.9f,78.2f,44.9f))
        colorList.add(ColorName("Very dark blue",60.9f,83.1f,20.4f))
        colorList.add(ColorName("Very dark blue",62.9f,76.0f,21.1f))
        colorList.add(ColorName("Very dark brown",8.6f,54.8f,21.8f))
        colorList.add(ColorName("Very dark cyan",49.8f,89.5f,16.0f))
        colorList.add(ColorName("Very dark green",39.6f,80.5f,19.3f))
        colorList.add(ColorName("Very dark grey",0.0f,0.0f,30.1f))
        colorList.add(ColorName("Very dark grey blue",62.0f,31.0f,26.6f))
        colorList.add(ColorName("Very dark grey blue",64.3f,31.3f,29.0f))
        colorList.add(ColorName("Very dark grey cyan",49.9f,28.1f,23.9f))
        colorList.add(ColorName("Very dark grey green",35.0f,32.2f,25.7f))
        colorList.add(ColorName("Very dark grey pink",91.4f,30.4f,29.7f))
        colorList.add(ColorName("Very dark grey purple",82.9f,30.2f,25.8f))
        colorList.add(ColorName("Very dark grey red",2.2f,30.7f,23.0f))
        colorList.add(ColorName("Very dark grey red",97.7f,33.3f,26.9f))
        colorList.add(ColorName("Very dark grey violet",70.8f,30.1f,28.0f))
        colorList.add(ColorName("Very dark grey violet",72.4f,28.1f,29.9f))
        colorList.add(ColorName("Very dark grey yellow",14.9f,33.8f,25.8f))
        colorList.add(ColorName("Very dark grey yellow",16.3f,35.3f,27.2f))
        colorList.add(ColorName("Very dark greyish blue",57.7f,14.8f,30.6f))
        colorList.add(ColorName("Very dark greyish blue",61.5f,16.3f,32.1f))
        colorList.add(ColorName("Very dark greyish cyan",51.1f,13.4f,27.4f))
        colorList.add(ColorName("Very dark greyish green",24.8f,12.4f,27.1f))
        colorList.add(ColorName("Very dark greyish lime",40.4f,15.0f,23.1f))
        colorList.add(ColorName("Very dark greyish lime green",33.4f,10.9f,28.3f))
        colorList.add(ColorName("Very dark greyish magenta",3.6f,8.7f,40.8f))
        colorList.add(ColorName("Very dark greyish magenta",84.4f,13.9f,31.3f))
        colorList.add(ColorName("Very dark greyish orange",38.8f,7.6f,36.8f))
        colorList.add(ColorName("Very dark greyish orange",70.0f,1.3f,43.7f))
        colorList.add(ColorName("Very dark greyish pink",91.7f,16.7f,30.9f))
        colorList.add(ColorName("Very dark greyish red",3.1f,16.6f,28.0f))
        colorList.add(ColorName("Very dark greyish red",94.5f,13.2f,27.3f))
        colorList.add(ColorName("Very dark greyish violet",76.2f,17.9f,28.8f))
        colorList.add(ColorName("Very dark greyish yellow",15.5f,12.7f,29.4f))
        colorList.add(ColorName("Very dark greyish yellow",16.6f,12.8f,28.4f))
        colorList.add(ColorName("Very dark lime green",32.4f,93.2f,20.0f))
        colorList.add(ColorName("Very dark olive",14.9f,72.9f,21.7f))
        colorList.add(ColorName("Very dark olive",15.8f,68.5f,22.4f))
        colorList.add(ColorName("Very dark pink",92.4f,73.8f,20.7f))
        colorList.add(ColorName("Very dark purple",84.7f,80.8f,20.0f))
        colorList.add(ColorName("Very dark red",1.7f,63.3f,23.3f))
        colorList.add(ColorName("Very dark red",97.6f,82.3f,19.3f))
        colorList.add(ColorName("Very dark violet",75.2f,74.7f,19.7f))
        colorList.add(ColorName("Very light blue-purple",67.1f,100.0f,83.2f))
        colorList.add(ColorName("Very light brown",8.7f,49.3f,89.5f))
        colorList.add(ColorName("Very light cyan",50.8f,100.0f,74.5f))
        colorList.add(ColorName("Very light cyan-blue",59.2f,100.0f,74.7f))
        colorList.add(ColorName("Very light cyan-green",44.4f,100.0f,74.9f))
        colorList.add(ColorName("Very light green",29.2f,100.0f,74.9f))
        colorList.add(ColorName("Very light green-cyan",41.9f,100.0f,89.4f))
        colorList.add(ColorName("Very light grey",33.6f,12.3f,91.2f))
        colorList.add(ColorName("Very light grey",66.1f,21.3f,92.5f))
        colorList.add(ColorName("Very light greyish blue",62.2f,28.1f,93.5f))
        colorList.add(ColorName("Very light greyish brown",9.6f,56.0f,94.4f))
        colorList.add(ColorName("Very light greyish cyan",45.8f,47.0f,94.0f))
        colorList.add(ColorName("Very light greyish purple",68.1f,70.9f,98.0f))
        colorList.add(ColorName("Very light greyish purple",76.4f,70.0f,96.3f))
        colorList.add(ColorName("Very light greyish yellow",14.0f,44.9f,90.5f))
        colorList.add(ColorName("Very light greyish yellow",14.5f,49.5f,90.6f))
        colorList.add(ColorName("Very light lime green",33.3f,100.0f,79.8f))
        colorList.add(ColorName("Very light orange",6.8f,100.0f,75.2f))
        colorList.add(ColorName("Very light pink",92.2f,100.0f,76.3f))
        colorList.add(ColorName("Very light pink-red",0.8f,82.8f,88.6f))
        colorList.add(ColorName("Very light pink-red",98.6f,78.3f,89.9f))
        colorList.add(ColorName("Very light purple",82.2f,88.2f,78.8f))
        colorList.add(ColorName("Very light red",1.8f,89.5f,81.7f))
        colorList.add(ColorName("Very light red",98.8f,100.0f,76.7f))
        colorList.add(ColorName("Very light violet",75.0f,100.0f,80.0f))
        colorList.add(ColorName("Very light yellow",13.7f,86.8f,80.7f))
        colorList.add(ColorName("Very light yellow",14.2f,92.3f,80.2f))
        colorList.add(ColorName("Very light yellow-green",19.7f,93.2f,88.4f))
        colorList.add(ColorName("Very pale cyan",48.3f,100.0f,93.4f))
        colorList.add(ColorName("Very pale green",26.9f,100.0f,92.7f))
        colorList.add(ColorName("Very pale orange",8.3f,100.0f,91.0f))
        colorList.add(ColorName("Very pale pink",5.0f,100.0f,93.3f))
        colorList.add(ColorName("Very pale pink",91.7f,100.0f,91.0f))
        colorList.add(ColorName("Very pale purple",84.7f,100.0f,90.7f))
        colorList.add(ColorName("Very pale red",97.0f,100.0f,90.0f))
        colorList.add(ColorName("Very pale violet",70.8f,100.0f,90.8f))
        colorList.add(ColorName("Very pale yellow",15.3f,100.0f,91.5f))
        colorList.add(ColorName("Very pale yellow",16.3f,100.0f,91.4f))
        colorList.add(ColorName("Very soft blue",60.8f,62.8f,76.3f))
        colorList.add(ColorName("Very soft blue",63.9f,59.9f,76.4f))
        colorList.add(ColorName("Very soft brown",8.2f,65.4f,74.1f))
        colorList.add(ColorName("Very soft cyan",50.6f,59.0f,77.3f))
        colorList.add(ColorName("Very soft green",25.6f,70.8f,78.6f))
        colorList.add(ColorName("Very soft green-cyan",40.9f,61.4f,77.0f))
        colorList.add(ColorName("Very soft lime green",33.1f,63.8f,76.2f))
        colorList.add(ColorName("Very soft magenta",83.0f,67.6f,77.2f))
        colorList.add(ColorName("Very soft orange",11.9f,81.7f,83.6f))
        colorList.add(ColorName("Very soft orange",13.9f,90.1f,84.1f))
        colorList.add(ColorName("Very soft pink",92.5f,74.0f,80.7f))
        colorList.add(ColorName("Very soft red",97.8f,72.1f,76.9f))
        colorList.add(ColorName("Very soft violet",71.9f,80.6f,85.9f))
        colorList.add(ColorName("Very soft violet",73.5f,68.6f,81.1f))
        colorList.add(ColorName("Very soft yellow",14.2f,73.7f,78.9f))
        colorList.add(ColorName("Violet",73.6f,100.0f,50.0f))
        colorList.add(ColorName("Vivid blue",59.4f,95.2f,54.1f))
        colorList.add(ColorName("Vivid blue",63.0f,91.4f,53.3f))
        colorList.add(ColorName("Vivid brown",9.9f,92.6f,52.2f))
        colorList.add(ColorName("Vivid cyan",50.1f,92.0f,51.5f))
        colorList.add(ColorName("Vivid green",24.7f,100.0f,58.7f))
        colorList.add(ColorName("Vivid green-cyan",38.9f,90.4f,44.9f))
        colorList.add(ColorName("Vivid lime green",30.8f,100.0f,53.9f))
        colorList.add(ColorName("Vivid orange",5.7f,96.4f,52.7f))
        colorList.add(ColorName("Vivid pink",90.8f,91.1f,51.9f))
        colorList.add(ColorName("Vivid purple",82.8f,89.9f,51.3f))
        colorList.add(ColorName("Vivid red",2.3f,90.4f,52.2f))
        colorList.add(ColorName("Vivid red",97.6f,90.1f,51.4f))
        colorList.add(ColorName("Vivid violet",70.8f,95.8f,53.7f))
        colorList.add(ColorName("Vivid violet",72.6f,95.0f,53.7f))
        colorList.add(ColorName("Vivid yellow",14.3f,97.2f,52.0f))
        colorList.add(ColorName("Vivid yellow",14.9f,97.2f,52.1f))
        colorList.add(ColorName("Vivid yellow-green",19.3f,92.0f,49.5f))
        colorList.add(ColorName("White",20.8f,91.3f,97.6f))
        colorList.add(ColorName("White",34.9f,95.8f,97.6f))
        colorList.add(ColorName("White",100.0f,100.0f,100.0f))
        colorList.add(ColorName("White",50.0f,100.0f,100.0f))
        colorList.add(ColorName("White",0.0f,100.0f,100.0f))
        colorList.add(ColorName("Yellow",14.0f,95.1f,51.2f))
        colorList.add(ColorName("Yellow",14.7f,95.5f,50.9f))
        colorList.add(ColorName("Yellow brown",11.9f,59.1f,50.2f))
        colorList.add(ColorName("Yellow-green",19.3f,93.0f,51.7f))
        colorList.add(ColorName("Yellowish brown",11.8f,74.6f,43.8f))"""

# %%
striped = []
for line in code.split('\n'):
    line = line.lstrip(pre)
    line = line.rstrip(post)
    # Get desc
    tmp = line.split(',')
    # get hsl
    h = float(tmp[1].rstrip('f'))/100*360
    sl = float(tmp[2].rstrip('f'))/100
    l = float(tmp[3].rstrip('f'))/100
    # Reset Hue to 0.0-360.0
    tmp[1] = "{:.1f}F".format(h)
    # Reset sl and l from percentage to 0.0-1.0
    tmp[2] = "{:.2f}F".format(sl)
    tmp[3] = "{:.2f}F".format(l)
    # hex to int
    r, g, b = colorsys.hls_to_rgb(h/360,l,sl)
    # Get HSV
    h, sv, v = colorsys.rgb_to_hsv(r, g, b)
    # reconstruct
    tmp.insert(1, ("0x{:02x}".format(np.uint16(b*255))))
    tmp.insert(1, ("0x{:02x}".format(np.uint16(g*255))))
    tmp.insert(1, ("0x{:02x}".format(np.uint16(r*255))))
    tmp.append("{:.2f}F".format(sv))
    tmp.append("{:.2f}F".format(v))
    striped.append(tmp)
# Format back to code
formatted = ''
for line in striped:
    formatted += new_pre
    for item in line:
        if line.index(item) == 0:
            formatted += item
        else: 
            formatted += ','
            formatted += item
    formatted += post
    formatted += '\n'
print(formatted)
# Out:
#         colourList.add(ColorName("Black",0x00,0x00,0x00,0.0F,0.00F,0.00F,0.00F,0.00F))
#         colourList.add(ColorName("Black",0x00,0x00,0x00,180.0F,0.00F,0.00F,0.00F,0.00F))
#         colourList.add(ColorName("Black",0x10,0x10,0x0f,92.5F,0.02F,0.06F,0.04F,0.06F))
#         colourList.add(ColorName("Black",0x15,0x14,0x15,270.0F,0.03F,0.08F,0.05F,0.09F))
#         colourList.add(ColorName("Black",0x00,0x00,0x00,360.0F,0.00F,0.00F,0.00F,0.00F))
#         colourList.add(ColorName("Grey",0x37,0x2e,0x2e,0.0F,0.09F,0.20F,0.17F,0.22F))
#         colourList.add(ColorName("Grey",0x2e,0x37,0x37,180.0F,0.09F,0.20F,0.17F,0.22F))
#         colourList.add(ColorName("Grey",0x33,0x36,0x31,92.5F,0.05F,0.20F,0.10F,0.21F))
#         colourList.add(ColorName("Grey",0x33,0x2d,0x39,270.0F,0.12F,0.20F,0.21F,0.23F))
#         colourList.add(ColorName("Grey",0x37,0x2e,0x2e,360.0F,0.09F,0.20F,0.17F,0.22F))
#         colourList.add(ColorName("Blue",0x00,0x95,0xf5,203.4F,1.00F,0.48F,1.00F,0.96F))
# ...

# %% [markdown]
# # Short Desc to code

# %% [markdown]
# ## to html to check

# %%
html_pre = """<li> <span style="background-color: """
html_post = """</li>"""
striped = []
for line in code.split('\n'):
    line = line.lstrip(pre)
    line = line.rstrip(post)
    # Get desc
    tmp = line.split(',')
    # get hsl
    h = float(tmp[1].rstrip('f'))/100*360
    sl = float(tmp[2].rstrip('f'))/100
    l = float(tmp[3].rstrip('f'))/100
    # Reset Hue to 0.0-360.0
    tmp[1] = "{:.1f}F".format(h)
    # Reset sl and l from percentage to 0.0-1.0
    tmp[2] = "{:.2f}F".format(sl)
    tmp[3] = "{:.2f}F".format(l)
    # hex to int
    r, g, b = colorsys.hls_to_rgb(h/360,l,sl)
    # Get HSV
    h, sv, v = colorsys.rgb_to_hsv(r, g, b)
    # reconstruct
    tmp.insert(1, ("0x{:02x}".format(np.uint16(b*255))))
    tmp.insert(1, ("0x{:02x}".format(np.uint16(g*255))))
    tmp.insert(1, ("0x{:02x}".format(np.uint16(r*255))))
    tmp.append("{:.2f}F".format(sv))
    tmp.append("{:.2f}F".format(v))
    tmp.insert(0, "#{:02x}{:02x}{:02x}".format(np.uint16(r*255),np.uint16(g*255),np.uint16(b*255)))
    striped.append(tmp)
# Format back to code
formatted = ''
for line in striped:
    formatted += html_pre
    for item in line:
        if line.index(item) == 0:
            formatted += item
            formatted += ";\">"
            formatted += item
            formatted += " </span> "
        else: 
            formatted += ','
            formatted += item
    formatted += html_post
    formatted += '\n'
print(formatted)
# Out:
# <li> <span style="background-color: #000000;">#000000 </span> ,"Black",0x00,0x00,0x00,0.0F,0.00F,0.00F,0.00F,0.00F</li>
# <li> <span style="background-color: #000000;">#000000 </span> ,"Black",0x00,0x00,0x00,180.0F,0.00F,0.00F,0.00F,0.00F</li>
# <li> <span style="background-color: #10100f;">#10100f </span> ,"Black",0x10,0x10,0x0f,92.5F,0.02F,0.06F,0.04F,0.06F</li>
# <li> <span style="background-color: #151415;">#151415 </span> ,"Black",0x15,0x14,0x15,270.0F,0.03F,0.08F,0.05F,0.09F</li>
# <li> <span style="background-color: #000000;">#000000 </span> ,"Black",0x00,0x00,0x00,360.0F,0.00F,0.00F,0.00F,0.00F</li>
# <li> <span style="background-color: #372e2e;">#372e2e </span> ,"Grey",0x37,0x2e,0x2e,0.0F,0.09F,0.20F,0.17F,0.22F</li>
# <li> <span style="background-color: #2e3737;">#2e3737 </span> ,"Grey",0x2e,0x37,0x37,180.0F,0.09F,0.20F,0.17F,0.22F</li>
# <li> <span style="background-color: #333631;">#333631 </span> ,"Grey",0x33,0x36,0x31,92.5F,0.05F,0.20F,0.10F,0.21F</li>
# ...

# %%
get_txt()
msg = get_message()
print(msg)
# Out:
# Hello
# Hello
# Hello

# %%
hex(np.uint16(r*100))
# Out:
# '0x4c'

# %%
np.uint16(r)
# Out:
# 63665

# %%
hex(int(r*100))
# Out:
# '0x4c'
